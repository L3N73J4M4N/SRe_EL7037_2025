# %% [markdown]
# ### **Experimentos con Datos con Desgaste**

# %% [markdown]
# **Estudiantes**: Matías Carvajal y Daryl Clerc
# **Profesores**: Pablo Estévez, Jorge Vergara
# **EL7037 - Primavera 2025**

# %% [markdown]
# Librerías y Funciones Iniciales

# %%
import pandas as pd
import numpy as np
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import time
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
# Configuraciones
FEATURES_CANDIDATAS = None    
RANDOM_STATE = 42
TEST_SIZE    = 0.2

# %% [markdown]
# ### Data

# %%
# --- Nusselt number ---
file_path = './DATA_LIB_Degradation//df_n_train_des.txt'
df_n_train = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_n_val_des.txt'
df_n_val = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_n_test_des.txt'
df_n_test = pd.read_csv(file_path, sep=',')

# --- Drag coefficient ---
file_path = './DATA_LIB_Degradation//df_cdrag_train_des.txt'
df_cdrag_train = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_cdrag_val_des.txt'
df_cdrag_val = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_cdrag_test_des.txt'
df_cdrag_test = pd.read_csv(file_path, sep=',')

# --- Friction factor ---
file_path = './DATA_LIB_Degradation//df_ff_train_des.txt'
df_ff_train = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_ff_val_des.txt'
df_ff_val = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_ff_test_des.txt'
df_ff_test = pd.read_csv(file_path, sep=',')

# Vista rápida para validar
print("Nusselt train:", df_n_train.shape, df_n_train.columns.tolist())
print("Drag train:", df_cdrag_train.shape, df_cdrag_train.columns.tolist())
print("Friction train:", df_ff_train.shape, df_ff_train.columns.tolist())
# Out:
# Nusselt train: (13477, 5) ['S', 'Re', 'Pr', 'SoH', 'nusselt']
# Drag train: (13432, 4) ['S', 'Re', 'SoH', 'cdrag']
# Friction train: (13391, 4) ['S', 'Re', 'SoH', 'frictionFactor']

# %% [markdown]
# ### Nusselt

# %%
import matplotlib.pyplot as plt

x_train = df_n_train 
y_train = df_n_train["nusselt"]

UMBRAL = 2000
BANDA  = 200   # ancho de transición

fig, ax = plt.subplots(1, 2, figsize=(14, 5))

# --- Plot 1: Nu vs Re, coloreado por S ---
sc1 = ax[0].scatter(x_train["Re"], y_train, c=x_train["S"],
                    cmap="viridis", s=10, alpha=0.7)
ax[0].axvline(UMBRAL, color="red", linestyle="--", label=f"Umbral Re={UMBRAL}")
ax[0].axvspan(UMBRAL-BANDA, UMBRAL+BANDA, color="red", alpha=0.1, label=f"Transición ±{BANDA}")
ax[0].set_xlabel("Reynolds (Re)")
ax[0].set_ylabel("Nusselt (Nu)")
ax[0].set_title("Nu vs Re (color = S)")
fig.colorbar(sc1, ax=ax[0], label="S")
ax[0].legend()

# --- Plot 2: Nu vs S, coloreado por Re ---
sc2 = ax[1].scatter(x_train["S"], y_train, c=x_train["Re"],
                    cmap="magma", s=10, alpha=0.7)
ax[1].set_xlabel("S")
ax[1].set_ylabel("Nusselt (Nu)")
ax[1].set_title("Nu vs S (color = Re)")
fig.colorbar(sc2, ax=ax[1], label="Re")

fig.suptitle("Número de Nusselt (Train)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Etiquetar en todo el conjunto (train+val+test juntos)
df_n_all = pd.concat([df_n_train, df_n_val, df_n_test], ignore_index=True)

df_n_all["regimen"] = np.where(df_n_all["Re"] < 2000, "laminar", "turbulento")
df_n_all["en_transicion"] = df_n_all["Re"].between(2000-200, 2000+200)

# Conteos totales
print("Total datos:", len(df_n_all))
print("Laminar:", (df_n_all["regimen"]=="laminar").sum())
print("Turbulento:", (df_n_all["regimen"]=="turbulento").sum())
print("En transición:", df_n_all["en_transicion"].sum())

# También puedes ver la intersección
print("\nLaminar (fuera transición):",
      ((df_n_all["regimen"]=="laminar") & (~df_n_all["en_transicion"])).sum())
print("Turbulento (fuera transición):",
      ((df_n_all["regimen"]=="turbulento") & (~df_n_all["en_transicion"])).sum())
# Out:
# Total datos: 44941
# Laminar: 44748
# Turbulento: 193
# En transición: 493
#
# Laminar (fuera transición): 44396
# Turbulento (fuera transición): 52

# %%
# --- parámetros simples ---
FEATURES = ["S","Re","Pr","SoH"]
TARGET   = "nusselt"
UMBRAL   = 2000
BANDA    = 200

# %%
# 1) juntar y etiquetar
df = pd.concat([df_n_train, df_n_val], ignore_index=True)  # train+val para entrenar
df["regimen"] = np.where(df["Re"] < UMBRAL, "laminar", "turbulento")
df["en_transicion"] = df["Re"].between(UMBRAL-BANDA, UMBRAL+BANDA)

# %%
# 2) hacer subsets
df_mid = df.copy()                              # global (incluye todo)
df_lam = df[(df["regimen"]=="laminar") & (~df["en_transicion"])].copy()
df_tur = df[(df["regimen"]=="turbulento") & (~df["en_transicion"])].copy()

# %%
def XY(d): return d[FEATURES].to_numpy(), d[TARGET].to_numpy()

# %%
# 3) misma config PySR (Lucas)
def new_model():
    return PySRRegressor(
        niterations=200,
        binary_operators=["+","-","*","/","^"],
        unary_operators=[],
        population_size=50,
        populations=4,
        tournament_selection_n=3,
        verbosity=1,
        maxsize=20,
        parsimony=1e-2,
        constraints={'^':(-1,1)},
        complexity_of_variables=2,
        random_state=0,
        progress=True
    )

# %%
# 3a) entrenar global
X_mid, y_mid = XY(df_mid)
mid = new_model(); t0=time.time(); mid.fit(X_mid, y_mid); print("global:", time.time()-t0,"s")
# Out:
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# Compiling Julia backend...
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 5.150e+03
# Progress: 6 / 800 total iterations (0.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.218e+01  7.650e-03  y = 19.552 + x₀
# 6           3.532e+01  8.874e-02  y = (x₀ + 1.5003) / 0.1225
# 9           2.780e+01  7.982e-02  y = (x₀ * (x₁ * 0.018217)) + 11.36
# 12          2.721e+01  7.132e-03  y = ((x₀ * (x₁ * 0.022221)) * x₂) + 12.119
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.370e+04
# Progress: 38 / 800 total iterations (4.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.218e+01  7.650e-03  y = x₀ + 19.552
# 6           3.532e+01  8.874e-02  y = (x₀ + 1.5003) / 0.1225
# 9           2.780e+01  7.982e-02  y = (x₀ * (x₁ * 0.018217)) + 11.36
# 12          2.721e+01  7.132e-03  y = ((x₀ * (x₁ * 0.022221)) * x₂) + 12.119
# 14          2.670e+01  9.486e-03  y = (((0.022221 * (x₂ * x₁)) - -0.85418) * x₀) + 12.119
# 15          2.420e+01  9.832e-02  y = ((x₀ * ((x₁ * 0.019194) * x₀)) * x₂) + 13.559
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.370e+04
# Progress: 54 / 800 total iterations (6.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.218e+01  7.650e-03  y = x₀ + 19.552
# 6           3.532e+01  8.874e-02  y = (x₀ + 1.5003) / 0.1225
# 8           3.532e+01  2.292e-05  y = ((x₀ * 8.2448) + 11.884) - -0.2583
# 9           2.723e+01  2.602e-01  y = ((x₀ * x₁) * 0.015732) + 12.115
# 12          2.721e+01  1.915e-04  y = ((x₀ * (x₁ * 0.022221)) * x₂) + 12.119
# 14          2.670e+01  9.486e-03  y = (((0.022221 * (x₂ * x₁)) - -0.85418) * x₀) + 12.119
# 15          2.420e+01  9.832e-02  y = ((x₀ * ((x₁ * 0.019194) * x₀)) * x₂) + 13.559
# 17          2.397e+01  4.835e-03  y = x₃ + (((((x₁ * x₀) * 0.19783) ^ 0.5666) + 5.1594) + x₀...
#                                       )
# 19          2.293e+01  2.218e-02  y = (x₃ + (((x₁ * x₀) * 0.01565) + 12.518)) + ((x₀ + -1.09...
#                                       73) * 7.0972)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+04
# Progress: 63 / 800 total iterations (7.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.907e-02  y = (x₀ + 1.5003) / 0.1225
# 8           3.532e+01  2.292e-05  y = ((x₀ * 8.2448) + 11.884) - -0.2583
# 9           2.723e+01  2.602e-01  y = ((x₀ * x₁) * 0.015732) + 12.115
# 12          2.721e+01  1.915e-04  y = ((x₀ * (x₁ * 0.022221)) * x₂) + 12.119
# 14          2.670e+01  9.486e-03  y = (((0.022221 * (x₂ * x₁)) - -0.85418) * x₀) + 12.119
# 15          2.418e+01  9.908e-02  y = (x₀ * ((x₀ + x₀) + (x₁ * 0.019194))) + 8.2219
# 17          2.397e+01  4.456e-03  y = x₃ + (((((x₁ * x₀) * 0.19783) ^ 0.5666) + 5.1594) + x₀...
#                                       )
# 18          2.173e+01  9.785e-02  y = (x₀ * ((x₁ * 0.014468) + (x₀ + (x₀ + x₀)))) + 9.9438
# 20          2.166e+01  1.751e-03  y = (x₀ * (((x₁ * 0.014257) + (x₀ + (x₀ + x₀))) + 0.82702)...
#                                       ) + 9.3002
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.070e+04
# Progress: 73 / 800 total iterations (9.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 9           2.723e+01  8.674e-02  y = ((x₀ * x₁) * 0.015732) + 12.115
# 12          2.721e+01  1.915e-04  y = ((x₀ * (x₁ * 0.022221)) * x₂) + 12.119
# 13          2.591e+01  4.916e-02  y = ((x₀ * ((x₁ * 0.014468) + 1.861)) + 0.82702) + 9.3002
# 15          2.418e+01  3.444e-02  y = (x₀ * ((x₀ + x₀) + (x₁ * 0.019194))) + 8.2219
# 17          2.397e+01  4.456e-03  y = x₃ + (((((x₁ * x₀) * 0.19783) ^ 0.5666) + 5.1594) + x₀...
#                                       )
# 18          2.173e+01  9.785e-02  y = (x₀ * ((x₁ * 0.014468) + (x₀ + (x₀ + x₀)))) + 9.9438
# 20          2.166e+01  1.751e-03  y = (x₀ * (((x₁ * 0.014257) + (x₀ + (x₀ + x₀))) + 0.82702)...
#                                       ) + 9.3002
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.120e+04
# Progress: 107 / 800 total iterations (13.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 9           2.723e+01  8.674e-02  y = ((x₀ * x₁) * 0.015732) + 12.115
# 12          2.721e+01  1.915e-04  y = ((x₀ * (x₁ * 0.022221)) * x₂) + 12.119
# 13          2.532e+01  7.208e-02  y = (x₀ * (((x₁ * 0.014468) + 1.861) + 0.82702)) + 9.3002
# 15          2.418e+01  2.299e-02  y = (x₀ * ((x₀ + x₀) + (x₁ * 0.019194))) + 8.2219
# 16          2.364e+01  2.253e-02  y = ((x₀ * (((x₁ * 0.014468) + 1.861) + 0.82702)) + 9.3002...
#                                       ) + x₀
# 18          2.173e+01  4.212e-02  y = (x₀ * ((x₁ * 0.014468) + (x₀ + (x₀ + x₀)))) + 9.9438
# 20          2.166e+01  1.751e-03  y = (x₀ * (((x₁ * 0.014257) + (x₀ + (x₀ + x₀))) + 0.82702)...
#                                       ) + 9.3002
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.540e+04
# Progress: 135 / 800 total iterations (16.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 9           2.723e+01  8.674e-02  y = ((x₀ * x₁) * 0.015732) + 12.115
# 12          2.609e+01  1.419e-02  y = (x₁ * (0.014468 * x₀)) + (x₀ + 11.541)
# 13          2.532e+01  3.007e-02  y = (x₀ * (((x₁ * 0.014468) + 1.861) + 0.82702)) + 9.3002
# 15          2.399e+01  2.690e-02  y = 9.9438 + (((0.76372 + (0.76372 + 1.6025)) + (x₁ * 0.01...
#                                       4468)) * x₀)
# 16          2.303e+01  4.122e-02  y = 9.9438 + ((0.76372 + (x₀ + (1.6025 + (x₁ * 0.014468)))...
#                                       ) * x₀)
# 17          2.286e+01  7.434e-03  y = (x₀ * (((x₁ * 0.014468) + x₀) + (x₀ + 0.45043))) + 9.9...
#                                       438
# 18          2.173e+01  5.028e-02  y = (x₀ * ((x₁ * 0.014468) + (x₀ + (x₀ + x₀)))) + 9.9438
# 20          2.166e+01  1.751e-03  y = (x₀ * (((x₁ * 0.014257) + (x₀ + (x₀ + x₀))) + 0.82702)...
#                                       ) + 9.3002
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.870e+04
# Progress: 158 / 800 total iterations (19.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.723e+01  7.503e-03  y = ((x₀ * x₁) * 0.015732) + 12.115
# 11          2.690e+01  6.041e-03  y = (x₀ * ((0.014468 * x₁) + 0.35502)) - -12.144
# 12          2.482e+01  8.039e-02  y = (x₀ * ((0.014468 * x₁) + x₀)) - -12.144
# 14          2.394e+01  1.806e-02  y = (x₀ * ((0.014468 * x₁) + (x₀ ^ 1.6381))) - -12.144
# 15          2.264e+01  5.595e-02  y = ((x₀ * x₁) ^ 0.4514) + ((x₀ * x₀) - -3.156)
# 16          1.773e+01  2.447e-01  y = (x₀ * ((x₁ * 0.015177) + ((x₀ ^ 5.7758) + -2.6893))) -...
#                                        -12.389
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.760e+04
# Progress: 191 / 800 total iterations (23.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.490e+01  5.220e-02  y = (x₁ ^ 0.4927) * (x₀ ^ 0.72766)
# 11          2.345e+01  2.996e-02  y = ((x₀ * (x₁ ^ 0.4514)) + 1.1954) - -3.156
# 13          2.296e+01  1.057e-02  y = ((x₀ * (x₁ ^ 0.4514)) + (1.1954 - -3.156)) + 0.54342
# 15          2.081e+01  4.927e-02  y = ((x₀ * x₁) ^ 0.4514) + (x₀ * (x₀ - -3.156))
# 16          1.773e+01  1.603e-01  y = (x₀ * ((x₁ * 0.015177) + ((x₀ ^ 5.7758) + -2.6893))) -...
#                                        -12.389
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.920e+04
# Progress: 227 / 800 total iterations (28.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.490e+01  5.220e-02  y = (x₁ ^ 0.4927) * (x₀ ^ 0.72766)
# 11          2.345e+01  2.996e-02  y = ((x₀ * (x₁ ^ 0.4514)) + 1.1954) - -3.156
# 13          2.257e+01  1.923e-02  y = ((x₀ - -0.063701) * (x₁ ^ 0.4514)) + (1.1954 - -3.156)
# 15          2.081e+01  4.061e-02  y = ((x₀ * x₁) ^ 0.4514) + (x₀ * (x₀ - -3.156))
# 16          1.773e+01  1.603e-01  y = (x₀ * ((x₁ * 0.015177) + ((x₀ ^ 5.7758) + -2.6893))) -...
#                                        -12.389
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.660e+04
# Progress: 243 / 800 total iterations (30.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.490e+01  5.220e-02  y = (x₁ ^ 0.4927) * (x₀ ^ 0.72766)
# 11          2.345e+01  2.996e-02  y = ((x₀ * (x₁ ^ 0.4514)) + 1.1954) - -3.156
# 13          2.257e+01  1.923e-02  y = ((x₀ - -0.063701) * (x₁ ^ 0.4514)) + (1.1954 - -3.156)
# 15          2.081e+01  4.061e-02  y = ((x₀ * x₁) ^ 0.4514) + (x₀ * (x₀ - -3.156))
# 16          1.773e+01  1.603e-01  y = (x₀ * ((x₁ * 0.015177) + ((x₀ ^ 5.7758) + -2.6893))) -...
#                                        -12.389
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.430e+04
# Progress: 258 / 800 total iterations (32.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.245e+01  1.039e-01  y = (x₀ * (x₁ ^ 0.43152)) + 6.7812
# 11          1.695e+01  1.405e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 16          1.692e+01  4.007e-04  y = ((((x₀ ^ 3.456) * x₃) * 4.5307) + (x₁ ^ 0.42684)) - -0...
#                                       .84346
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+04
# Progress: 272 / 800 total iterations (34.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.245e+01  1.039e-01  y = (x₀ * (x₁ ^ 0.43152)) + 6.7812
# 11          1.695e+01  1.405e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 16          1.692e+01  4.007e-04  y = ((((x₀ ^ 3.456) * x₃) * 4.5307) + (x₁ ^ 0.42684)) - -0...
#                                       .84346
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.930e+04
# Progress: 283 / 800 total iterations (35.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.245e+01  1.039e-01  y = (x₀ * (x₁ ^ 0.43152)) + 6.7812
# 11          1.695e+01  1.405e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 16          1.679e+01  1.978e-03  y = ((((x₀ ^ 3.456) * x₃) * 4.5307) + (x₁ ^ 0.42684)) - -0...
#                                       .46309
# 20          1.668e+01  1.559e-03  y = ((((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)) - ((-0.463...
#                                       09 - x₃) + 0.70372)) - 0.63221
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.610e+04
# Progress: 292 / 800 total iterations (36.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.245e+01  1.039e-01  y = (x₀ * (x₁ ^ 0.43152)) + 6.7812
# 11          1.695e+01  1.405e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 16          1.679e+01  1.978e-03  y = ((((x₀ ^ 3.456) * x₃) * 4.5307) + (x₁ ^ 0.42684)) - -0...
#                                       .46309
# 20          1.668e+01  1.559e-03  y = ((((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)) - ((-0.463...
#                                       09 - x₃) + 0.70372)) - 0.63221
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.410e+04
# Progress: 303 / 800 total iterations (37.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.245e+01  1.039e-01  y = (x₀ * (x₁ ^ 0.43152)) + 6.7812
# 11          1.695e+01  1.405e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 13          1.693e+01  6.529e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 15          1.693e+01  1.326e-04  y = ((x₁ + -0.5647) ^ 0.42995) + (((x₀ ^ 3.3245) + -0.0992...
#                                       69) * 4.7532)
# 16          1.679e+01  8.316e-03  y = ((((x₀ ^ 3.456) * x₃) * 4.5307) + (x₁ ^ 0.42684)) - -0...
#                                       .46309
# 18          1.658e+01  6.273e-03  y = (x₁ ^ 0.42684) + ((x₀ ^ 3.456) * ((x₃ * 4.5307) - (0.6...
#                                       5413 / -1.9603)))
# 20          1.656e+01  4.916e-04  y = (x₁ ^ 0.42684) + ((x₀ ^ 3.456) * ((x₃ * 4.5307) - ((0....
#                                       65413 / -1.9603) * 1.4494)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+04
# Progress: 317 / 800 total iterations (39.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.204e+01  1.131e-01  y = (x₁ ^ 0.42684) * (x₀ + 0.42245)
# 11          1.695e+01  1.312e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 13          1.693e+01  6.529e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.630e+04
# Progress: 334 / 800 total iterations (41.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.204e+01  1.131e-01  y = (x₁ ^ 0.42684) * (x₀ + 0.42245)
# 11          1.695e+01  1.312e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 13          1.693e+01  6.529e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 19          1.638e+01  1.850e-03  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (((x₃ + -0.8653) + x...
#                                       ₃) + 3.5588))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.760e+04
# Progress: 348 / 800 total iterations (43.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.204e+01  1.131e-01  y = (x₁ ^ 0.42684) * (x₀ + 0.42245)
# 11          1.695e+01  1.312e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 13          1.693e+01  6.529e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 19          1.638e+01  1.850e-03  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (((x₃ + -0.8653) + x...
#                                       ₃) + 3.5588))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.150e+04
# Progress: 369 / 800 total iterations (46.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.194e+01  1.155e-01  y = (x₁ ^ 0.42684) * (x₀ + 0.42684)
# 11          1.695e+01  1.289e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 13          1.693e+01  6.529e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 19          1.638e+01  1.850e-03  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (((x₃ + -0.8653) + x...
#                                       ₃) + 3.5588))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.410e+04
# Progress: 396 / 800 total iterations (49.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.194e+01  1.155e-01  y = (x₁ ^ 0.42684) * (x₀ + 0.42684)
# 11          1.695e+01  1.289e-01  y = ((x₀ ^ 3.456) * 4.5307) + (x₁ ^ 0.42684)
# 13          1.693e+01  6.529e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 19          1.638e+01  1.850e-03  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (((x₃ + -0.8653) + x...
#                                       ₃) + 3.5588))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.100e+04
# Progress: 424 / 800 total iterations (53.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.194e+01  1.155e-01  y = (x₁ ^ 0.42684) * (x₀ + 0.42684)
# 11          1.695e+01  1.291e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.122e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.050e+04
# Progress: 441 / 800 total iterations (55.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.160e+01  1.234e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42684)
# 11          1.695e+01  1.212e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.122e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.890e+04
# Progress: 454 / 800 total iterations (56.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.156e+01  1.242e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.122e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.830e+04
# Progress: 478 / 800 total iterations (59.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.764e+01  2.452e-01  y = (x₀ * x₁) ^ 0.4927
# 9           2.156e+01  1.242e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.122e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.270e+04
# Progress: 495 / 800 total iterations (61.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.706e+01  2.664e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.122e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.400e+04
# Progress: 512 / 800 total iterations (64.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.532e+01  7.910e-02  y = (x₀ * 8.2436) - -12.144
# 7           2.706e+01  2.664e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.122e-04  y = (x₁ ^ 0.42967) + (((x₀ ^ 3.3233) * 4.7534) + -0.44703)
# 14          1.653e+01  2.388e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+04
# Progress: 517 / 800 total iterations (64.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.325e-04  y = (x₁ ^ 0.43001) + (((x₀ ^ 3.3451) + -0.09752) * 4.7117)
# 14          1.653e+01  2.384e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.320e+04
# Progress: 517 / 800 total iterations (64.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.325e-04  y = (x₁ ^ 0.43001) + (((x₀ ^ 3.3451) + -0.09752) * 4.7117)
# 14          1.653e+01  2.384e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.590e+03
# Progress: 523 / 800 total iterations (65.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.325e-04  y = (x₁ ^ 0.43001) + (((x₀ ^ 3.3451) + -0.09752) * 4.7117)
# 14          1.653e+01  2.384e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.630e+03
# Progress: 533 / 800 total iterations (66.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.325e-04  y = (x₁ ^ 0.43001) + (((x₀ ^ 3.3451) + -0.09752) * 4.7117)
# 14          1.653e+01  2.384e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.210e+04
# Progress: 558 / 800 total iterations (69.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.330e+04
# Progress: 591 / 800 total iterations (73.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.910e+04
# Progress: 614 / 800 total iterations (76.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.200e+04
# Progress: 630 / 800 total iterations (78.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.750e+04
# Progress: 639 / 800 total iterations (79.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# ...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.710e+04
# Progress: 714 / 800 total iterations (89.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.870e+03
# Progress: 718 / 800 total iterations (89.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.620e+03
# Progress: 718 / 800 total iterations (89.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.156e+01  1.136e-01  y = (x₁ ^ 0.42967) * (x₀ + 0.42967)
# 11          1.695e+01  1.204e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.990e+03
# Progress: 720 / 800 total iterations (90.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.040e+03
# Progress: 725 / 800 total iterations (90.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.280e+03
# Progress: 739 / 800 total iterations (92.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.180e+04
# Progress: 755 / 800 total iterations (94.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.760e+04
# Progress: 775 / 800 total iterations (96.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.910e+04
# Progress: 782 / 800 total iterations (97.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.058e-04  y = ((x₀ ^ 3.1906) * ((x₃ * 2.9883) + 2.3771)) + ((x₁ ^ 0....
#                                       43074) + -0.75154)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 1.560e+04
# Progress: 790 / 800 total iterations (98.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.731e-04  y = (((x₀ ^ 3.2564) * (x₃ + 0.77856)) * 2.9182) + ((x₁ ^ 0...
#                                       .43031) + -0.59244)
# 20          1.623e+01  3.923e-04  y = (((x₁ + -1.1872) - 3.4114) ^ 0.42691) + (((x₀ ^ 3.4114...
#                                       ) * (x₃ + 0.73828)) * 2.777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.316e+01  0.000e+00  y = 19.552
# 4           4.138e+01  1.409e-02  y = x₀ + 18.653
# 6           3.274e+01  1.171e-01  y = (x₀ ^ 6.2716) + 16.554
# 7           2.706e+01  1.905e-01  y = (x₀ * x₁) ^ 0.48156
# 9           2.127e+01  1.203e-01  y = (x₁ ^ 0.41417) * (x₀ + 0.58594)
# 11          1.695e+01  1.136e-01  y = (x₁ ^ 0.42722) + ((x₀ ^ 3.4641) * 4.4562)
# 13          1.693e+01  4.417e-04  y = (x₁ ^ 0.43028) + (((x₀ ^ 3.3122) * 4.7786) + -0.52943)
# 14          1.653e+01  2.382e-02  y = (x₁ ^ 0.42797) + ((x₀ ^ 3.5588) * (x₃ + 3.4195))
# 16          1.626e+01  8.293e-03  y = (x₁ ^ 0.42691) + (((x₀ ^ 3.4114) * (x₃ + 0.73828)) * 2...
#                                       .777)
# 18          1.624e+01  6.731e-04  y = (((x₀ ^ 3.2564) * (x₃ + 0.77856)) * 2.9182) + ((x₁ ^ 0...
#                                       .43031) + -0.59244)
# 20          1.623e+01  3.923e-04  y = (((x₁ + -1.1872) - 3.4114) ^ 0.42691) + (((x₀ ^ 3.4114...
#                                       ) * (x₃ + 0.73828)) * 2.777)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250923_170332_KIaE8V\hall_of_fame.csv
# global: 276.3102123737335 s

# %%
# 3b) entrenar laminar 
lam = None
if len(df_lam) > 0:
    X_lam = df_lam[['S', 'Re', 'Pr', 'SoH']].rename(columns={'S': 'Se'})
    y_lam = df_lam['nusselt']
    lam = new_model(); t0=time.time(); lam.fit(X_lam, y_lam); print("laminar:", time.time()-t0,"s")
else:
    print("[aviso] subset laminar vacío; usaré global como fallback.")
# Out:
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 1.610e+04
# Progress: 13 / 800 total iterations (1.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.235e+01  8.379e-03  y = Se + 19.486
# 6           3.904e+01  4.067e-02  y = (-3.3447 / Se) + 23.905
# 9           2.744e+01  1.176e-01  y = (Se * (Re * 0.015764)) + 12.103
# 17          2.616e+01  5.971e-03  y = (Se * 10.145) + (((Se * Re) * (Re * 9.3225e-06)) + 7.2...
#                                       109)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.820e+04
# Progress: 31 / 800 total iterations (3.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.235e+01  8.379e-03  y = Se + 19.486
# 6           3.502e+01  9.508e-02  y = (Se * 10.145) + 10.145
# 8           3.455e+01  6.719e-03  y = ((Se + 3.1695) ^ 2.1213) - 0.33572
# 9           2.744e+01  2.304e-01  y = (Se * (Re * 0.015764)) + 12.103
# 17          2.616e+01  5.971e-03  y = (Se * 10.145) + (((Se * Re) * (Re * 9.3225e-06)) + 7.2...
#                                       109)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.420e+04
# Progress: 54 / 800 total iterations (6.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.502e+01  8.569e-02  y = (Se * 10.145) + 10.145
# 8           3.455e+01  6.719e-03  y = ((Se + 3.1695) ^ 2.1213) - 0.33572
# 9           2.744e+01  2.304e-01  y = (Se * (Re * 0.015764)) + 12.103
# 17          2.616e+01  5.971e-03  y = (Se * 10.145) + (((Se * Re) * (Re * 9.3225e-06)) + 7.2...
#                                       109)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.540e+04
# Progress: 80 / 800 total iterations (10.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.502e+01  8.569e-02  y = (Se * 10.145) + 10.145
# 8           3.455e+01  6.719e-03  y = ((Se + 3.1695) ^ 2.1213) - 0.33572
# 9           2.744e+01  2.304e-01  y = (Se * (Re * 0.015764)) + 12.103
# 11          2.718e+01  4.829e-03  y = (Se * ((Re * 0.015764) + 12.103)) + 1.5275
# 17          2.616e+01  6.352e-03  y = (Se * 10.145) + (((Se * Re) * (Re * 9.3225e-06)) + 7.2...
#                                       109)
# 19          2.594e+01  4.169e-03  y = 10.145 + ((Se * ((Se + (Re * (Re * 9.3225e-06))) + 7.2...
#                                       109)) - 1.1133)
# 20          2.581e+01  5.174e-03  y = ((SoH + 9.292) * (Se + ((Se * (Re * 9.0175e-07)) * Re)...
#                                       )) + 7.2003
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.960e+04
# Progress: 108 / 800 total iterations (13.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.502e+01  8.569e-02  y = (Se * 10.145) + 10.145
# 8           3.455e+01  6.719e-03  y = ((Se + 3.1695) ^ 2.1213) - 0.33572
# 9           2.744e+01  2.304e-01  y = (Se * (Re * 0.015764)) + 12.103
# 11          2.718e+01  4.829e-03  y = (Se * ((Re * 0.015764) + 12.103)) + 1.5275
# 17          2.616e+01  6.352e-03  y = (Se * 10.145) + (((Se * Re) * (Re * 9.3225e-06)) + 7.2...
#                                       109)
# 19          2.594e+01  4.169e-03  y = 10.145 + ((Se * ((Se + (Re * (Re * 9.3225e-06))) + 7.2...
#                                       109)) - 1.1133)
# 20          2.581e+01  5.174e-03  y = ((SoH + 9.292) * (Se + ((Se * (Re * 9.0175e-07)) * Re)...
#                                       )) + 7.2003
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.160e+04
# Progress: 128 / 800 total iterations (16.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.477e+01  8.925e-02  y = (Se * 8.7524) + 11.577
# 8           3.455e+01  3.157e-03  y = ((Se + 3.1695) ^ 2.1213) - 0.33572
# 9           2.744e+01  2.304e-01  y = (Se * (Re * 0.015764)) + 12.103
# 11          2.718e+01  4.829e-03  y = (Se * ((Re * 0.015764) + 12.103)) + 1.5275
# 12          2.632e+01  3.194e-02  y = ((12.103 + Se) * Se) + (Re * 0.015764)
# 13          2.602e+01  1.133e-02  y = 12.103 + ((Se * (1.117 + (Re * 0.015764))) - 1.117)
# 14          2.414e+01  7.535e-02  y = (((12.103 + Se) * Se) + (Re * 0.015764)) - 1.1306
# 17          2.412e+01  1.536e-04  y = (12.103 + (Se * ((SoH + Se) + (Re * 0.015764)))) - 1.1...
#                                       306
# 19          2.094e+01  7.073e-02  y = (Se * 14.094) + ((((Se * Re) * -5.4289e-06) + 0.015009...
#                                       ) * (Re + -0.099187))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.130e+04
# Progress: 154 / 800 total iterations (19.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.477e+01  8.925e-02  y = (Se * 8.7524) + 11.577
# 8           3.455e+01  3.157e-03  y = ((Se + 3.1695) ^ 2.1213) - 0.33572
# 9           2.601e+01  2.838e-01  y = (Se * 12.103) + (Re * 0.015764)
# 11          2.583e+01  3.575e-03  y = (Se * 12.103) + ((Re * 0.015764) + -1.0138)
# 13          2.551e+01  6.250e-03  y = (Se * 12.103) + (Re * (0.015764 * (1.5275 ^ -0.040259)...
#                                       ))
# 14          2.414e+01  5.522e-02  y = (((12.103 + Se) * Se) + (Re * 0.015764)) - 1.1306
# 17          2.300e+01  1.613e-02  y = ((((12.103 + Se) * Se) + (0.015764 * Re)) / 1.1306) + ...
#                                       SoH
# 19          2.094e+01  4.676e-02  y = (Se * 14.094) + ((((Se * Re) * -5.4289e-06) + 0.015009...
#                                       ) * (Re + -0.099187))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.290e+04
# Progress: 178 / 800 total iterations (22.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.477e+01  8.925e-02  y = (Se * 8.7524) + 11.577
# 8           3.455e+01  3.157e-03  y = ((Se + 3.1695) ^ 2.1213) - 0.33572
# 9           2.601e+01  2.838e-01  y = (Se * 12.103) + (Re * 0.015764)
# 11          2.583e+01  3.575e-03  y = (Se * 12.103) + ((Re * 0.015764) + -1.0138)
# 13          2.397e+01  3.727e-02  y = (12.103 * Se) + ((0.29023 ^ 0.15781) * (Re * 0.015764)...
#                                       )
# 14          2.339e+01  2.461e-02  y = (Se * 12.103) + ((Se ^ 0.15781) * (Re * 0.015764))
# 15          2.232e+01  4.673e-02  y = ((Se * 12.103) + (Re * ((0.14588 ^ 0.15781) * 0.015764...
#                                       ))) - -1.7431
# 16          2.190e+01  1.920e-02  y = (Se * (12.103 + Se)) + ((0.15781 ^ 0.14588) * (Re * 0....
#                                       015764))
# 19          2.094e+01  1.485e-02  y = (Se * 14.094) + ((((Se * Re) * -5.4289e-06) + 0.015009...
#                                       ) * (Re + -0.099187))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.360e+04
# Progress: 209 / 800 total iterations (26.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.477e+01  8.925e-02  y = (Se * 8.7524) + 11.577
# 8           3.441e+01  5.188e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.70731
# 9           2.601e+01  2.797e-01  y = (Se * 12.103) + (Re * 0.015764)
# 11          2.568e+01  6.465e-03  y = (Se * 12.103) + ((Re * 0.015764) + -0.44419)
# 13          2.234e+01  6.966e-02  y = (Se * 12.103) + ((Re ^ 0.43796) / (0.15781 - -1.5623))
# 15          2.230e+01  8.283e-04  y = ((Se * 12.103) + ((Re ^ 0.43796) / (0.15781 - -1.5623)...
#                                       )) + -0.043625
# 16          2.190e+01  1.833e-02  y = (Se * (12.103 + Se)) + ((0.15781 ^ 0.14588) * (Re * 0....
#                                       015764))
# 18          2.168e+01  4.899e-03  y = ((Se * (12.103 + Se)) + ((0.15781 ^ 0.14588) * (Re * 0...
#                                       .015764))) - -0.20347
# 19          2.092e+01  3.572e-02  y = (Se * 14.094) + (((((Se * Re) * -5.4289e-06) + 0.01500...
#                                       9) * Re) + -0.099187)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.640e+04
# Progress: 238 / 800 total iterations (29.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.477e+01  8.925e-02  y = (Se * 8.7524) + 11.577
# 8           3.441e+01  5.188e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.70731
# 9           2.601e+01  2.797e-01  y = (Se * 12.103) + (Re * 0.015764)
# 11          2.568e+01  6.465e-03  y = (Se * 12.103) + ((Re * 0.015764) + -0.44419)
# 13          2.234e+01  6.966e-02  y = (Se * 12.103) + ((Re ^ 0.43796) / (0.15781 - -1.5623))
# 15          2.177e+01  1.279e-02  y = (Se * 14.094) + (-5.4289e-06 + (0.015009 * ((Re * 0.74...
#                                       201) + -0.099187)))
# 17          2.173e+01  1.097e-03  y = ((Se * 14.094) + ((-5.4289e-06 + 0.015009) * ((Re * 0....
#                                       74201) + -0.099187))) - -0.46398
# 18          2.168e+01  2.016e-03  y = ((Se * (12.103 + Se)) + ((0.15781 ^ 0.14588) * (Re * 0...
#                                       .015764))) - -0.20347
# 19          2.092e+01  3.572e-02  y = (Se * 14.094) + (((((Se * Re) * -5.4289e-06) + 0.01500...
#                                       9) * Re) + -0.099187)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.370e+04
# Progress: 257 / 800 total iterations (32.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.477e+01  8.925e-02  y = (Se * 8.7524) + 11.577
# 8           3.441e+01  5.188e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.70731
# 9           2.199e+01  4.479e-01  y = (Se * (Re ^ 0.43155)) + 6.6742
# 15          2.072e+01  9.894e-03  y = (Re ^ 0.39846) + (((Se - 0.21949) * 12.103) - (0.47586...
#                                        / 0.47586))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.920e+04
# Progress: 269 / 800 total iterations (33.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.880e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.70731
# 9           2.199e+01  4.479e-01  y = (Se * (Re ^ 0.43155)) + 6.6742
# 15          2.072e+01  9.894e-03  y = (Re ^ 0.39846) + (((Se - 0.21949) * 12.103) - (0.47586...
#                                        / 0.47586))
# 17          2.048e+01  5.783e-03  y = (((Re ^ 0.39846) * Se) - ((-1.0642 + -1.0642) / Se)) /...
#                                        Pr
# 19          1.969e+01  1.966e-02  y = (((0.95186 + (Re ^ 0.39846)) * Se) - ((-1.0642 + -1.06...
#                                       42) / Se)) / Pr
# 20          1.919e+01  2.567e-02  y = (SoH + ((Se * (Re ^ 0.41415)) - ((-2.3548 / Se) + 1.70...
#                                       81))) / Pr
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.210e+04
# Progress: 273 / 800 total iterations (34.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.880e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.70731
# 9           2.199e+01  4.479e-01  y = (Se * (Re ^ 0.43155)) + 6.6742
# 11          2.140e+01  1.361e-02  y = (Re ^ 0.39846) + ((Se - 0.21949) * 12.103)
# 13          2.070e+01  1.656e-02  y = (12.103 * (Se - 0.21949)) + ((Re ^ 0.39846) - 0.76203)
# 16          1.894e+01  2.956e-02  y = (((Se * 14.546) - 5.2861) + (Re ^ 0.43259)) - (2.7154 ...
#                                       / SoH)
# 18          1.875e+01  5.108e-03  y = (((Se - 0.50882) * 11.941) + ((Re ^ 0.41333) - (1.6042...
#                                        / SoH))) * 1.217
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.920e+04
# Progress: 297 / 800 total iterations (37.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.880e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.70731
# 9           2.199e+01  4.479e-01  y = (Se * (Re ^ 0.43203)) - -6.6359
# 11          2.138e+01  1.398e-02  y = ((Se * 12.496) + (Re ^ 0.39846)) - 2.9943
# 13          1.944e+01  4.765e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 16          1.894e+01  8.572e-03  y = (((Se * 14.546) - 5.2861) + (Re ^ 0.43259)) - (2.7154 ...
#                                       / SoH)
# 18          1.875e+01  5.108e-03  y = (((Se - 0.50882) * 11.941) + ((Re ^ 0.41333) - (1.6042...
#                                        / SoH))) * 1.217
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.060e+04
# Progress: 318 / 800 total iterations (39.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.199e+01  4.479e-01  y = (Se * (Re ^ 0.43203)) - -6.6359
# 11          2.138e+01  1.398e-02  y = ((Se * 12.496) + (Re ^ 0.39846)) - 2.9943
# 13          1.944e+01  4.765e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 16          1.894e+01  8.572e-03  y = (((Se * 14.546) - 5.2861) + (Re ^ 0.43259)) - (2.7154 ...
#                                       / SoH)
# 18          1.875e+01  5.108e-03  y = (((Se - 0.50882) * 11.941) + ((Re ^ 0.41333) - (1.6042...
#                                        / SoH))) * 1.217
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.550e+04
# Progress: 346 / 800 total iterations (43.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.199e+01  4.479e-01  y = (Se * (Re ^ 0.43203)) - -6.6359
# 11          1.994e+01  4.881e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.943e+01  1.217e-04  y = (((Se * 14.427) + (Re ^ 0.43617)) - 9.5597) + Pr
# 16          1.769e+01  4.708e-02  y = (((Re + 0.81894) ^ 0.43056) - (Se / (-0.12861 / Se))) ...
#                                       - 2.5638
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.900e+04
# Progress: 363 / 800 total iterations (45.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.199e+01  4.479e-01  y = (Se * (Re ^ 0.43203)) - -6.6359
# 11          1.994e+01  4.881e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.852e-02  y = (Re ^ 0.4362) + (((Se * 8.1597) * Se) + -3.3959)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.800e+04
# Progress: 382 / 800 total iterations (47.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.166e+01  4.629e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.852e-02  y = (Re ^ 0.4362) + (((Se * 8.1597) * Se) + -3.3959)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.440e+04
# Progress: 394 / 800 total iterations (49.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.166e+01  4.629e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.310e+04
# Progress: 417 / 800 total iterations (52.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.166e+01  4.629e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.230e+04
# Progress: 431 / 800 total iterations (53.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.166e+01  4.629e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.040e+04
# Progress: 444 / 800 total iterations (55.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.166e+01  4.629e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 20          1.723e+01  2.107e-03  y = ((Re ^ 0.43648) + ((Se * (Se * 8.1602)) + -4.3227)) + ...
#                                       (SoH * SoH)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.330e+04
# Progress: 463 / 800 total iterations (57.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.475e+01  8.956e-02  y = (Se + 3.1695) ^ 2.1241
# 8           3.441e+01  4.903e-03  y = ((Se + 3.1695) ^ 2.0812) - -0.75276
# 9           2.166e+01  4.629e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 20          1.723e+01  2.107e-03  y = ((Re ^ 0.43648) + ((Se * (Se * 8.1602)) + -4.3227)) + ...
#                                       (SoH * SoH)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.200e+04
# Progress: 483 / 800 total iterations (60.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.170e+04
# Progress: 498 / 800 total iterations (62.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.660e+04
# Progress: 526 / 800 total iterations (65.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.994e+01  4.129e-02  y = (Se * 14.427) + ((Re ^ 0.43617) - 9.5597)
# 13          1.944e+01  1.282e-02  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.730e+04
# Progress: 548 / 800 total iterations (68.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+04
# Progress: 564 / 800 total iterations (70.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 17          1.734e+01  5.241e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.460e+04
# Progress: 574 / 800 total iterations (71.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.780e+04
# Progress: 580 / 800 total iterations (72.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.580e+04
# Progress: 596 / 800 total iterations (74.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.790e+04
# Progress: 622 / 800 total iterations (77.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.240e+04
# Progress: 645 / 800 total iterations (80.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.630e+04
# Progress: 665 / 800 total iterations (83.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.990e+04
# Progress: 686 / 800 total iterations (85.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = ((Re ^ 0.43862) + (((Se * 10.641) * (Se + -0.43364)) +...
#                                        -2.6023)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.700e+04
# Progress: 705 / 800 total iterations (88.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.947e+01  5.329e-02  y = (Re ^ 0.4318) + ((Se * 14.337) - 8.4111)
# 13          1.944e+01  8.199e-04  y = (((Se * 14.419) - 2.3401) + (Re ^ 0.43609)) - 6.4942
# 14          1.761e+01  9.857e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.755e+01  1.841e-03  y = (((Se * (Se - 0.14834)) * 8.9435) + (Re ^ 0.44069)) - ...
#                                       3.4835
# 17          1.734e+01  1.204e-02  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.707e+01  7.822e-03  y = (SoH + (10.641 * (Se * (-0.43364 + Se)))) + ((Re ^ 0.4...
#                                       3862) + -2.6023)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.310e+04
# Progress: 713 / 800 total iterations (89.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.944e+01  5.412e-02  y = (Se * 14.445) + ((Re ^ 0.43628) + -8.87)
# 12          1.834e+01  5.806e-02  y = ((Se * 7.0905) * Se) + (Re ^ 0.4117)
# 14          1.761e+01  2.025e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.746e+01  4.390e-03  y = ((Re ^ 0.43862) + ((Se * (Se + -0.37587)) * 10.641)) +...
#                                        -2.5842
# 17          1.734e+01  6.943e-03  y = (Re ^ 0.43648) + ((((Se * Se) * 8.1602) + -4.3227) + S...
#                                       oH)
# 19          1.694e+01  1.170e-02  y = SoH + ((((Se * 12.494) * (Se + -0.65377)) + -0.71925) ...
#                                       + (Re ^ 0.4333))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.080e+04
# Progress: 727 / 800 total iterations (90.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 9           2.166e+01  1.271e-01  y = (Se + 0.53096) * (Re ^ 0.41601)
# 11          1.944e+01  5.412e-02  y = (Se * 14.445) + ((Re ^ 0.43628) + -8.87)
# 12          1.834e+01  5.806e-02  y = ((Se * 7.0905) * Se) + (Re ^ 0.4117)
# 14          1.761e+01  2.025e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.726e+01  1.007e-02  y = ((Se * 12.494) * (Se + -0.65377)) + ((-0.096845 + Re) ...
#                                       ^ 0.4333)
# 17          1.699e+01  1.596e-02  y = SoH + (((Se * 12.494) * (Se + -0.71925)) + (Re ^ 0.433...
#                                       3))
# 19          1.694e+01  1.514e-03  y = SoH + ((((Se * 12.494) * (Se + -0.65377)) + -0.71925) ...
#                                       + (Re ^ 0.4333))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 1.890e+04
# Progress: 741 / 800 total iterations (92.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 7           2.922e+01  8.171e-02  y = (Re * Se) ^ 0.4734
# 9           2.157e+01  1.518e-01  y = (Se + 0.59815) * (Re ^ 0.41601)
# 11          1.944e+01  5.208e-02  y = (Se * 14.445) + ((Re ^ 0.43628) + -8.87)
# 12          1.834e+01  5.806e-02  y = ((Se * 7.0905) * Se) + (Re ^ 0.4117)
# 14          1.761e+01  2.025e-02  y = ((Re ^ 0.43705) + (Se * (Se * 8.1682))) + -3.4975
# 16          1.726e+01  1.007e-02  y = ((Se * 12.494) * (Se + -0.65377)) + ((-0.096845 + Re) ...
#                                       ^ 0.4333)
# 17          1.699e+01  1.596e-02  y = SoH + (((Se * 12.494) * (Se + -0.71925)) + (Re ^ 0.433...
#                                       3))
# 19          1.694e+01  1.514e-03  y = SoH + ((((Se * 12.494) * (Se + -0.65377)) + -0.71925) ...
#                                       + (Re ^ 0.4333))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.470e+04
# Progress: 751 / 800 total iterations (93.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 7           2.706e+01  1.584e-01  y = (Se * Re) ^ 0.48366
# 9           2.157e+01  1.134e-01  y = (Se + 0.59815) * (Re ^ 0.41601)
# 11          1.944e+01  5.208e-02  y = (Se * 14.445) + ((Re ^ 0.43628) + -8.87)
# 12          1.834e+01  5.806e-02  y = ((Se * 7.0905) * Se) + (Re ^ 0.4117)
# 14          1.726e+01  3.032e-02  y = ((Se * 12.494) * (Se + -0.65377)) + (Re ^ 0.4333)
# 16          1.726e+01  -0.000e+00  y = ((Se * 12.494) * (Se + -0.65377)) + ((-0.096845 + Re)...
#                                         ^ 0.4333)
# 17          1.699e+01  1.596e-02  y = SoH + (((Se * 12.494) * (Se + -0.71925)) + (Re ^ 0.433...
#                                       3))
# 19          1.694e+01  1.514e-03  y = SoH + ((((Se * 12.494) * (Se + -0.65377)) + -0.71925) ...
#                                       + (Re ^ 0.4333))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.570e+04
# Progress: 762 / 800 total iterations (95.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 7           2.706e+01  1.584e-01  y = (Se * Re) ^ 0.48366
# 9           2.157e+01  1.134e-01  y = (Se + 0.59815) * (Re ^ 0.41601)
# 11          1.944e+01  5.208e-02  y = (Se * 14.445) + ((Re ^ 0.43628) + -8.87)
# 12          1.834e+01  5.806e-02  y = ((Se * 7.0905) * Se) + (Re ^ 0.4117)
# 14          1.726e+01  3.032e-02  y = ((Se * 12.494) * (Se + -0.65377)) + (Re ^ 0.4333)
# 16          1.721e+01  1.484e-03  y = ((Re ^ 0.4333) + ((Se * 12.494) * (Se + -0.65377))) + ...
#                                       0.26893
# 17          1.695e+01  1.528e-02  y = (Se * ((12.494 * (Se + -0.71925)) + SoH)) + (Re ^ 0.43...
#                                       33)
# 19          1.692e+01  7.020e-04  y = ((Se * ((12.494 * (Se + -0.71925)) + SoH)) + (Re ^ 0.4...
#                                       333)) + 0.1149
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.020e+04
# Progress: 790 / 800 total iterations (98.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 7           2.706e+01  1.584e-01  y = (Se * Re) ^ 0.48366
# 9           2.142e+01  1.169e-01  y = (Se + 0.59815) * (Re ^ 0.4117)
# 11          1.944e+01  4.861e-02  y = (Se * 14.445) + ((Re ^ 0.43628) + -8.87)
# 12          1.834e+01  5.806e-02  y = ((Se * 7.0905) * Se) + (Re ^ 0.4117)
# 14          1.726e+01  3.032e-02  y = ((Se * 12.494) * (Se + -0.65377)) + (Re ^ 0.4333)
# 16          1.721e+01  1.484e-03  y = ((Re ^ 0.4333) + ((Se * 12.494) * (Se + -0.65377))) + ...
#                                       0.26893
# 17          1.695e+01  1.528e-02  y = (Se * ((12.494 * (Se + -0.71925)) + SoH)) + (Re ^ 0.43...
#                                       33)
# 19          1.692e+01  7.020e-04  y = ((Se * ((12.494 * (Se + -0.71925)) + SoH)) + (Re ^ 0.4...
#                                       333)) + 0.1149
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.343e+01  0.000e+00  y = 19.504
# 4           4.156e+01  1.464e-02  y = Se + 18.598
# 6           3.171e+01  1.354e-01  y = (Se ^ 6.506) - -17.243
# 7           2.706e+01  1.584e-01  y = (Se * Re) ^ 0.48366
# 9           2.142e+01  1.169e-01  y = (Se + 0.59815) * (Re ^ 0.4117)
# 11          1.944e+01  4.861e-02  y = (Se * 14.445) + ((Re ^ 0.43628) + -8.87)
# 12          1.834e+01  5.806e-02  y = ((Se * 7.0905) * Se) + (Re ^ 0.4117)
# 14          1.726e+01  3.032e-02  y = ((Se * 12.494) * (Se + -0.65377)) + (Re ^ 0.4333)
# 16          1.721e+01  1.484e-03  y = ((Re ^ 0.4333) + ((Se * 12.494) * (Se + -0.65377))) + ...
#                                       0.26893
# 17          1.695e+01  1.528e-02  y = (Se * ((12.494 * (Se + -0.71925)) + SoH)) + (Re ^ 0.43...
#                                       33)
# 19          1.692e+01  7.643e-04  y = ((Se * ((12.494 * (Se + -0.71925)) + SoH)) + (Re ^ 0.4...
#                                       333)) + 0.15618
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# laminar: 214.93181014060974 s
#   - outputs\20250923_172624_XTjE6s\hall_of_fame.csv

# %%
# 3c) entrenar turbulento 
tur = None
if len(df_tur) > 0:
    X_tur = df_tur[['S', 'Re', 'Pr', 'SoH']].rename(columns={'S': 'Se'})
    y_tur = df_tur['nusselt']
    tur = new_model(); t0=time.time(); tur.fit(X_tur, y_tur); print("turbulento:", time.time()-t0,"s")
else:
    print("[aviso] subset turbulento vacío; usaré global como fallback.")
# Out:
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 5.350e+05
# Progress: 454 / 800 total iterations (56.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.165e+00  0.000e+00  y = 24.734
# 4           1.009e+00  4.789e-02  y = Re ^ 0.41492
# 6           9.727e-01  1.823e-02  y = 10.874 - (Re * -0.0059858)
# 9           9.491e-01  8.186e-03  y = 7.8524 - ((Re * -0.0068851) - SoH)
# 11          9.282e-01  1.112e-02  y = (8.345 - (Re * -0.0075166)) - (0.92631 / SoH)
# 15          9.248e-01  9.189e-04  y = (9.0253 - (Re * -0.0071424)) - ((0.326 / (SoH / 2.1166...
#                                       )) - -0.071573)
# 17          9.244e-01  1.847e-04  y = (8.1226 - (Re * -0.0074206)) - (-0.25973 - (-1.4691 / ...
#                                       ((SoH / 4.2359) / 0.11934)))
# 19          9.172e-01  3.952e-03  y = ((8.859 - (Re * -0.0074536)) - (Pr / SoH)) - (-0.41308...
#                                        / (SoH - 1.6607))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.165e+00  0.000e+00  y = 24.734
# 4           9.864e-01  5.536e-02  y = Re ^ 0.41429
# 6           9.727e-01  7.023e-03  y = 10.874 - (Re * -0.0059858)
# 8           7.901e-01  1.039e-01  y = (1398.1 - (1978.2 / Pr)) + 1417.8
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250923_172959_AR8BTH\hall_of_fame.csv
# turbulento: 8.401222467422485 s

# %%
# 4) evaluar en test (piecewise vs global)
def predict_piecewise(d):
    re = d["Re"].to_numpy()
    X  = d[FEATURES].to_numpy()
    yhat = np.empty(len(d))
    mask_l = re < (UMBRAL-BANDA)
    mask_t = re > (UMBRAL+BANDA)
    mask_m = ~(mask_l | mask_t)
    yhat[mask_l] = (lam or mid).predict(X[mask_l])
    yhat[mask_t] = (tur or mid).predict(X[mask_t])
    yhat[mask_m] = mid.predict(X[mask_m])  # zona transición
    return yhat

X_te, y_te = df_n_test[FEATURES].to_numpy(), df_n_test[TARGET].to_numpy()
yhat_mid   = mid.predict(X_te)
yhat_piece = predict_piecewise(df_n_test)

print("TEST global  : MSE=%.4f R2=%.4f"%(mean_squared_error(y_te,yhat_mid),   r2_score(y_te,yhat_mid)))
print("TEST piecewise: MSE=%.4f R2=%.4f"%(mean_squared_error(y_te,yhat_piece), r2_score(y_te,yhat_piece)))
# Out:
# TEST global  : MSE=19.0839 R2=0.5059
# TEST piecewise: MSE=19.0652 R2=0.5064

# %%
from sklearn.metrics import mean_squared_error

def eval_equations(x, y, equations):
    """
    Evalúa una lista de expresiones matemáticas contra los datos y calcula el MSE para cada una.

    :param x: dataframe con las variables
    :param y: variable objetivo
    :param equations: dataframe/lista con las expresiones obtenidas
    :return: lista de tuplas (expresión, MSE) ordenadas de menor a mayor MSE.
    """
    resultados = []

    for eq in equations:
        try:
            float(eq)
            resultados.append(np.inf)
        except ValueError:
            y_pred = eval(eq, {"__builtins__": {}, "np": np}, x.to_dict(orient='series'))
            mse = mean_squared_error(y, y_pred)
            resultados.append(mse)

    return pd.DataFrame({'expresiones': equations, 'mse': resultados})

# %%
x_val = pd.read_csv(r'.\DATA_LIB_Degradation\df_n_val_des.txt')
y_val = x_val['nusselt']
x_val = x_val.drop('nusselt', axis=1)
x_val
# Out:
#               S          Re        Pr     SoH
# 0      1.038156  745.465433  0.710556  0.8181
# 1      1.038156  745.465433  0.710200  0.8181
# 2      1.038156  692.028356  0.709984  1.0000
# 3      1.038156  680.067627  0.709899  1.0000
# 4      1.038156  655.436666  0.709738  1.0000
# ...         ...         ...       ...     ...
# 15728  0.911669  818.127652  0.706280  1.0000
# 15729  0.911669  751.097192  0.706263  1.0000
# 15730  0.911669  747.250023  0.706245  1.0000
# 15731  0.911669  711.906739  0.706225  0.4545
# 15732  0.911669  699.304370  0.706180  0.4545
#
# [15733 rows x 4 columns]

# %%
x_train = pd.read_csv(r'.\DATA_LIB_Degradation\df_n_train_des.txt')
y_train = x_train['nusselt']
x_train = x_train.drop('nusselt', axis=1)
print('x_train:')
display(x_train.head())
print('y_train:', y_train.to_numpy()[: 5])
# Out:
# x_train:
#           S          Re        Pr     SoH
# 0  0.280625  212.041256  0.709840  0.6363
# 1  0.280625  212.041256  0.707471  1.0000
# 2  0.280625  197.894331  0.706170  1.0000
# 3  0.344410  188.969448  0.708576  0.6363
# 4  0.344410  188.969448  0.704657  1.0000
# y_train: [12.63272114 13.64363625 14.81134875 11.75386263 12.61276223]

# %%
x_val = pd.read_csv(r'.\DATA_LIB_Degradation\df_n_val_des.txt')
y_val = x_val['nusselt']
x_val = x_val.drop('nusselt', axis=1)
x_val
# Out:
#               S          Re        Pr     SoH
# 0      1.038156  745.465433  0.710556  0.8181
# 1      1.038156  745.465433  0.710200  0.8181
# 2      1.038156  692.028356  0.709984  1.0000
# 3      1.038156  680.067627  0.709899  1.0000
# 4      1.038156  655.436666  0.709738  1.0000
# ...         ...         ...       ...     ...
# 15728  0.911669  818.127652  0.706280  1.0000
# 15729  0.911669  751.097192  0.706263  1.0000
# 15730  0.911669  747.250023  0.706245  1.0000
# 15731  0.911669  711.906739  0.706225  0.4545
# 15732  0.911669  699.304370  0.706180  0.4545
#
# [15733 rows x 4 columns]

# %%
def get_general_metrics(y_pred, y_true):
    """
    Calcula las métricas de error RMSE, MAE y SMAPE, junto con su desviación estándar.
    :param y_pred: Arreglo con los valores predichos por la ecuación obtenida.
    :param y_true: Arreglo con los valores reales de la variable.
    :return: Retorna un diccionario, donde los values son una tupla con el valor de la métrica
             y la desviación estándar; y las keys son los strings de las métricas calculadas
             i.e. 'RMSE', 'MAE, 'SMAPE'.
    """

    # Cálculo de errores
    errores_rmse = (y_true - y_pred) ** 2
    errores_mae = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2 + 1e-6
    errores_smape = (np.abs(y_true - y_pred) / denominator) * 100

    # Cálculo de métricas
    rmse = np.round(np.sqrt(np.mean(errores_rmse)), 2)
    mae = np.round(np.mean(errores_mae), 2)
    smape = np.round(np.mean(errores_smape), 2)

    # Cálculo de desviaciones estándar
    std_rmse = np.round(np.std(np.sqrt(errores_rmse)), 2)
    std_mae = np.round(np.std(errores_mae), 2)
    std_smape = np.round(np.std(errores_smape), 2)

    # Retorna un diccionario con las métricas y sus desviaciones estándar
    return {
        "RMSE": (float(rmse), float(std_rmse)),
        "MAE": (float(mae), float(std_mae)),
        "SMAPE": (float(smape), float(std_smape))
    }

# %%
equations = tur.equations_['equation']
equations = equations.apply(lambda x: x.replace('^', '**'))
print('=== TRAIN ===')
df_train = eval_equations(x_train[x_train['Re'] > 2000], y_train[x_train['Re'] > 2000], equations).sort_values(by='mse')
display(df_train)

print('\n=== VALIDATION ===')
x_val.rename(columns={'S': 'Se'}, inplace=True)
df_val = eval_equations(x_val[x_val['Re'] > 2000], y_val[x_val['Re'] > 2000], equations).sort_values(by='mse')
display(df_val)
# Out:
# === TRAIN ===
#                                  expresiones        mse
# 1                           Re ** 0.41429377  19.442458
# 2             10.87422 - (Re * -0.005985785)  19.896500
# 3  (1398.0946 - (1978.191 / Pr)) + 1417.8433  36.794705
# 0                                  24.733618        inf
# === VALIDATION ===
#                                  expresiones        mse
# 2             10.87422 - (Re * -0.005985785)   1.400312
# 1                           Re ** 0.41429377   1.780165
# 3  (1398.0946 - (1978.191 / Pr)) + 1417.8433  43.689675
# 0                                  24.733618        inf

# %%
import sympy as sp

expr1 = sp.sympify(
    df_val['expresiones'].iloc[0]
).evalf(4)
expr1
# Out:
# 0.005986*Re + 10.87

# %%
equations = lam.equations_['equation']
equations = equations.apply(lambda x: x.replace('^', '**'))
print('=== TRAIN ===')
x_train.rename(columns={'S': 'Se'}, inplace=True)
df_train = eval_equations(x_train[x_train['Re'] <= 2000], y_train[x_train['Re'] <= 2000], equations).sort_values(by='mse')
display(df_train)

print('\n=== VALIDATION ===')
x_val.rename(columns={'S': 'Se'}, inplace=True)
df_val = eval_equations(x_val[x_val['Re'] <= 2000], y_val[x_val['Re'] <= 2000], equations).sort_values(by='mse')
display(df_val)
# Out:
# === TRAIN ===
#                                           expresiones        mse
# 10  ((Se * ((12.493999 * (Se + -0.71925366)) + SoH...  19.490198
# 9   (Se * ((12.493999 * (Se + -0.71925366)) + SoH)...  19.578057
# 8   ((Re ** 0.43329948) + ((Se * 12.493999) * (Se ...  19.791675
# 7   ((Se * 12.493999) * (Se + -0.6537722)) + (Re *...  19.941982
# 6          ((Se * 7.090499) * Se) + (Re ** 0.4116961)  20.835204
# 5   (Se * 14.444939) + ((Re ** 0.43628022) + -8.86...  22.089456
# 4                (Se + 0.5981525) * (Re ** 0.4116961)  24.286113
# 3                             (Se * Re) ** 0.48366335  29.963487
# 2                        (Se ** 6.505971) - -17.24254  34.378003
# 1                                      Se + 18.598368  43.971024
# 0                                           19.504103        inf
# === VALIDATION ===
#                                           expresiones        mse
# 9   (Se * ((12.493999 * (Se + -0.71925366)) + SoH)...  14.634424
# 10  ((Se * ((12.493999 * (Se + -0.71925366)) + SoH...  14.673357
# 7   ((Se * 12.493999) * (Se + -0.6537722)) + (Re *...  14.896834
# 8   ((Re ** 0.43329948) + ((Se * 12.493999) * (Se ...  14.951237
# 6          ((Se * 7.090499) * Se) + (Re ** 0.4116961)  16.045392
# 5   (Se * 14.444939) + ((Re ** 0.43628022) + -8.86...  16.994343
# 4                (Se + 0.5981525) * (Re ** 0.4116961)  18.780361
# 3                             (Se * Re) ** 0.48366335  24.323196
# 2                        (Se ** 6.505971) - -17.24254  29.528132
# 1                                      Se + 18.598368  39.193786
# 0                                           19.504103        inf

# %%
import sympy as sp

expr2 = sp.sympify(
    df_val['expresiones'].iloc[0]
).evalf(4)
expr2
# Out:
# Re**0.4333 + Se*(12.49*Se + SoH - 8.986)

# %%
x_test = pd.read_csv(r'.\DATA_LIB_Degradation\df_n_test_des.txt')
y_true = x_test['nusselt']
x_test = x_test.drop('nusselt', axis=1)
print('x_test:')
display(x_train.head())
print('y_test:', y_true.to_numpy()[: 5])

f1 = sp.lambdify(sp.symbols('Re SoH Se Pr'), expr2, 'numpy')
f2 = sp.lambdify(sp.symbols('Re SoH Se Pr'), expr1, 'numpy')
y_pred1 = f1(x_test['Re'].to_numpy()[x_test['Re'] <= 2000],
           x_test['SoH'].to_numpy()[x_test['Re'] <= 2000],
           x_test['S'].to_numpy()[x_test['Re'] <= 2000],
           x_test['Pr'].to_numpy()[x_test['Re'] <= 2000])
y_pred2 = f2(x_test['Re'].to_numpy()[x_test['Re'] > 2000],
           x_test['SoH'].to_numpy()[x_test['Re'] > 2000],
           x_test['S'].to_numpy()[x_test['Re'] > 2000],
           x_test['Pr'].to_numpy()[x_test['Re'] > 2000])

print('n_pred =', len(y_pred1) + len(y_pred2), '/ n_true =', len(y_true))
print()

results = get_general_metrics(np.concatenate([y_pred1, y_pred2]), np.concatenate([
    y_true[x_test['Re'] <= 2000], y_true[x_test['Re'] > 2000]
]))
for key, value in results.items():
    print(key, '=', value[0], '+/-', value[1])
# Out:
# x_test:
#          Se          Re        Pr     SoH
# 0  0.280625  212.041256  0.709840  0.6363
# 1  0.280625  212.041256  0.707471  1.0000
# 2  0.280625  197.894331  0.706170  1.0000
# 3  0.344410  188.969448  0.708576  0.6363
# 4  0.344410  188.969448  0.704657  1.0000
# y_test: [12.65606225 13.78598212 14.02560596 13.66040888 13.68752691]
# n_pred = 15731 / n_true = 15731
#
# RMSE = 3.81 +/- 2.64
# MAE = 2.75 +/- 2.64
# SMAPE = 14.05 +/- 13.19

# %%
y_pred1 = f1(x_val['Re'].to_numpy()[x_val['Re'] <= 2000],
           x_val['SoH'].to_numpy()[x_val['Re'] <= 2000],
           x_val['Se'].to_numpy()[x_val['Re'] <= 2000],
           x_val['Pr'].to_numpy()[x_val['Re'] <= 2000])
y_pred2 = f2(x_val['Re'].to_numpy()[x_val['Re'] > 2000],
           x_val['SoH'].to_numpy()[x_val['Re'] > 2000],
           x_val['Se'].to_numpy()[x_val['Re'] > 2000],
           x_val['Pr'].to_numpy()[x_val['Re'] > 2000])

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

x = x_val
y = y_val

ax[0].scatter(x['Re'], y, marker='.', c=x['Se'])
ax[0].set_xlabel('Re', fontsize=15)
ax[0].set_ylabel('Nu', fontsize=15)

print(len(np.concatenate([x_val[x_val['Re'] <= 2000], x_val[x_val['Re'] > 2000]])[:, 1]))
print(len(np.concatenate(
        [x_val[x_val['Re'] <= 2000], x_val[x_val['Re'] > 2000]]
    )[:, 0]))
print(len( np.concatenate([y_pred1, y_pred2])))
ax[1].scatter(
    np.concatenate([x_val[x_val['Re'] <= 2000], x_val[x_val['Re'] > 2000]])[:, 1],
    np.concatenate([y_pred1, y_pred2]),
    marker='.',
    c=np.concatenate(
        [x_val[x_val['Re'] <= 2000], x_val[x_val['Re'] > 2000]]
    )[:, 0])
ax[1].set_xlabel('Re', fontsize=15)
ax[1].set_ylabel('Nu', fontsize=15)
ax[1].set_ylim([y.min(), y.max()])

fig.suptitle('Resultados para el Número de Nusselt (Validación)', fontsize=15)
plt.show()
# Out:
# 15733
# 15733
# 15733

# %%
import pandas as pd

# Ruta a tu hall_of_fame (ajusta con la que corresponda)
path_hof = "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_134923_b2m6HF/hall_of_fame.csv"
hof = pd.read_csv(path_hof)

print(hof.head(15))
# Out:
#     Complexity      Loss                                           Equation
# 0            1  1.164645                                          24.733585
# 1            4  0.994061                                     x1 ^ 0.4146105
# 2            6  0.972661                   (x1 * 0.0059871254) - -10.871114
# 3            8  0.972661        ((x1 * 0.005987064) + 15.313141) - 4.441885
# 4            9  0.949064              (x1 * 0.00688443) - (-7.8540893 - x3)
# 5           11  0.949064  (x1 * 0.0068831574) - ((-10.276347 - x3) + 2.4...
# 6           13  0.927749  (((1.2781217 / x1) ^ -0.6056115) * 0.27276325)...
# 7           15  0.925685  (((1.044474 / x1) ^ -0.62119305) * 0.21758054)...
# 8           16  0.917822  0.27276325 * (((1.3251495 / x1) ^ -0.6056115) ...
# 9           18  0.846239  0.27276325 * ((x2 * (1.1644828 / (x1 ^ -0.6056...
# 10          20  0.837050  (0.27276325 * (((1.1644828 / (x1 ^ -0.6056115)...

# %%
import pandas as pd

# rutas de tus hall_of_fame
paths = {
    "Global": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_132233_Egwr0m/hall_of_fame.csv",
    "Re<2000": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_133604_mPlIMU/hall_of_fame.csv",  # ojo al nombre correcto
    "Re>2000": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_134923_b2m6HF/hall_of_fame.csv"
}


resumen = []
for nombre, path in paths.items():
    hof = pd.read_csv(path)
    prom = hof["Loss"].mean()
    std  = hof["Loss"].std()
    best = hof.sort_values("Loss").iloc[0]["Loss"]
    resumen.append({"Caso": nombre, "Loss_promedio": prom, "Loss_std": std, "Mejor_Loss": best})

df_resumen = pd.DataFrame(resumen)
print(df_resumen)
# Out:
#       Caso  Loss_promedio   Loss_std  Mejor_Loss
# 0   Global      23.547600  11.068184   15.741444
# 1  Re<2000      25.371649  10.509476   15.600397
# 2  Re>2000       0.950609   0.086420    0.837050

# %% [markdown]
# ### Coeficiente de arrastre

# %%
# --- Drag coefficient ---
file_path = './DATA_LIB_Degradation//df_cdrag_train_des.txt'
df_cdrag_train = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_cdrag_val_des.txt'
df_cdrag_val = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_cdrag_test_des.txt'
df_cdrag_test = pd.read_csv(file_path, sep=',')

print("Drag train:", df_cdrag_train.shape, df_cdrag_train.columns.tolist())
# Out:
# Drag train: (13432, 4) ['S', 'Re', 'SoH', 'cdrag']

# %%
# Junta los splits para visualizar todo
df_cdrag_all = pd.concat([df_cdrag_train, df_cdrag_val, df_cdrag_test], ignore_index=True)

UMBRAL = 2000
BANDA  = 200

fig, ax = plt.subplots(1, 2, figsize=(14, 5))

# --- Panel 1: cdrag vs Re (color = S) ---
sc1 = ax[0].scatter(df_cdrag_all["Re"], df_cdrag_all["cdrag"],
                    c=df_cdrag_all["S"], cmap="viridis", s=10, alpha=0.7)
ax[0].axvline(UMBRAL, color="red", linestyle="--", label=f"Umbral Re={UMBRAL}")
ax[0].axvspan(UMBRAL-BANDA, UMBRAL+BANDA, color="red", alpha=0.1, label=f"Transición ±{BANDA}")
ax[0].set_xlabel("Reynolds (Re)")
ax[0].set_ylabel("Coeficiente de arrastre (cdrag)")
ax[0].set_title("cdrag vs Re (color = S)")
ax[0].legend()
cb1 = fig.colorbar(sc1, ax=ax[0]); cb1.set_label("S")

# --- Panel 2: cdrag vs S (color = Re) ---
sc2 = ax[1].scatter(df_cdrag_all["S"], df_cdrag_all["cdrag"],
                    c=df_cdrag_all["Re"], cmap="magma", s=10, alpha=0.7)
ax[1].set_xlabel("S")
ax[1].set_ylabel("Coeficiente de arrastre (cdrag)")
ax[1].set_title("cdrag vs S (color = Re)")
cb2 = fig.colorbar(sc2, ax=ax[1]); cb2.set_label("Re")

fig.suptitle("Coeficiente de arrastre (cdrag) — Visualización", fontsize=14)
plt.tight_layout()
plt.show()

print("Rango Re:", df_cdrag_all["Re"].min(), "→", df_cdrag_all["Re"].max())
# Out:
# Rango Re: 14.389918982801634 → 2414.258394568012

# %%
# Etiquetar en todo el conjunto 
df_cdrag_all = pd.concat([df_cdrag_train, df_cdrag_val, df_cdrag_test], ignore_index=True)

df_cdrag_all["regimen"] = np.where(df_cdrag_all["Re"] < 2000, "laminar", "turbulento")
df_cdrag_all["en_transicion"] = df_cdrag_all["Re"].between(2000-200, 2000+200)

# Conteos totales
print("Total datos:", len(df_cdrag_all))
print("Laminar:", (df_cdrag_all["regimen"]=="laminar").sum())
print("Turbulento:", (df_cdrag_all["regimen"]=="turbulento").sum())
print("En transición:", df_cdrag_all["en_transicion"].sum())

# También puedes ver la intersección
print("\nLaminar (fuera transición):",
      ((df_cdrag_all["regimen"]=="laminar") & (~df_cdrag_all["en_transicion"])).sum())
print("Turbulento (fuera transición):",
      ((df_cdrag_all["regimen"]=="turbulento") & (~df_cdrag_all["en_transicion"])).sum())
# Out:
# Total datos: 44712
# Laminar: 44519
# Turbulento: 193
# En transición: 493
#
# Laminar (fuera transición): 44167
# Turbulento (fuera transición): 52

# %%
# --- parámetros simples ---
FEATURES = ["S", "Re", "SoH"]
TARGET   = "cdrag"
UMBRAL   = 2000
BANDA    = 200

# %%
# 1) juntar y etiquetar
df = pd.concat([df_cdrag_train, df_cdrag_val], ignore_index=True)  # train+val para entrenar
df["regimen"] = np.where(df["Re"] < UMBRAL, "laminar", "turbulento")
df["en_transicion"] = df["Re"].between(UMBRAL-BANDA, UMBRAL+BANDA)

# %%
# 2) hacer subsets
df_mid = df.copy()  # global (incluye todo)
df_lam = df[(df["regimen"]=="laminar") & (~df["en_transicion"])].copy()
df_tur = df[(df["regimen"]=="turbulento") & (~df["en_transicion"])].copy()

print("Total:", len(df), "| Laminar puro:", len(df_lam), "| Turbulento puro:", len(df_tur))
# Out:
# Total: 29073 | Laminar puro: 28688 | Turbulento puro: 27

# %%
def XY(d): 
    return d[FEATURES].to_numpy(), d[TARGET].to_numpy()

# %%
# 3) misma config PySR (Lucas)
def new_model():
    return PySRRegressor(
        niterations=200,
        binary_operators=["+","-","*","/","^"],
        unary_operators=[],
        population_size=50,
        populations=4,
        tournament_selection_n=3,
        verbosity=1,
        maxsize=20,
        parsimony=1e-2,
        constraints={'^':(-1,1)},
        complexity_of_variables=2,
        random_state=0,
        progress=True
    )

# %%
# 3a) entrenar global
X_mid, y_mid = XY(df_mid)
mid = new_model()
t0 = time.time()
mid.fit(X_mid, y_mid)
print("global:", time.time()-t0, "s")
# Out:
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 5.050e+03
# Progress: 5 / 800 total iterations (0.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 8           3.893e-01  3.177e-04  y = ((x₀ - -0.69533) * 1.0347) / 0.98409
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.800e+03
# Progress: 10 / 800 total iterations (1.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 8           3.893e-01  3.177e-04  y = ((x₀ - -0.69533) * 1.0347) / 0.98409
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.990e+03
# Progress: 15 / 800 total iterations (1.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.480e+03
# Progress: 18 / 800 total iterations (2.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.310e+03
# Progress: 22 / 800 total iterations (2.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.640e+03
# Progress: 32 / 800 total iterations (4.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.440e+03
# Progress: 43 / 800 total iterations (5.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.040e+04
# Progress: 53 / 800 total iterations (6.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.030e+04
# Progress: 55 / 800 total iterations (6.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.290e+03
# Progress: 60 / 800 total iterations (7.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 11          3.508e-01  2.067e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.410e+03
# Progress: 69 / 800 total iterations (8.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.508e-01  3.471e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.830e+03
# Progress: 78 / 800 total iterations (9.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.508e-01  3.471e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.150e+03
# Progress: 89 / 800 total iterations (11.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.508e-01  3.471e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.110e+04
# Progress: 97 / 800 total iterations (12.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.508e-01  3.471e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.300e+04
# Progress: 108 / 800 total iterations (13.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.508e-01  3.471e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.270e+04
# Progress: 116 / 800 total iterations (14.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.508e-01  3.471e-02  y = (x₀ + 0.59694) - (-1.3402 / (x₁ * 0.017573))
# 13          3.500e-01  1.214e-03  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.220e+04
# Progress: 123 / 800 total iterations (15.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.080e+04
# Progress: 133 / 800 total iterations (16.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.450e+03
# Progress: 135 / 800 total iterations (16.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.150e+03
# Progress: 141 / 800 total iterations (17.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.530e+03
# Progress: 154 / 800 total iterations (19.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.930e+03
# Progress: 158 / 800 total iterations (19.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.430e+03
# Progress: 165 / 800 total iterations (20.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.020e+03
# Progress: 173 / 800 total iterations (21.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.502e-01  3.568e-02  y = (x₀ + 0.54989) - ((-4.4044 / x₁) * 19.446)
# 13          3.500e-01  2.419e-04  y = (x₀ + 0.55644) - (-1.3586 / ((x₁ * -0.071052) / -4.576...
#                                       9))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.240e+03
# Progress: 178 / 800 total iterations (22.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.761e-01  1.131e-02  y = ((x₁ ^ -0.097429) + x₀) * 1.1615
# 11          3.500e-01  3.593e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.310e+03
# Progress: 185 / 800 total iterations (23.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.758e-01  1.154e-02  y = ((0.032262 * x₁) ^ -0.071762) + x₀
# 11          3.500e-01  3.558e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.890e+03
# Progress: 187 / 800 total iterations (23.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.758e-01  1.154e-02  y = ((0.032262 * x₁) ^ -0.071762) + x₀
# 11          3.500e-01  3.558e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.170e+03
# Progress: 191 / 800 total iterations (23.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.758e-01  1.154e-02  y = ((0.032262 * x₁) ^ -0.071762) + x₀
# 11          3.500e-01  3.558e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# 16          3.494e-01  7.309e-04  y = ((x₀ + x₀) * 0.43913) - ((-0.10829 + -0.53113) + (-88....
#                                       359 / x₁))
# 18          3.488e-01  8.117e-04  y = ((((x₀ + x₀) * 0.43913) - (-88.359 / x₁)) + 0.19177) -...
#                                        (-0.35575 - 0.11224)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.180e+03
# Progress: 197 / 800 total iterations (24.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.758e-01  1.154e-02  y = ((0.032262 * x₁) ^ -0.071762) + x₀
# 11          3.500e-01  3.558e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# 16          3.494e-01  7.309e-04  y = ((x₀ + x₀) * 0.43913) - ((-0.10829 + -0.53113) + (-88....
#                                       359 / x₁))
# 18          3.488e-01  8.117e-04  y = ((((x₀ + x₀) * 0.43913) - (-88.359 / x₁)) + 0.19177) -...
#                                        (-0.35575 - 0.11224)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.400e+03
# Progress: 200 / 800 total iterations (25.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.758e-01  1.154e-02  y = ((0.032262 * x₁) ^ -0.071762) + x₀
# 11          3.500e-01  3.558e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# 16          3.494e-01  7.310e-04  y = ((x₀ + x₀) * 0.43913) - (-0.10829 + (-0.53113 + (-88.3...
#                                       59 / x₁)))
# 18          3.488e-01  8.116e-04  y = ((((x₀ + x₀) * 0.43913) - (-88.359 / x₁)) + 0.19177) -...
#                                        (-0.35575 - 0.11224)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.200e+03
# Progress: 206 / 800 total iterations (25.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.758e-01  1.154e-02  y = ((0.032262 * x₁) ^ -0.071762) + x₀
# 11          3.500e-01  3.558e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# 16          3.487e-01  1.670e-03  y = 0.7372 + (x₀ - ((((0.7372 / x₁) / -0.009262) - -0.1338...
#                                       ) / x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.910e+03
# Progress: 208 / 800 total iterations (26.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.758e-01  1.154e-02  y = ((0.032262 * x₁) ^ -0.071762) + x₀
# 11          3.500e-01  3.558e-02  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.499e-01  7.905e-05  y = x₀ + (0.44602 - ((-88.359 / (x₁ + x₂)) + -0.10829))
# 16          3.487e-01  1.670e-03  y = 0.7372 + (x₀ - ((((0.7372 / x₁) / -0.009262) - -0.1338...
#                                       ) / x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.580e+03
# Progress: 211 / 800 total iterations (26.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.790e+03
# Progress: 215 / 800 total iterations (26.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.500e+03
# Progress: 219 / 800 total iterations (27.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.130e+03
# Progress: 226 / 800 total iterations (28.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.860e+03
# Progress: 234 / 800 total iterations (29.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.490e+03
# Progress: 241 / 800 total iterations (30.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.820e+03
# Progress: 248 / 800 total iterations (31.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.880e+03
# Progress: 253 / 800 total iterations (31.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.060e+03
# Progress: 260 / 800 total iterations (32.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.620e+03
# Progress: 265 / 800 total iterations (33.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.490e+03
# Progress: 266 / 800 total iterations (33.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 14          3.487e-01  1.241e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.850e+03
# Progress: 271 / 800 total iterations (33.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.490e-04  y = (x₀ - -0.66463) * 1.08
# 9           3.501e-01  3.515e-02  y = x₀ + (0.56491 - (-88.359 / x₁))
# 11          3.500e-01  1.605e-04  y = x₀ + (0.44602 - ((-88.359 / x₁) + -0.10829))
# 13          3.494e-01  8.172e-04  y = (x₀ + ((-1.1818 + 1.8101) - (-88.359 / x₁))) / 1.0398
# 14          3.487e-01  2.088e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + (x₀ + 43.727)))
# 16          3.460e-01  3.932e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.910e+03
# ...
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.130e+04
# Progress: 748 / 800 total iterations (93.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.150e+04
# Progress: 754 / 800 total iterations (94.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.070e+04
# Progress: 758 / 800 total iterations (94.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.260e+03
# Progress: 764 / 800 total iterations (95.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.960e+03
# Progress: 769 / 800 total iterations (96.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.560e+03
# Progress: 777 / 800 total iterations (97.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.400e+03
# Progress: 788 / 800 total iterations (98.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.810e+03
# Progress: 797 / 800 total iterations (99.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.234e-01  0.000e+00  y = 1.6866
# 4           3.898e-01  9.825e-02  y = x₀ - -0.78951
# 6           3.890e-01  9.907e-04  y = (x₀ + 0.74407) ^ 1.0541
# 7           3.840e-01  1.298e-02  y = (x₁ ^ -0.052162) + x₀
# 9           3.500e-01  4.636e-02  y = (x₀ + 0.55431) - (-88.361 / x₁)
# 11          3.487e-01  1.800e-03  y = (x₀ + 0.48944) - (-133.83 / (x₁ + 43.727))
# 13          3.487e-01  1.293e-05  y = (x₀ + 0.48944) - (-133.83 / ((x₁ + 43.727) - -0.78737)...
#                                       )
# 14          3.477e-01  2.993e-03  y = x₀ + (0.48944 - (-133.83 / (x₁ + (x₀ * 43.727))))
# 16          3.460e-01  2.483e-03  y = (x₀ + 1.056) - ((-56.471 / x₁) + ((x₁ * 0.00024909) + ...
#                                       0.26712))
# 18          3.459e-01  3.105e-05  y = (x₀ + 1.056) - ((-56.471 / (x₁ - 0.66631)) + ((x₁ * 0....
#                                       00024909) + 0.26712))
# 19          3.432e-01  7.970e-03  y = (x₀ + 1.0266) - ((0.00024909 * x₁) + ((0.26712 + (-56....
#                                       471 / x₁)) * x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# global: 693.8318212032318 s
#   - outputs/20250921_181514_m6HFIv/hall_of_fame.csv

# %%
# 3b) entrenar laminar (si hay datos)
lam = None
if len(df_lam) > 0:
    X_lam, y_lam = XY(df_lam)
    lam = new_model()
    t0 = time.time()
    lam.fit(X_lam, y_lam)
    print("laminar:", time.time()-t0, "s")
else:
    print("[aviso] subset laminar vacío; usaré global como fallback.")
# Out:
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 1.920e+03
# Progress: 5 / 800 total iterations (0.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 7           3.863e-01  5.058e-03  y = x₀ + (x₁ ^ -0.031619)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.500e+03
# Progress: 8 / 800 total iterations (1.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 7           3.863e-01  5.058e-03  y = x₀ + (x₁ ^ -0.031619)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+03
# Progress: 9 / 800 total iterations (1.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.610e+03
# Progress: 13 / 800 total iterations (1.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 19          3.778e-01  1.856e-03  y = 0.27791 + (1.0766 * (((x₁ ^ -0.15415) + x₀) - (x₁ - (x...
#                                       ₁ - -0.052865))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.440e+03
# Progress: 18 / 800 total iterations (2.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 16          3.824e-01  1.134e-03  y = ((x₁ ^ -0.072328) + (0.94923 + x₀)) + ((x₂ * -0.02247)...
#                                        + -0.81661)
# 19          3.776e-01  4.203e-03  y = 0.27791 + ((1.0766 * ((x₁ ^ -0.15415) + x₀)) - (x₁ - (...
#                                       x₁ - -0.052865)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.790e+03
# Progress: 22 / 800 total iterations (2.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 16          3.824e-01  1.134e-03  y = ((x₁ ^ -0.072328) + (0.94923 + x₀)) + ((x₂ * -0.02247)...
#                                        + -0.81661)
# 19          3.776e-01  4.203e-03  y = ((0.27791 + (1.0766 * ((x₁ ^ -0.15415) + x₀))) - x₁) -...
#                                        (-0.052865 - x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.790e+03
# Progress: 27 / 800 total iterations (3.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 11          3.812e-01  3.358e-03  y = (x₁ ^ -0.072328) + ((0.94923 + x₀) + -0.81661)
# 19          3.776e-01  1.173e-03  y = ((0.27791 + (1.0766 * ((x₁ ^ -0.15415) + x₀))) - x₁) -...
#                                        (-0.052865 - x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.380e+03
# Progress: 30 / 800 total iterations (3.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 11          3.812e-01  3.358e-03  y = (x₁ ^ -0.072328) + ((0.94923 + x₀) + -0.81661)
# 19          3.776e-01  1.173e-03  y = ((0.27791 + (1.0766 * ((x₁ ^ -0.15415) + x₀))) - x₁) -...
#                                        (-0.052865 - x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.430e+03
# Progress: 31 / 800 total iterations (3.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 11          3.812e-01  3.358e-03  y = (x₁ ^ -0.072328) + ((0.94923 + x₀) + -0.81661)
# 19          3.776e-01  1.173e-03  y = ((0.27791 + (1.0766 * ((x₁ ^ -0.15415) + x₀))) - x₁) -...
#                                        (-0.052865 - x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.520e+03
# Progress: 34 / 800 total iterations (4.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 11          3.730e-01  8.779e-03  y = (x₁ ^ -0.13716) * ((x₀ + 2.1679) - -0.86146)
# 13          3.668e-01  8.398e-03  y = (x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -0.816...
#                                       61)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.920e+03
# Progress: 36 / 800 total iterations (4.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.668e-01  6.013e-03  y = (x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -0.816...
#                                       61)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.000e+03
# Progress: 38 / 800 total iterations (4.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.668e-01  6.013e-03  y = (x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -0.816...
#                                       61)
# 17          3.511e-01  1.092e-02  y = (x₁ ^ -0.15091) * ((((x₀ ^ -0.11044) + x₀) + x₀) + 1.4...
#                                       48)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.230e+03
# Progress: 42 / 800 total iterations (5.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.668e-01  6.013e-03  y = (x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -0.816...
#                                       61)
# 17          3.511e-01  1.092e-02  y = (x₁ ^ -0.15091) * ((((x₀ ^ -0.11044) + x₀) + x₀) + 1.4...
#                                       48)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.280e+03
# Progress: 50 / 800 total iterations (6.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.668e-01  6.013e-03  y = (x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -0.816...
#                                       61)
# 15          3.653e-01  1.963e-03  y = ((x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -1.72...
#                                       )) - 0.67319
# 17          3.511e-01  1.987e-02  y = (x₁ ^ -0.15091) * ((((x₀ ^ -0.11044) + x₀) + x₀) + 1.4...
#                                       48)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.260e+03
# Progress: 56 / 800 total iterations (7.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.668e-01  6.013e-03  y = (x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -0.816...
#                                       61)
# 15          3.645e-01  3.155e-03  y = ((x₁ ^ -0.072328) * (((x₀ ^ 1.4876) + 0.94923) - -1.72...
#                                       )) - 0.67319
# 17          3.511e-01  1.868e-02  y = (x₁ ^ -0.15091) * ((((x₀ ^ -0.11044) + x₀) + x₀) + 1.4...
#                                       48)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.340e+03
# Progress: 57 / 800 total iterations (7.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.668e-01  6.013e-03  y = (x₁ ^ -0.072328) * (((x₀ ^ 1.7488) + 0.94923) - -0.816...
#                                       61)
# 15          3.645e-01  3.155e-03  y = ((x₁ ^ -0.072328) * (((x₀ ^ 1.4876) + 0.94923) - -1.72...
#                                       )) - 0.67319
# 17          3.511e-01  1.868e-02  y = (x₁ ^ -0.15091) * ((((x₀ ^ -0.11044) + x₀) + x₀) + 1.4...
#                                       48)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.710e+03
# Progress: 58 / 800 total iterations (7.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.633e-01  1.071e-02  y = ((((x₁ ^ -0.15091) * x₀) + 0.42933) - 0.15369) / 0.372...
#                                       59
# 17          3.511e-01  8.567e-03  y = (x₁ ^ -0.15091) * ((((x₀ ^ -0.11044) + x₀) + x₀) + 1.4...
#                                       48)
# 19          3.504e-01  1.066e-03  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.470e+03
# Progress: 63 / 800 total iterations (7.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.863e-01  1.794e-05  y = x₀ + ((x₁ + -0.75069) ^ -0.031619)
# 11          3.712e-01  1.993e-02  y = ((x₁ ^ -0.26353) + 0.83255) * (x₀ + 0.73771)
# 13          3.633e-01  1.071e-02  y = ((((x₁ ^ -0.15091) * x₀) + 0.42933) - 0.15369) / 0.372...
#                                       59
# 17          3.506e-01  8.890e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.170e+03
# Progress: 71 / 800 total iterations (8.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ + 0.7088) / 0.94894
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.490e+03
# Progress: 78 / 800 total iterations (9.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.760e+03
# Progress: 83 / 800 total iterations (10.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.680e+03
# Progress: 87 / 800 total iterations (10.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.560e+03
# Progress: 89 / 800 total iterations (11.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.580e+03
# Progress: 94 / 800 total iterations (11.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.840e+03
# Progress: 96 / 800 total iterations (12.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.520e+03
# Progress: 97 / 800 total iterations (12.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.790e+03
# Progress: 101 / 800 total iterations (12.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.550e+03
# Progress: 106 / 800 total iterations (13.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.650e+03
# Progress: 110 / 800 total iterations (13.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.950e+03
# Progress: 115 / 800 total iterations (14.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.552e-01  3.158e-03  y = ((((x₁ ^ -0.75862) / -0.036602) * -0.84998) + x₀) - -0...
#                                       .55854
# 15          3.551e-01  5.323e-05  y = ((((x₁ ^ -0.75862) / -0.036602) * (0.9137 * -1.0315)) ...
#                                       + x₀) - -0.55854
# 17          3.506e-01  6.369e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.504e-01  4.197e-04  y = (x₁ ^ -0.15091) * ((((x₂ + 0.39686) ^ -0.11044) + (x₀ ...
#                                       + x₀)) + 1.448)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.020e+03
# Progress: 120 / 800 total iterations (15.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.534e-01  5.626e-03  y = (-0.075331 - ((x₁ ^ -0.75862) / -0.036602)) + (x₀ - -0...
#                                       .55854)
# 17          3.506e-01  1.977e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.501e-01  7.519e-04  y = (x₁ ^ -0.15091) * (((x₂ + -0.082261) ^ -0.11044) + ((x...
#                                       ₀ + x₀) + 1.448))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.250e+03
# Progress: 127 / 800 total iterations (15.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.534e-01  5.626e-03  y = (-0.075331 - ((x₁ ^ -0.75862) / -0.036602)) + (x₀ - -0...
#                                       .55854)
# 17          3.506e-01  1.977e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.501e-01  7.519e-04  y = (x₁ ^ -0.15091) * (((x₂ + -0.082261) ^ -0.11044) + ((x...
#                                       ₀ + x₀) + 1.448))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.700e+03
# Progress: 133 / 800 total iterations (16.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.534e-01  5.626e-03  y = (-0.075331 - ((x₁ ^ -0.75862) / -0.036602)) + (x₀ - -0...
#                                       .55854)
# 17          3.506e-01  1.977e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.501e-01  7.519e-04  y = (x₁ ^ -0.15091) * (((x₂ + -0.082261) ^ -0.11044) + ((x...
#                                       ₀ + x₀) + 1.448))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.040e+03
# Progress: 136 / 800 total iterations (17.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.534e-01  5.626e-03  y = (-0.075331 - ((x₁ ^ -0.75862) / -0.036602)) + (x₀ - -0...
#                                       .55854)
# 17          3.506e-01  1.977e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.501e-01  7.519e-04  y = (x₁ ^ -0.15091) * (((x₂ + -0.082261) ^ -0.11044) + ((x...
#                                       ₀ + x₀) + 1.448))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.810e+03
# Progress: 138 / 800 total iterations (17.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.534e-01  5.626e-03  y = (-0.075331 - ((x₁ ^ -0.75862) / -0.036602)) + (x₀ - -0...
#                                       .55854)
# 17          3.506e-01  1.977e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
#                                       4))
# 19          3.501e-01  7.519e-04  y = (x₁ ^ -0.15091) * (((x₂ + -0.082261) ^ -0.11044) + ((x...
#                                       ₀ + x₀) + 1.448))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.970e+03
# Progress: 141 / 800 total iterations (17.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.919e-01  4.256e-04  y = (x₀ * 1.0544) + 0.74635
# 7           3.863e-01  1.432e-02  y = x₀ + (x₁ ^ -0.031619)
# 9           3.600e-01  3.524e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.574e-01  3.621e-03  y = ((x₁ ^ -0.76783) / 0.045156) + (x₀ - -0.6016)
# 13          3.534e-01  5.626e-03  y = (-0.075331 - ((x₁ ^ -0.75862) / -0.036602)) + (x₀ - -0...
#                                       .55854)
# 17          3.506e-01  1.977e-03  y = (x₁ ^ -0.16244) * (((x₂ ^ -0.61125) + x₂) * (x₀ + 1.38...
# ...
#                                       34) / 0.38267)
# 20          3.477e-01  3.322e-04  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.960e+03
# Progress: 759 / 800 total iterations (94.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  3.493e-05  y = ((x₁ ^ -0.19324) * 1.1489) * ((x₀ + 1.2426) / 0.44867)
# 15          3.478e-01  1.627e-05  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  9.610e-05  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.840e+03
# Progress: 764 / 800 total iterations (95.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.238e-05  y = ((x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)) ^ 0.99696
# 15          3.478e-01  8.881e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  9.610e-05  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.160e+03
# Progress: 767 / 800 total iterations (95.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.238e-05  y = ((x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)) ^ 0.99696
# 15          3.478e-01  8.881e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  9.610e-05  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.450e+03
# Progress: 769 / 800 total iterations (96.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.238e-05  y = ((x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)) ^ 0.99696
# 15          3.478e-01  8.881e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  9.610e-05  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.000e+03
# Progress: 773 / 800 total iterations (96.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.238e-05  y = ((x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)) ^ 0.99696
# 15          3.478e-01  8.881e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  9.610e-05  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.460e+03
# Progress: 775 / 800 total iterations (96.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.238e-05  y = ((x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)) ^ 0.99696
# 15          3.478e-01  8.881e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  9.610e-05  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.800e+03
# Progress: 783 / 800 total iterations (97.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.435e-05  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / (0.38611 ^ 0.99696))
# 15          3.478e-01  6.855e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 19          3.478e-01  6.557e-06  y = (((((-1.9951 + x₁) * 0.15649) / 1.0609) + -0.50078) ^ ...
#                                       -0.18765) * ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  2.751e-04  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.970e+03
# Progress: 788 / 800 total iterations (98.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.435e-05  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / (0.38611 ^ 0.99696))
# 15          3.478e-01  6.855e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 19          3.478e-01  6.557e-06  y = (((((-1.9951 + x₁) * 0.15649) / 1.0609) + -0.50078) ^ ...
#                                       -0.18765) * ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  2.751e-04  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.290e+03
# Progress: 794 / 800 total iterations (99.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.435e-05  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / (0.38611 ^ 0.99696))
# 15          3.478e-01  6.855e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 19          3.478e-01  6.557e-06  y = (((((-1.9951 + x₁) * 0.15649) / 1.0609) + -0.50078) ^ ...
#                                       -0.18765) * ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  2.751e-04  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.173e-01  0.000e+00  y = 1.6997
# 4           3.922e-01  9.229e-02  y = x₀ - -0.79553
# 6           3.917e-01  6.119e-04  y = (x₀ ^ 1.0761) - -0.79712
# 7           3.845e-01  1.876e-02  y = (x₁ ^ -0.040235) + x₀
# 9           3.600e-01  3.283e-02  y = (x₁ * -0.00050678) + (x₀ - -1.0908)
# 11          3.479e-01  1.719e-02  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / 0.38611)
# 13          3.478e-01  4.435e-05  y = (x₁ ^ -0.19244) * ((x₀ + 1.216) / (0.38611 ^ 0.99696))
# 15          3.478e-01  6.855e-06  y = (((x₁ - 1.6971) * 1.1511) ^ -0.19221) * ((x₀ + 1.2434)...
#                                        / 0.38267)
# 17          3.478e-01  3.648e-05  y = ((((x₁ * 0.15649) / 1.0609) + -0.50078) ^ -0.18765) * ...
#                                       ((x₀ + 1.21) / 0.57038)
# 19          3.478e-01  6.557e-06  y = (((((-1.9951 + x₁) * 0.15649) / 1.0609) + -0.50078) ^ ...
#                                       -0.18765) * ((x₀ + 1.21) / 0.57038)
# 20          3.477e-01  2.751e-04  y = (((x₁ ^ -0.15593) * ((x₀ + 3.6395) + x₀)) + -0.40609) ...
#                                       + (x₀ - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# laminar: 1101.5365929603577 s
#   - outputs/20250921_182802_KojOg7/hall_of_fame.csv

# %%
# 3c) entrenar turbulento (si hay datos)
tur = None
if len(df_tur) > 0:
    X_tur, y_tur = XY(df_tur)
    tur = new_model()
    t0 = time.time()
    tur.fit(X_tur, y_tur)
    print("turbulento:", time.time()-t0, "s")
else:
    print("[aviso] subset turbulento vacío; usaré global como fallback.")
# Out:
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 2.970e+05
# Progress: 223 / 800 total iterations (27.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.314e-03  0.000e+00  y = 0.60119
# 4           1.314e-03  5.960e-08  y = 0.88182 - x₀
# 6           1.258e-03  2.195e-02  y = (0.055187 * x₂) + 0.55187
# 8           1.257e-03  4.619e-04  y = ((x₂ ^ 0.22434) * 0.16703) - -0.43704
# 9           1.253e-03  3.141e-03  y = (x₁ ^ -0.074748) + (x₂ * 0.045658)
# 11          1.221e-03  1.291e-02  y = (x₂ + ((x₂ ^ -0.52019) + -0.51793)) * 0.40889
# 16          1.219e-03  2.634e-04  y = ((x₂ * 1.2725) + (x₂ ^ -0.61381)) * ((x₀ ^ -5.1671) * ...
#                                       0.00037454)
# 18          1.219e-03  2.444e-05  y = (((x₂ + 0.0008647) * 1.2725) + (x₂ ^ -0.61381)) * ((x₀...
#                                        ^ -5.1671) * 0.00037454)
# 20          1.219e-03  1.207e-04  y = ((((x₂ + (x₂ ^ -0.5077)) * (x₀ * x₀)) / x₀) + 0.14853)...
#                                        ^ 1.4695
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.360e+05
# Progress: 497 / 800 total iterations (62.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.314e-03  0.000e+00  y = 0.60119
# 4           1.303e-03  2.754e-03  y = x₁ ^ -0.065703
# 6           1.251e-03  2.052e-02  y = (x₂ * 0.05081) - -0.55347
# 8           1.251e-03  8.941e-08  y = (-0.83952 - (x₂ * -0.050811)) + 1.393
# 11          1.217e-03  9.167e-03  y = (x₂ ^ -0.25456) + (-0.83728 - (x₂ * -0.44237))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.270e+05
# Progress: 768 / 800 total iterations (96.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.314e-03  0.000e+00  y = 0.60119
# 4           1.303e-03  2.754e-03  y = x₁ ^ -0.065703
# 6           1.251e-03  2.052e-02  y = (x₂ * 0.05081) - -0.55347
# 8           1.251e-03  8.941e-08  y = (-0.83952 - (x₂ * -0.050811)) + 1.393
# 11          1.217e-03  9.167e-03  y = (x₂ ^ -0.25456) + (-0.83728 - (x₂ * -0.44237))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.314e-03  0.000e+00  y = 0.60119
# 4           1.303e-03  2.754e-03  y = x₁ ^ -0.065703
# 6           1.251e-03  2.052e-02  y = (x₂ * 0.05081) - -0.55347
# 8           1.251e-03  8.941e-08  y = (-0.83952 - (x₂ * -0.050811)) + 1.393
# 11          1.217e-03  9.167e-03  y = (x₂ ^ -0.25456) + (-0.83728 - (x₂ * -0.44237))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# turbulento: 16.83162021636963 s
#   - outputs/20250921_184624_b2m6HF/hall_of_fame.csv

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

UMBRAL = 2000
BANDA  = 200

def predict_piecewise(d):
    re = d["Re"].to_numpy()
    X  = d[FEATURES].to_numpy()
    yhat = np.empty(len(d))
    mask_l = re < (UMBRAL - BANDA)
    mask_t = re > (UMBRAL + BANDA)
    mask_m = ~(mask_l | mask_t)
    # fallback al global si lam/tur es None
    yhat[mask_l] = (lam or mid).predict(X[mask_l])
    yhat[mask_t] = (tur or mid).predict(X[mask_t])
    yhat[mask_m] = mid.predict(X[mask_m])
    return yhat

X_te = df_cdrag_test[FEATURES].to_numpy()
y_te = df_cdrag_test[TARGET].to_numpy()

yhat_mid   = mid.predict(X_te)
yhat_piece = predict_piecewise(df_cdrag_test)

print("TEST Global   : MSE=%.4f  R2=%.4f" % (mean_squared_error(y_te, yhat_mid),   r2_score(y_te, yhat_mid)))
print("TEST Piecewise: MSE=%.4f  R2=%.4f" % (mean_squared_error(y_te, yhat_piece), r2_score(y_te, yhat_piece)))
# Out:
# TEST Global   : MSE=0.3233  R2=0.2726
# TEST Piecewise: MSE=0.3232  R2=0.2728

# %%
# rutas de hall_of_fame para ff
paths = {
    "Global": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_181514_m6HFIv/hall_of_fame.csv",
    "Re<2000": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_182802_KojOg7/hall_of_fame.csv",
    "Re>2000": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_184624_b2m6HF/hall_of_fame.csv"
}

resumen = []
for nombre, path in paths.items():
    hof = pd.read_csv(path)
    prom = hof["Loss"].mean()
    std  = hof["Loss"].std()
    best = hof.sort_values("Loss").iloc[0]["Loss"]
    resumen.append({
        "Caso": nombre,
        "Loss_promedio": prom,
        "Loss_std": std,
        "Mejor_Loss": best
    })

df_resumen = pd.DataFrame(resumen)
print(df_resumen)
# Out:
#       Caso  Loss_promedio  Loss_std  Mejor_Loss
# 0   Global       0.374222  0.052879    0.343195
# 1  Re<2000       0.375693  0.050584    0.347699
# 2  Re>2000       0.001267  0.000041    0.001217

# %% [markdown]
# ### Friction Factor

# %%
# --- Friction factor ---
file_path = './DATA_LIB_Degradation//df_ff_train_des.txt'
df_ff_train = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_ff_val_des.txt'
df_ff_val = pd.read_csv(file_path, sep=',')
file_path = './DATA_LIB_Degradation//df_ff_test_des.txt'
df_ff_test = pd.read_csv(file_path, sep=',')

print("FF train:", df_ff_train.shape, df_ff_train.columns.tolist())
# Out:
# FF train: (13391, 4) ['S', 'Re', 'SoH', 'frictionFactor']

# %%
df_ff_all = pd.concat([df_ff_train, df_ff_val, df_ff_test], ignore_index=True)

UMBRAL = 2000
BANDA  = 200

fig, ax = plt.subplots(1, 2, figsize=(14, 5))

# --- Panel 1: ff vs Re (color = S) ---
sc1 = ax[0].scatter(df_ff_all["Re"], df_ff_all["frictionFactor"],
                    c=df_ff_all["S"], cmap="viridis", s=10, alpha=0.7)
ax[0].axvline(UMBRAL, color="red", linestyle="--", label=f"Umbral Re={UMBRAL}")
ax[0].axvspan(UMBRAL-BANDA, UMBRAL+BANDA, color="red", alpha=0.1, label=f"Transición ±{BANDA}")
ax[0].set_xlabel("Reynolds (Re)")
ax[0].set_ylabel("Friction factor (ff)")
ax[0].set_title("ff vs Re (color = S)")
ax[0].legend()
cb1 = fig.colorbar(sc1, ax=ax[0]); cb1.set_label("S")

# --- Panel 2: ff vs S (color = Re) ---
sc2 = ax[1].scatter(df_ff_all["S"], df_ff_all["frictionFactor"],
                    c=df_ff_all["Re"], cmap="magma", s=10, alpha=0.7)
ax[1].set_xlabel("S")
ax[1].set_ylabel("Friction factor (ff)")
ax[1].set_title("ff vs S (color = Re)")
cb2 = fig.colorbar(sc2, ax=ax[1]); cb2.set_label("Re")

fig.suptitle("Friction factor (ff) — Visualización", fontsize=14)
plt.tight_layout()
plt.show()

print("Rango Re:", df_ff_all["Re"].min(), "→", df_ff_all["Re"].max())
# Out:
# Rango Re: 15.902603659079924 → 2414.258394568012

# %%
# --- parámetros simples (ff) ---
FEATURES = ["S", "Re", "SoH"]       
TARGET   = "frictionFactor"
UMBRAL   = 2000
BANDA    = 200

# %%
df = pd.concat([df_ff_train, df_ff_val], ignore_index=True)
df["regimen"] = np.where(df["Re"] < UMBRAL, "laminar", "turbulento")
df["en_transicion"] = df["Re"].between(UMBRAL - BANDA, UMBRAL + BANDA)

# %%
df_mid = df.copy()  # global (incluye todo)
df_lam = df[(df["regimen"]=="laminar") & (~df["en_transicion"])].copy()
df_tur = df[(df["regimen"]=="turbulento") & (~df["en_transicion"])].copy()

print("Total:", len(df), "| Laminar puro:", len(df_lam), "| Turbulento puro:", len(df_tur))
# Out:
# Total: 29018 | Laminar puro: 28633 | Turbulento puro: 27

# %%
def XY(d):
    return d[FEATURES].to_numpy(), d[TARGET].to_numpy()

# %%
def new_model():
    return PySRRegressor(
        niterations=200,
        binary_operators=["+","-","*","/","^"],
        unary_operators=[],
        population_size=50,
        populations=4,
        tournament_selection_n=3,
        verbosity=1,
        maxsize=20,
        parsimony=1e-2,
        constraints={'^':(-1,1)},
        complexity_of_variables=2,
        random_state=0,
        progress=True
    )

# %%
# Global
X_mid, y_mid = XY(df_mid)
mid = new_model(); t0=time.time(); mid.fit(X_mid, y_mid); print("global:", time.time()-t0, "s")
# Out:
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 3.260e+03
# Progress: 2 / 800 total iterations (0.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           1.124e-01  1.766e-03  y = 1.411 * (x₁ ^ -0.031619)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.660e+03
# Progress: 6 / 800 total iterations (0.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           1.032e-01  1.880e-02  y = (2.2672 - x₀) ^ 0.64122
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.140e+03
# Progress: 11 / 800 total iterations (1.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.958e-02  2.603e-02  y = (2.6298 - x₀) ^ 0.38321
# 8           9.771e-02  9.515e-03  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.480e+03
# Progress: 15 / 800 total iterations (1.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 17          7.781e-02  2.530e-02  y = (0.24589 + (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.110e+03
# Progress: 17 / 800 total iterations (2.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          9.766e-02  6.491e-05  y = ((1.2485 - (x₀ + -0.6426)) ^ 0.22629) + ((0.073337 / x...
#                                       ₀) - -0.1164)
# 17          7.781e-02  1.136e-01  y = (0.24589 + (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.820e+03
# Progress: 19 / 800 total iterations (2.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          9.766e-02  6.491e-05  y = ((1.2485 - (x₀ + -0.6426)) ^ 0.22629) + ((0.073337 / x...
#                                       ₀) - -0.1164)
# 17          7.781e-02  1.136e-01  y = (0.24589 + (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.770e+03
# Progress: 21 / 800 total iterations (2.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          9.766e-02  6.491e-05  y = ((1.2485 - (x₀ + -0.6426)) ^ 0.22629) + ((0.073337 / x...
#                                       ₀) - -0.1164)
# 17          7.781e-02  1.136e-01  y = (0.24589 + (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.860e+03
# Progress: 29 / 800 total iterations (3.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          9.766e-02  6.491e-05  y = ((1.2485 - (x₀ + -0.6426)) ^ 0.22629) + ((0.073337 / x...
#                                       ₀) - -0.1164)
# 17          7.740e-02  1.163e-01  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.330e+03
# Progress: 37 / 800 total iterations (4.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          9.766e-02  6.491e-05  y = ((1.2485 - (x₀ + -0.6426)) ^ 0.22629) + ((0.073337 / x...
#                                       ₀) - -0.1164)
# 17          7.740e-02  1.163e-01  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.250e+03
# Progress: 43 / 800 total iterations (5.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          8.057e-02  2.755e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.370e+03
# Progress: 47 / 800 total iterations (5.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          8.057e-02  2.755e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.650e+03
# Progress: 51 / 800 total iterations (6.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          8.057e-02  2.755e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.700e+03
# Progress: 52 / 800 total iterations (6.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 15          8.057e-02  2.755e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.660e+03
# Progress: 56 / 800 total iterations (7.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.510e+03
# Progress: 60 / 800 total iterations (7.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.160e+03
# Progress: 68 / 800 total iterations (8.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.130e+03
# Progress: 77 / 800 total iterations (9.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.760e+03
# Progress: 83 / 800 total iterations (10.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.060e+03
# Progress: 84 / 800 total iterations (10.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.950e+03
# Progress: 86 / 800 total iterations (10.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.020e+03
# Progress: 87 / 800 total iterations (10.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.010e+03
# Progress: 93 / 800 total iterations (11.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.300e+03
# Progress: 101 / 800 total iterations (12.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.160e+03
# Progress: 111 / 800 total iterations (13.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.130e+03
# Progress: 117 / 800 total iterations (14.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.420e+03
# Progress: 120 / 800 total iterations (15.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.290e+03
# Progress: 122 / 800 total iterations (15.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+03
# Progress: 126 / 800 total iterations (15.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.670e+03
# Progress: 132 / 800 total iterations (16.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# 19          7.739e-02  5.973e-05  y = (((((x₀ * ((x₁ - -0.56507) ^ 0.48008)) ^ 0.94811) ^ -0...
#                                       .71892) / 0.24589) + 0.24589) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.020e+03
# Progress: 133 / 800 total iterations (16.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# 19          7.739e-02  5.973e-05  y = (((((x₀ * ((x₁ - -0.56507) ^ 0.48008)) ^ 0.94811) ^ -0...
#                                       .71892) / 0.24589) + 0.24589) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.230e+03
# Progress: 138 / 800 total iterations (17.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# 19          7.739e-02  5.973e-05  y = (((((x₀ * ((x₁ - -0.56507) ^ 0.48008)) ^ 0.94811) ^ -0...
#                                       .71892) / 0.24589) + 0.24589) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.340e+03
# Progress: 142 / 800 total iterations (17.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          8.057e-02  3.537e-02  y = (0.24589 + (((x₀ * (x₁ ^ 0.48008)) ^ -0.71892) / 0.245...
#                                       89)) - -0.31959
# 17          7.740e-02  2.006e-02  y = (0.24589 + ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71...
#                                       892) / 0.24589)) - -0.31959
# 19          7.739e-02  7.520e-05  y = (((((x₀ * ((x₁ - -0.71892) ^ 0.48008)) ^ 0.94811) ^ -0...
#                                       .71892) / 0.24589) + 0.24589) - -0.31959
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.460e+03
# Progress: 145 / 800 total iterations (18.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          7.781e-02  5.279e-02  y = (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.726e-02  3.528e-03  y = (0.24589 + ((((x₁ ^ 0.48008) * x₀) ^ -0.71892) / 0.245...
#                                       89)) - (-0.31959 * 1.1993)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.210e+03
# Progress: 148 / 800 total iterations (18.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.647e-02  2.443e-02  y = (((x₀ * (x₁ ^ 0.24834)) ^ 0.76232) ^ -1.2064) - -0.900...
#                                       12
# 15          7.781e-02  5.279e-02  y = (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.725e-02  3.611e-03  y = ((0.24589 - -0.31959) / 0.91411) + (((x₀ * (x₁ ^ 0.480...
#                                       08)) ^ -0.71892) / 0.24589)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.750e+03
# Progress: 156 / 800 total iterations (19.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.097e-02  3.758e-02  y = ((((x₁ ^ 0.2381) + -1.1372) * x₀) ^ -0.76636) + 0.6981...
#                                       4
# 15          7.781e-02  1.992e-02  y = (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.725e-02  3.611e-03  y = ((0.24589 - -0.31959) / 0.91411) + (((x₀ * (x₁ ^ 0.480...
#                                       08)) ^ -0.71892) / 0.24589)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.260e+03
# Progress: 161 / 800 total iterations (20.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.097e-02  3.758e-02  y = ((((x₁ ^ 0.2381) + -1.1372) * x₀) ^ -0.76636) + 0.6981...
#                                       4
# 15          7.781e-02  1.992e-02  y = (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.725e-02  3.611e-03  y = ((0.24589 - -0.31959) / 0.91411) + (((x₀ * (x₁ ^ 0.480...
#                                       08)) ^ -0.71892) / 0.24589)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.300e+03
# Progress: 164 / 800 total iterations (20.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.097e-02  3.758e-02  y = ((((x₁ ^ 0.2381) + -1.1372) * x₀) ^ -0.76636) + 0.6981...
#                                       4
# 15          7.781e-02  1.992e-02  y = (((x₀ * ((x₁ ^ 0.48008) ^ 0.94811)) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.725e-02  3.611e-03  y = ((0.24589 - -0.31959) / 0.91411) + (((x₀ * (x₁ ^ 0.480...
#                                       08)) ^ -0.71892) / 0.24589)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.040e+03
# Progress: 166 / 800 total iterations (20.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.097e-02  3.758e-02  y = ((((x₁ ^ 0.2381) + -1.1372) * x₀) ^ -0.76636) + 0.6981...
#                                       4
# 15          7.740e-02  2.255e-02  y = ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.725e-02  9.802e-04  y = ((0.24589 - -0.31959) / 0.91411) + (((x₀ * (x₁ ^ 0.480...
#                                       08)) ^ -0.71892) / 0.24589)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+03
# Progress: 170 / 800 total iterations (21.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.097e-02  3.758e-02  y = ((((x₁ ^ 0.2381) + -1.1372) * x₀) ^ -0.76636) + 0.6981...
#                                       4
# 15          7.740e-02  2.255e-02  y = ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.725e-02  9.802e-04  y = ((0.24589 - -0.31959) / 0.91411) + (((x₀ * (x₁ ^ 0.480...
#                                       08)) ^ -0.71892) / 0.24589)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.790e+03
# Progress: 171 / 800 total iterations (21.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 13          8.097e-02  3.758e-02  y = ((((x₁ ^ 0.2381) + -1.1372) * x₀) ^ -0.76636) + 0.6981...
#                                       4
# 15          7.740e-02  2.255e-02  y = ((((x₀ * (x₁ ^ 0.48008)) ^ 0.94811) ^ -0.71892) / 0.24...
#                                       589) + 0.56548
# 17          7.725e-02  9.802e-04  y = ((0.24589 - -0.31959) / 0.91411) + (((x₀ * (x₁ ^ 0.480...
#                                       08)) ^ -0.71892) / 0.24589)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+03
# Progress: 173 / 800 total iterations (21.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ...
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.650e+03
# Progress: 766 / 800 total iterations (95.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.120e+03
# Progress: 768 / 800 total iterations (96.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.520e+03
# Progress: 770 / 800 total iterations (96.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.770e+03
# Progress: 776 / 800 total iterations (97.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.710e+03
# Progress: 780 / 800 total iterations (97.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.990e+03
# Progress: 784 / 800 total iterations (98.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.350e+03
# Progress: 791 / 800 total iterations (98.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.090e+03
# Progress: 796 / 800 total iterations (99.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.134e-01  0.000e+00  y = 1.2018
# 6           9.779e-02  2.966e-02  y = (x₀ * -0.36795) + 1.5319
# 8           9.771e-02  4.408e-04  y = (2.2663 - (x₀ ^ 0.61305)) ^ 0.62585
# 9           8.603e-02  1.272e-01  y = 0.8822 + ((x₁ ^ -0.22869) / x₀)
# 11          8.583e-02  1.176e-03  y = (((x₁ + -5.7822) ^ -0.22869) / x₀) + 0.8822
# 13          7.743e-02  5.149e-02  y = ((((x₁ ^ 0.52693) * x₀) ^ -0.75108) / 0.18818) + 0.654...
#                                       56
# 15          7.664e-02  5.142e-03  y = (((((x₁ ^ 0.50304) * x₀) + -0.54369) ^ -0.85651) / 0.2...
#                                       0023) + 0.75776
# 16          7.656e-02  1.009e-03  y = (((((x₁ ^ 0.5482) + x₀) * x₀) ^ -0.84634) / 0.15185) +...
#                                        0.75058
# 17          7.640e-02  2.156e-03  y = ((((((x₁ / 0.90561) ^ 0.50304) * x₀) + -0.85295) ^ -0....
#                                       85651) / 0.20023) + 0.75776
# 18          7.607e-02  4.291e-03  y = (((((x₀ + (x₁ ^ 0.5091)) * x₀) + -0.85162) ^ -0.84864)...
#                                        / 0.20352) + 0.76657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# global: 1568.5715761184692 s
#   - outputs/20250921_190711_Kk8jTp/hall_of_fame.csv

# %%
# Laminar
lam = None
if len(df_lam) > 0:
    X_lam, y_lam = XY(df_lam)
    lam = new_model(); t0=time.time(); lam.fit(X_lam, y_lam); print("laminar:", time.time()-t0, "s")
else:
    print("[aviso] subset laminar vacío; fallback=global")
# Out:
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 7.070e+03
# Progress: 5 / 800 total iterations (0.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.637e-02  3.400e-02  y = (x₀ ^ -0.28713) + 0.14324
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.900e+03
# Progress: 9 / 800 total iterations (1.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 11          9.628e-02  1.409e-04  y = ((x₂ ^ -0.024979) * (x₀ ^ -0.25431)) * 1.1395
# 15          9.404e-02  5.878e-03  y = ((x₁ ^ -0.27722) / (x₀ ^ 0.68619)) + (x₂ / x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.910e+03
# Progress: 11 / 800 total iterations (1.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 11          9.628e-02  1.409e-04  y = ((x₂ ^ -0.024979) * (x₀ ^ -0.25431)) * 1.1395
# 15          9.404e-02  5.878e-03  y = ((x₁ ^ -0.27722) / (x₀ ^ 0.68619)) + (x₂ / x₂)
# 16          8.804e-02  6.594e-02  y = (x₂ / x₂) + (((x₀ * x₁) ^ -0.27722) / x₀)
# 18          8.325e-02  2.799e-02  y = x₂ / (x₂ + (((x₂ * (x₁ ^ -0.27722)) / x₀) / -1.2647))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.590e+03
# Progress: 14 / 800 total iterations (1.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 11          9.628e-02  1.409e-04  y = ((x₂ ^ -0.024979) * (x₀ ^ -0.25431)) * 1.1395
# 15          9.404e-02  5.878e-03  y = ((x₁ ^ -0.27722) / (x₀ ^ 0.68619)) + (x₂ / x₂)
# 16          8.804e-02  6.594e-02  y = (x₂ / x₂) + (((x₀ * x₁) ^ -0.27722) / x₀)
# 17          8.752e-02  5.958e-03  y = ((x₁ ^ -0.27722) / x₀) + (((x₂ / x₀) ^ 0.51776) ^ 0.13...
#                                       505)
# 18          8.325e-02  5.002e-02  y = x₂ / (x₂ + (((x₂ * (x₁ ^ -0.27722)) / x₀) / -1.2647))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.910e+03
# Progress: 20 / 800 total iterations (2.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 11          9.046e-02  1.260e-02  y = (0.51776 ^ 0.13505) + ((x₁ ^ -0.27722) / x₀)
# 12          8.941e-02  1.165e-02  y = (x₂ ^ 0.13505) + ((x₁ ^ -0.27722) / x₀)
# 13          8.838e-02  1.166e-02  y = ((x₁ ^ -0.27722) / x₀) + (x₂ / x₂)
# 14          8.757e-02  9.136e-03  y = ((x₀ ^ -0.46939) ^ 0.13505) + ((x₁ ^ -0.27722) / x₀)
# 15          8.612e-02  1.677e-02  y = ((x₀ + x₀) ^ -0.11187) + ((x₁ ^ -0.27722) / x₀)
# 17          8.309e-02  1.790e-02  y = ((x₁ ^ -0.19373) / x₀) + ((x₁ + (x₀ * 0.63901)) ^ -0.0...
#                                       34758)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.510e+03
# Progress: 30 / 800 total iterations (3.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.838e-02  2.158e-02  y = (x₀ + (x₁ ^ -0.27722)) / x₀
# 13          8.745e-02  3.535e-03  y = ((0.51776 ^ 0.13505) + ((x₁ ^ -0.27722) / x₀)) / 0.971...
#                                       6
# 15          8.612e-02  7.649e-03  y = ((x₀ + x₀) ^ -0.11187) + ((x₁ ^ -0.27722) / x₀)
# 17          8.309e-02  1.790e-02  y = ((x₁ ^ -0.19373) / x₀) + ((x₁ + (x₀ * 0.63901)) ^ -0.0...
#                                       34758)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.980e+03
# Progress: 37 / 800 total iterations (4.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.838e-02  2.158e-02  y = (x₀ + (x₁ ^ -0.27722)) / x₀
# 13          8.745e-02  3.535e-03  y = ((0.51776 ^ 0.13505) + ((x₁ ^ -0.27722) / x₀)) / 0.971...
#                                       6
# 14          8.583e-02  1.869e-02  y = ((x₀ + 0.27509) ^ -0.11187) + ((x₁ ^ -0.27722) / x₀)
# 17          8.309e-02  1.080e-02  y = ((x₁ ^ -0.19373) / x₀) + ((x₁ + (x₀ * 0.63901)) ^ -0.0...
#                                       34758)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.880e+03
# Progress: 42 / 800 total iterations (5.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.836e-02  2.163e-02  y = (x₀ + (x₁ ^ -0.282)) / x₀
# 13          8.745e-02  3.461e-03  y = ((0.51776 ^ 0.13505) + ((x₁ ^ -0.27722) / x₀)) / 0.971...
#                                       6
# 14          8.583e-02  1.869e-02  y = ((x₀ + 0.27509) ^ -0.11187) + ((x₁ ^ -0.27722) / x₀)
# 17          8.309e-02  1.080e-02  y = ((x₁ ^ -0.19373) / x₀) + ((x₁ + (x₀ * 0.63901)) ^ -0.0...
#                                       34758)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.030e+03
# Progress: 47 / 800 total iterations (5.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.836e-02  2.163e-02  y = (x₀ + (x₁ ^ -0.282)) / x₀
# 13          8.732e-02  3.944e-03  y = (x₀ + ((x₀ * x₁) ^ -0.282)) / x₀
# 14          8.583e-02  1.725e-02  y = ((x₀ + 0.27509) ^ -0.11187) + ((x₁ ^ -0.27722) / x₀)
# 17          8.309e-02  1.080e-02  y = ((x₁ ^ -0.19373) / x₀) + ((x₁ + (x₀ * 0.63901)) ^ -0.0...
#                                       34758)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.880e+03
# Progress: 51 / 800 total iterations (6.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.836e-02  2.163e-02  y = (x₀ + (x₁ ^ -0.282)) / x₀
# 11          8.477e-02  4.148e-02  y = ((x₁ ^ -0.25085) / (x₀ - 0.056988)) + 0.90073
# 13          8.151e-02  1.963e-02  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.050e+03
# Progress: 55 / 800 total iterations (6.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.836e-02  2.163e-02  y = (x₀ + (x₁ ^ -0.282)) / x₀
# 11          8.477e-02  4.148e-02  y = ((x₁ ^ -0.25085) / (x₀ - 0.056988)) + 0.90073
# 13          8.151e-02  1.963e-02  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.880e+03
# Progress: 62 / 800 total iterations (7.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.836e-02  2.163e-02  y = (x₀ + (x₁ ^ -0.282)) / x₀
# 11          8.477e-02  4.148e-02  y = ((x₁ ^ -0.25085) / (x₀ - 0.056988)) + 0.90073
# 13          8.151e-02  1.963e-02  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.880e+03
# Progress: 68 / 800 total iterations (8.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.836e-02  2.163e-02  y = (x₀ + (x₁ ^ -0.282)) / x₀
# 11          8.477e-02  4.148e-02  y = ((x₁ ^ -0.25085) / (x₀ - 0.056988)) + 0.90073
# 13          8.151e-02  1.963e-02  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.670e+03
# Progress: 78 / 800 total iterations (9.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2046
# 6           9.635e-02  3.404e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.030e+04
# Progress: 90 / 800 total iterations (11.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.134e-01  2.390e-03  y = x₀ ^ -0.43007
# 6           9.635e-02  8.152e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.630e+03
# Progress: 96 / 800 total iterations (12.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.134e-01  2.390e-03  y = x₀ ^ -0.43007
# 6           9.635e-02  8.152e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.120e+04
# Progress: 105 / 800 total iterations (13.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.134e-01  2.390e-03  y = x₀ ^ -0.43007
# 6           9.635e-02  8.152e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.040e+04
# Progress: 113 / 800 total iterations (14.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.090e+04
# Progress: 122 / 800 total iterations (15.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.090e+04
# Progress: 133 / 800 total iterations (16.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.150e+04
# Progress: 139 / 800 total iterations (17.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.144e-02  4.185e-04  y = ((((1.6429 * (x₁ ^ -0.30261)) / x₀) - 0.043164) + 0.52...
#                                       046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.080e+04
# Progress: 144 / 800 total iterations (18.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 18          8.091e-02  1.305e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ - (-0.1178 / x₂))) ...
#                                       + 0.52046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.520e+03
# Progress: 145 / 800 total iterations (18.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 10          8.835e-02  2.165e-02  y = ((x₁ ^ -0.28042) + x₀) / x₀
# 11          8.209e-02  7.346e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 18          8.091e-02  1.305e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ - (-0.1178 / x₂))) ...
#                                       + 0.52046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.500e+03
# Progress: 149 / 800 total iterations (18.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 9           8.494e-02  4.201e-02  y = ((x₁ ^ -0.21874) / x₀) + 0.86789
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 18          8.091e-02  1.305e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ - (-0.1178 / x₂))) ...
#                                       + 0.52046) * 1.5042
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.100e+03
# Progress: 158 / 800 total iterations (19.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 9           8.494e-02  4.201e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 18          8.075e-02  1.973e-03  y = (((x₁ ^ -0.2075) / x₀) + (((x₁ ^ -0.31523) ^ 0.55326) ...
#                                       + 0.46238)) + 0.037782
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.120e+03
# Progress: 159 / 800 total iterations (19.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 9           8.494e-02  4.201e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 18          8.075e-02  1.973e-03  y = (((x₁ ^ -0.2075) / x₀) + (((x₁ ^ -0.31523) ^ 0.55326) ...
#                                       + 0.46238)) + 0.037782
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.770e+03
# Progress: 162 / 800 total iterations (20.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.635e-02  7.929e-02  y = (x₀ ^ -0.25428) * 1.1437
# 9           8.494e-02  4.201e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 18          8.075e-02  1.973e-03  y = (((x₁ ^ -0.2075) / x₀) + (((x₁ ^ -0.31523) ^ 0.55326) ...
#                                       + 0.46238)) + 0.037782
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.960e+03
# Progress: 165 / 800 total iterations (20.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 18          8.075e-02  1.973e-03  y = (((x₁ ^ -0.2075) / x₀) + (((x₁ ^ -0.31523) ^ 0.55326) ...
#                                       + 0.46238)) + 0.037782
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.460e+03
# Progress: 168 / 800 total iterations (21.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 16          8.117e-02  7.354e-04  y = (x₂ * -0.060437) + ((((x₁ ^ -0.28007) * 1.7855) / x₀) ...
#                                       + 0.83681)
# 18          7.864e-02  1.582e-02  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.550e+03
# Progress: 171 / 800 total iterations (21.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 16          8.117e-02  7.354e-04  y = (x₂ * -0.060437) + ((((x₁ ^ -0.28007) * 1.7855) / x₀) ...
#                                       + 0.83681)
# 18          7.864e-02  1.582e-02  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.510e+03
# Progress: 179 / 800 total iterations (22.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 16          8.117e-02  7.354e-04  y = (x₂ * -0.060437) + ((((x₁ ^ -0.28007) * 1.7855) / x₀) ...
#                                       + 0.83681)
# 18          7.864e-02  1.582e-02  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.390e+03
# Progress: 187 / 800 total iterations (23.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 16          8.117e-02  7.354e-04  y = (x₂ * -0.060437) + ((((x₁ ^ -0.28007) * 1.7855) / x₀) ...
#                                       + 0.83681)
# 18          7.864e-02  1.582e-02  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.260e+03
# Progress: 198 / 800 total iterations (24.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.123e-02  1.714e-03  y = (((1.6429 * (x₁ ^ -0.30261)) / (x₀ + 0.043164)) + 0.52...
#                                       046) * 1.5042
# 16          8.117e-02  7.354e-04  y = (x₂ * -0.060437) + ((((x₁ ^ -0.28007) * 1.7855) / x₀) ...
#                                       + 0.83681)
# 18          7.864e-02  1.582e-02  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.620e+03
# Progress: 205 / 800 total iterations (25.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.091e-02  3.691e-03  y = (((1.6429 * ((x₁ ^ -0.30261) / x₀)) + 0.52046) * 1.504...
#                                       2) ^ 0.83784
# 18          7.864e-02  9.472e-03  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.680e+03
# Progress: 213 / 800 total iterations (26.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.091e-02  3.691e-03  y = (((1.6429 * ((x₁ ^ -0.30261) / x₀)) + 0.52046) * 1.504...
#                                       2) ^ 0.83784
# 18          7.864e-02  9.472e-03  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.090e+04
# Progress: 224 / 800 total iterations (28.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.091e-02  3.691e-03  y = (((1.6429 * ((x₁ ^ -0.30261) / x₀)) + 0.52046) * 1.504...
#                                       2) ^ 0.83784
# 18          7.864e-02  9.472e-03  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.650e+03
# Progress: 229 / 800 total iterations (28.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.091e-02  3.691e-03  y = (((1.6429 * ((x₁ ^ -0.30261) / x₀)) + 0.52046) * 1.504...
#                                       2) ^ 0.83784
# 18          7.864e-02  9.472e-03  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# 20          7.864e-02  2.402e-05  y = (((x₂ ^ -0.055311) * 0.68422) + ((((x₁ - 0.1147) ^ -0....
#                                       34755) / x₀) * 2.6009)) + 0.11701
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.200e+03
# Progress: 234 / 800 total iterations (29.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          8.209e-02  1.701e-02  y = (((x₁ ^ -0.30261) / x₀) + 0.52046) * 1.6429
# 13          8.151e-02  3.602e-03  y = (((x₁ ^ -0.30261) / (x₀ - 0.043164)) + 0.52046) * 1.64...
#                                       29
# 15          8.091e-02  3.691e-03  y = (((1.6429 * ((x₁ ^ -0.30261) / x₀)) + 0.52046) * 1.504...
#                                       2) ^ 0.83784
# 18          7.864e-02  9.472e-03  y = (((x₂ ^ -0.055311) * 0.68422) + (((x₁ ^ -0.34755) / x₀...
#                                       ) * 2.6009)) + 0.11701
# 20          7.864e-02  2.402e-05  y = (((x₂ ^ -0.055311) * 0.68422) + ((((x₁ - 0.1147) ^ -0....
#                                       34755) / x₀) * 2.6009)) + 0.11701
# ...
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 18          7.658e-02  1.391e-04  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.220e+03
# Progress: 759 / 800 total iterations (94.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 18          7.658e-02  1.391e-04  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.530e+03
# Progress: 768 / 800 total iterations (96.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 18          7.658e-02  1.391e-04  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.900e+03
# Progress: 771 / 800 total iterations (96.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 18          7.658e-02  1.391e-04  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.310e+03
# Progress: 772 / 800 total iterations (96.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 18          7.658e-02  1.391e-04  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.130e+03
# Progress: 773 / 800 total iterations (96.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 18          7.658e-02  1.391e-04  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.170e+03
# Progress: 778 / 800 total iterations (97.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 18          7.658e-02  1.391e-04  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.780e+03
# Progress: 780 / 800 total iterations (97.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 16          7.659e-02  2.256e-04  y = 0.80848 + (((x₂ * -0.013016) + ((x₁ ^ -0.46759) * 5.59...
#                                       22)) / x₀)
# 18          7.658e-02  9.328e-06  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.490e+03
# Progress: 784 / 800 total iterations (98.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 16          7.659e-02  2.256e-04  y = 0.80848 + (((x₂ * -0.013016) + ((x₁ ^ -0.46759) * 5.59...
#                                       22)) / x₀)
# 18          7.658e-02  9.328e-06  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.320e+03
# Progress: 789 / 800 total iterations (98.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 16          7.659e-02  2.256e-04  y = 0.80848 + (((x₂ * -0.013016) + ((x₁ ^ -0.46759) * 5.59...
#                                       22)) / x₀)
# 18          7.658e-02  9.328e-06  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 5.250e+03
# Progress: 796 / 800 total iterations (99.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 16          7.659e-02  2.256e-04  y = 0.80848 + (((x₂ * -0.013016) + ((x₁ ^ -0.46759) * 5.59...
#                                       22)) / x₀)
# 18          7.658e-02  9.328e-06  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.180e+03
# Progress: 799 / 800 total iterations (99.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 16          7.659e-02  2.256e-04  y = 0.80848 + (((x₂ * -0.013016) + ((x₁ ^ -0.46759) * 5.59...
#                                       22)) / x₀)
# 18          7.658e-02  9.328e-06  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.142e-01  0.000e+00  y = 1.2045
# 4           1.129e-01  3.877e-03  y = x₀ ^ -0.39416
# 6           9.626e-02  7.975e-02  y = 2.1531 - (x₀ ^ 0.3496)
# 9           8.494e-02  4.171e-02  y = ((x₁ ^ -0.21885) / x₀) + 0.86794
# 11          7.667e-02  5.120e-02  y = (((x₁ ^ -0.47097) * 5.5922) / x₀) + 0.80227
# 13          7.664e-02  2.027e-04  y = (((x₁ ^ -0.46759) + -0.0016229) * (5.5539 / x₀)) + 0.8...
#                                       0848
# 16          7.659e-02  2.256e-04  y = 0.80848 + (((x₂ * -0.013016) + ((x₁ ^ -0.46759) * 5.59...
#                                       22)) / x₀)
# 18          7.658e-02  9.328e-06  y = (((x₁ ^ -0.4701) * (5.595 / x₀)) + ((x₂ ^ -0.39205) * ...
#                                       0.091584)) + 0.7032
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# laminar: 1136.8286819458008 s
#   - outputs/20250921_193319_KojOg7/hall_of_fame.csv

# %%
# Turbulento
tur = None
if len(df_tur) > 0:
    X_tur, y_tur = XY(df_tur)
    tur = new_model(); t0=time.time(); tur.fit(X_tur, y_tur); print("turbulento:", time.time()-t0, "s")
else:
    print("[aviso] subset turbulento vacío; fallback=global")
# Out:
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/darylclerc/opt/anaconda3/envs/el4203/lib/python3.12/site-packages/pysr/sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 3.940e+05
# Progress: 317 / 800 total iterations (39.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.196e-03  0.000e+00  y = 0.98164
# 4           7.831e-03  1.520e-02  y = x₂ ^ 0.11816
# 6           7.715e-03  7.437e-03  y = (x₂ * 0.14021) + 0.84993
# 9           7.686e-03  1.265e-03  y = (x₂ * (x₂ + -1.3568)) - -1.3493
# 10          7.676e-03  1.263e-03  y = ((-1.32 - (-1.5162 / x₂)) * 6.5243) ^ -0.035461
# 17          7.660e-03  3.007e-04  y = (((0.25787 + (x₀ ^ -2.3955)) * ((x₂ ^ -2.0811) - 0.879...
#                                       57)) - 0.87957) ^ -0.017507
# 18          7.660e-03  3.219e-06  y = (((x₀ + (x₀ ^ -2.3955)) * ((x₂ ^ -2.0811) - 0.87957)) ...
#                                       - 0.87957) ^ -0.017507
# 19          7.647e-03  1.677e-03  y = (((((x₂ ^ -2.0811) - 0.87957) * ((-0.046806 + x₀) ^ -2...
#                                       .0811)) - 0.87957) ^ -0.017507) ^ 1.1564
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.140e+05
# Progress: 646 / 800 total iterations (80.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.196e-03  0.000e+00  y = 0.98164
# 4           7.831e-03  1.520e-02  y = x₂ ^ 0.11816
# 6           7.715e-03  7.437e-03  y = (x₂ * 0.14021) + 0.84993
# 9           7.686e-03  1.265e-03  y = (x₂ * (x₂ + -1.3568)) - -1.3493
# 10          7.676e-03  1.263e-03  y = ((-1.32 - (-1.5162 / x₂)) * 6.5243) ^ -0.035461
# 11          7.675e-03  1.031e-04  y = ((x₂ * (x₂ + -1.3568)) - -1.3493) ^ 0.87174
# 15          7.660e-03  4.909e-04  y = (((x₀ ^ -2.3955) * ((x₂ ^ -2.0811) - 0.87957)) - 0.889...
#                                       75) ^ -0.017507
# 16          7.631e-03  3.760e-03  y = ((((((x₂ + 0.35551) - 1.2212) + -0.20423) / -0.055852)...
#                                        ^ -0.15226) ^ -0.12757) ^ -1.9131
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.196e-03  0.000e+00  y = 0.98164
# 4           7.831e-03  1.520e-02  y = x₂ ^ 0.11816
# 6           7.715e-03  7.437e-03  y = (x₂ * 0.14021) + 0.84993
# 9           7.686e-03  1.265e-03  y = (x₂ * (x₂ + -1.3568)) - -1.3493
# 10          7.676e-03  1.263e-03  y = ((-1.32 - (-1.5162 / x₂)) * 6.5243) ^ -0.035461
# 11          7.675e-03  1.031e-04  y = ((x₂ * (x₂ + -1.3568)) - -1.3493) ^ 0.87174
# 13          7.675e-03  1.222e-05  y = (((x₂ * (x₂ + -1.3568)) - -1.3493) ^ 0.87174) ^ 1.0054
# 15          7.660e-03  9.696e-04  y = (((x₀ ^ -2.3955) * ((x₂ ^ -2.0811) - 0.87957)) - 0.889...
#                                       75) ^ -0.017507
# 16          7.631e-03  3.760e-03  y = ((((((x₂ + 0.35551) - 1.2212) + -0.20423) / -0.055852)...
#                                        ^ -0.15226) ^ -0.12757) ^ -1.9131
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# turbulento: 12.835418939590454 s
#   - outputs/20250921_195216_rl14CH/hall_of_fame.csv

# %%
from sklearn.metrics import mean_squared_error, r2_score

def predict_piecewise(d):
    re = d["Re"].to_numpy()
    X  = d[FEATURES].to_numpy()
    yhat = np.empty(len(d))
    mask_l = re < (UMBRAL - BANDA)
    mask_t = re > (UMBRAL + BANDA)
    mask_m = ~(mask_l | mask_t)
    yhat[mask_l] = (lam or mid).predict(X[mask_l])
    yhat[mask_t] = (tur or mid).predict(X[mask_t])
    yhat[mask_m] = mid.predict(X[mask_m])
    return yhat

X_te, y_te = XY(df_ff_test)
yhat_mid   = mid.predict(X_te)
yhat_piece = predict_piecewise(df_ff_test)

print("TEST Global   : MSE=%.4f  R2=%.4f" % (mean_squared_error(y_te, yhat_mid),   r2_score(y_te, yhat_mid)))
print("TEST Piecewise: MSE=%.4f  R2=%.4f" % (mean_squared_error(y_te, yhat_piece), r2_score(y_te, yhat_piece)))
# Out:
# TEST Global   : MSE=0.0722  R2=0.2695
# TEST Piecewise: MSE=0.0822  R2=0.1684

# %%
# rutas de hall_of_fame para friction factor (ff)
paths = {
    "Global": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_190711_Kk8jTp/hall_of_fame.csv",
    "Re<2000": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_193319_KojOg7/hall_of_fame.csv",
    "Re>2000": "/Users/darylclerc/Desktop/Computacion Evolutiva/outputs/20250921_195216_rl14CH/hall_of_fame.csv"
}

resumen = []
for nombre, path in paths.items():
    hof = pd.read_csv(path)
    prom = hof["Loss"].mean()
    std  = hof["Loss"].std()
    best = hof.sort_values("Loss").iloc[0]["Loss"]
    resumen.append({
        "Caso": nombre,
        "Loss_promedio": prom,
        "Loss_std": std,
        "Mejor_Loss": best
    })

df_resumen = pd.DataFrame(resumen)
print(df_resumen)
# Out:
#       Caso  Loss_promedio  Loss_std  Mejor_Loss
# 0   Global       0.086389  0.012769    0.076071
# 1  Re<2000       0.089349  0.016427    0.076584
# 2  Re>2000       0.007749  0.000177    0.007631

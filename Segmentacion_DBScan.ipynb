# %% [markdown]
# # Experimentos con Datos con Desgaste
# #### Estudiantes: Matías Carvajal y Daryl Clerc
# #### Profesores: Pablo Estévez, Jorge Vergara
# #### EL7037 - Primavera 2025

# %% [markdown]
# ## Librerías y Funciones Iniciales

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import numpy as np
import sympy as sp

# %%
from sklearn.metrics import mean_squared_error

def eval_equations(x, y, equations):
    """
    Evalúa una lista de expresiones matemáticas contra los datos y calcula el MSE para cada una.

    :param x: dataframe con las variables
    :param y: variable objetivo
    :param equations: dataframe/lista con las expresiones obtenidas
    :return: lista de tuplas (expresión, MSE) ordenadas de menor a mayor MSE.
    """
    resultados = []

    for eq in equations:
        try:
            float(eq)
            resultados.append(np.inf)
        except ValueError:
            y_pred = eval(eq, {"__builtins__": {}, "np": np}, x.to_dict(orient='series'))
            mse = mean_squared_error(y, y_pred)
            resultados.append(mse)

    return pd.DataFrame({'expresiones': equations, 'mse': resultados})

# %%
def get_general_metrics(y_pred, y_true):
    """
    Calcula las métricas de error RMSE, MAE y SMAPE, junto con su desviación estándar.
    :param y_pred: Arreglo con los valores predichos por la ecuación obtenida.
    :param y_true: Arreglo con los valores reales de la variable.
    :return: Retorna un diccionario, donde los values son una tupla con el valor de la métrica
             y la desviación estándar; y las keys son los strings de las métricas calculadas
             i.e. 'RMSE', 'MAE, 'SMAPE'.
    """

    # Cálculo de errores
    errores_rmse = (y_true - y_pred) ** 2
    errores_mae = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2 + 1e-6
    errores_smape = (np.abs(y_true - y_pred) / denominator) * 100

    # Cálculo de métricas
    rmse = np.round(np.sqrt(np.mean(errores_rmse)), 2)
    mae = np.round(np.mean(errores_mae), 2)
    smape = np.round(np.mean(errores_smape), 2)

    # Cálculo de desviaciones estándar
    std_rmse = np.round(np.std(np.sqrt(errores_rmse)), 2)
    std_mae = np.round(np.std(errores_mae), 2)
    std_smape = np.round(np.std(errores_smape), 2)

    # Retorna un diccionario con las métricas y sus desviaciones estándar
    return {
        "RMSE": (float(rmse), float(std_rmse)),
        "MAE": (float(mae), float(std_mae)),
        "SMAPE": (float(smape), float(std_smape))
    }

# %% [markdown]
# ## Número de Nusselt

# %% [markdown]
# ### Base de datos y Exploración

# %%
x_train = pd.read_csv(r'.\DATA_LIB_Degradation\df_n_train_des.txt')
y_train = x_train['nusselt']
x_train = x_train.drop('nusselt', axis=1)
print('x_train:')
display(x_train.head())
print('y_train:', y_train.to_numpy()[: 5])
# Out:
# x_train:
#           S          Re        Pr     SoH
# 0  0.280625  212.041256  0.709840  0.6363
# 1  0.280625  212.041256  0.707471  1.0000
# 2  0.280625  197.894331  0.706170  1.0000
# 3  0.344410  188.969448  0.708576  0.6363
# 4  0.344410  188.969448  0.704657  1.0000
# y_train: [12.63272114 13.64363625 14.81134875 11.75386263 12.61276223]

# %%
x_min, x_max = x_train.min(), x_train.max()
xn_train = (x_train - x_min) / (x_max - x_min)
xn_train.head()
# Out:
#           S        Re        Pr       SoH
# 0  0.000000  0.078191  0.949814  0.333272
# 1  0.000000  0.078191  0.818411  1.000000
# 2  0.000000  0.072269  0.746265  1.000000
# 3  0.052307  0.068533  0.879694  0.333272
# 4  0.052307  0.068533  0.662373  1.000000

# %%
x_val = pd.read_csv(r'.\DATA_LIB_Degradation\df_n_val_des.txt')
y_val = x_val['nusselt']
x_val = x_val.drop('nusselt', axis=1)
xn_val = (x_val - x_min) / (x_max - x_min)
xn_val.head()
# Out:
#    Pr        Re         S       SoH
# 0 NaN  0.287809  0.621218  0.666544
# 1 NaN  0.287809  0.621218  0.666544
# 2 NaN  0.265003  0.621218  1.000000
# 3 NaN  0.259899  0.621218  1.000000
# 4 NaN  0.249387  0.621218  1.000000

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

ax[0].scatter(x_train['Re'], y_train, marker='.', c=x_train['S'])
ax[0].set_xlabel('Re')
ax[0].set_ylabel('Nu')

ax[1].scatter(x_train['S'], y_train, marker='.', c=x_train['Re'], cmap='magma')
ax[1].set_xlabel('S')
ax[1].set_ylabel('Nu')

fig.suptitle('Número de Nusselt (Train)')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

ax[0].scatter(x_val['Re'], y_val, marker='.', c=x_val['S'])
ax[0].set_xlabel('Re')
ax[0].set_ylabel('Nu')

ax[1].scatter(x_val['S'], y_val, marker='.', c=x_val['Re'], cmap='magma')
ax[1].set_xlabel('S')
ax[1].set_ylabel('Nu')

fig.suptitle('Número de Nusselt (Val)')
plt.show()

# %%
print(len(np.unique(x_train['S'])))
# Out:
# 50

# %% [markdown]
# ### Segmentación con DB-Scan

# %%
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors

fig, ax = plt.subplots(1, 3, figsize=(12, 3))

k = 5  # usado como min_samples en DBSCAN
neighbors = NearestNeighbors(n_neighbors=k)
neighbors_fit = neighbors.fit(xn_train)
distances, _ = neighbors_fit.kneighbors(xn_train)
k_distances = np.sort(distances[:, k - 1])  # Ordenar las distancias al k-ésimo vecino

ax[0].plot(k_distances)
ax[0].set_ylabel(f'Distancia al {k}-ésimo vecino')
ax[0].set_xlabel('Puntos ordenados')
ax[0].set_title(f'Gráfico de codo con k = {k}')
ax[0].grid(True)

k = 15  # usado como min_samples en DBSCAN
neighbors = NearestNeighbors(n_neighbors=k)
neighbors_fit = neighbors.fit(xn_train)
distances, _ = neighbors_fit.kneighbors(xn_train)
k_distances = np.sort(distances[:, k - 1])  # Ordenar las distancias al k-ésimo vecino

ax[1].plot(k_distances)
ax[1].set_ylabel(f'Distancia al {k}-ésimo vecino')
ax[1].set_xlabel('Puntos ordenados')
ax[1].set_title(f'Gráfico de codo con k = {k}')
ax[1].grid(True)

k = 200  # usado como min_samples en DBSCAN
neighbors = NearestNeighbors(n_neighbors=k)
neighbors_fit = neighbors.fit(xn_train)
distances, _ = neighbors_fit.kneighbors(xn_train)
k_distances = np.sort(distances[:, k - 1])  # Ordenar las distancias al k-ésimo vecino

ax[2].plot(k_distances)
ax[2].set_ylabel(f'Distancia al {k}-ésimo vecino')
ax[2].set_xlabel('Puntos ordenados')
ax[2].set_title(f'Gráfico de codo con k = {k}')
ax[2].grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import DBSCAN

clustering = DBSCAN(eps=10, min_samples=200).fit(x_train)
clusters = clustering.labels_
print('clusters =', np.unique(clusters).shape[0])
print(np.unique(clusters, return_counts=True))
# Out:
# clusters = 4
# (array([-1,  0,  1,  2]), array([3292, 5430, 4162,  593]))

# %%
# Graficar cada cluster por separado
for i in np.unique(clusters)[1: ]:
    idx = clusters == i
    label = f'Cluster {i + 1}'
    plt.scatter(x_train['Re'][idx], y_train[idx], marker='.', label=label)

plt.grid()
plt.ylabel('Nusselt')
plt.xlabel('Reynolds')
plt.title(f'Clustering con DBSCAN para {np.unique(clusters).shape[0] - 1} clusters')
plt.show()

# %% [markdown]
# ### Segmentación con Arboles

# %%
from sklearn.tree import DecisionTreeRegressor

reg = DecisionTreeRegressor(
    max_depth=2,
    min_samples_leaf=2500,
    random_state=42
)
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, min_samples_leaf=2500, random_state=42)

# %%
from sklearn.tree import plot_tree

plot_tree(
    reg,
    feature_names=x_train.columns,
    filled=True,
    rounded=True
)
plt.tight_layout()
plt.show()

# %%
plt.scatter(x_train['S'], x_train['Re'], marker='.')
plt.axvline(x=1.243, color='red', linestyle='--', label='S = 1.243')
plt.plot([x_train['S'].min(), 1.243], [449.228, 449.228], color='green', linestyle='--', label='Re = 449.228')
plt.legend()
plt.show()

# %%
plt.plot(x_train['S'], y_train, '.')
plt.axvline(x=1.243, color='red', linestyle='--', label='S = 1.243')
plt.legend()
plt.show()

# %%
plt.scatter(x_train['S'], x_train['Re'], marker='.')
plt.axvline(x=1.243, color='red', linestyle='--', label='S = 1.243')
plt.axhline(y=449.228, color='blue', linestyle='--', label='Re = 449.228')
plt.legend()
plt.show()

# %%
plt.hist(y_train)
plt.show()
print(np.mean(y_train), '+/-', np.std(y_train))
# Out:
# 20.01450210170413 +/- 6.74553197442427

# %% [markdown]
# ### Segmentación con otras formas de Clustering

# %%
from sklearn import mixture

gmm = mixture.GaussianMixture(
        n_components=3,
        covariance_type="full",
        random_state=42,
    )

gmm.fit(xn_train)
clusters = gmm.predict(xn_train)
print('clusters =', np.unique(clusters, return_counts=True))
# Out:
# clusters = (array([0, 1, 2]), array([5248, 4499, 3730]))

# %%
plt.figure(figsize=(8, 4))
plt.scatter(x_train['Re'], y_train, marker='.', c=clusters)
plt.title('Número de Nusselt (Train) segmentado con Gaussian Mixture')
plt.xlabel('Re')
plt.ylabel('Nu')
plt.show()

# %%
from sklearn import cluster

hdbscan = cluster.HDBSCAN(
    min_samples=20,
    min_cluster_size=15,
    allow_single_cluster=True,
)

hdbscan.fit(xn_train)
clusters = hdbscan.labels_.astype(int)
print('clusters =', np.unique(clusters, return_counts=True))
# Out:
# clusters = (array([-1,  0,  1,  2,  3]), array([  15, 8975, 1495, 1495, 1497]))

# %%
plt.figure(figsize=(8, 4))
plt.scatter(x_train['Re'], y_train, marker='.', c=clusters)
plt.title('Número de Nusselt (Train) segmentado con HDBScan')
plt.xlabel('Re')
plt.ylabel('Nu')
plt.show()

# %% [markdown]
# ### Evolución Grámatica (sin segmentación)

# %%
from time import time
from tqdm import tqdm

from pysr import PySRRegressor

# %%
x_train.rename(columns={'S': 'Se'}, inplace=True)

model = PySRRegressor(
    niterations=200,
    binary_operators=["+","-","*" ,"/", "^"],
    unary_operators=[],
    population_size=50,
    populations=4,
    tournament_selection_n=3,
    verbosity=1,
    maxsize=20,
    parsimony=1e-2,
    constraints={'^':(-1,1)},
    complexity_of_variables=2,
    random_state=0,
    progress=True
)

t0 = time()
model.fit(x_train, y_train)
tf = time()

print(f"Tiempo de ejecución: {tf - t0} [s]")
# Out:
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 3.570e+04
# Progress: 28 / 800 total iterations (3.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.373e+01  1.328e-02  y = Se - -19.136
# 6           4.310e+01  7.215e-03  y = (Se / 0.63556) - -19.136
# 7           4.294e+01  3.756e-03  y = 19.999 + (Se * Se)
# 8           3.779e+01  1.278e-01  y = ((Se + 1.1503) / 0.12772) - -3.86
# 10          3.441e+01  4.676e-02  y = (((Se ^ 4.7925) * 0.59752) + 5.6107) * 3.083
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.680e+04
# Progress: 72 / 800 total iterations (9.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           4.004e+01  4.396e-02  y = 20.036 / (Se ^ -0.27625)
# 8           3.779e+01  2.901e-02  y = ((Se + 1.1503) / 0.12772) - -3.86
# 10          3.441e+01  4.676e-02  y = (((Se ^ 4.7925) * 0.59752) + 5.6107) * 3.083
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.840e+04
# Progress: 111 / 800 total iterations (13.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.812e+01  6.854e-02  y = (1.6375 + Se) / 0.12307
# 8           3.745e+01  8.927e-03  y = ((Se + 2.0431) - -1.6388) ^ 1.9649
# 10          3.441e+01  4.226e-02  y = (((Se ^ 4.7925) * 0.59752) + 5.6107) * 3.083
# 16          3.385e+01  2.747e-03  y = ((((SoH + Se) / (Se ^ -4.4741)) + 6.8302) ^ 0.97171) +...
#                                        10.812
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.730e+04
# Progress: 143 / 800 total iterations (17.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.812e+01  6.854e-02  y = (1.6375 + Se) / 0.12307
# 8           3.745e+01  8.927e-03  y = ((Se + 2.0431) - -1.6388) ^ 1.9649
# 10          3.441e+01  4.226e-02  y = (((Se ^ 4.7925) * 0.59752) + 5.6107) * 3.083
# 12          3.387e+01  7.974e-03  y = ((Se + SoH) / (Se ^ -4.2591)) + 17.229
# 16          3.385e+01  1.324e-04  y = ((((SoH + Se) / (Se ^ -4.4741)) + 6.8302) ^ 0.97171) +...
#                                        10.812
# 20          3.385e+01  3.542e-05  y = ((((SoH + Se) / (Se ^ -4.4741)) + 6.8302) ^ 0.97171) +...
#                                        (10.812 - (0.32476 * -0.24072))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.370e+04
# Progress: 198 / 800 total iterations (24.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.812e+01  6.854e-02  y = (1.6375 + Se) / 0.12307
# 8           3.745e+01  8.927e-03  y = ((Se + 2.0431) - -1.6388) ^ 1.9649
# 9           2.462e+01  4.192e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.460e+01  5.135e-04  y = ((Re + -1.7816) ^ 0.38693) + (Se / 0.10227)
# 13          2.459e+01  1.787e-04  y = ((Re + (0.48698 + -2.8977)) ^ 0.38693) + (Se / 0.10227...
#                                       )
# 15          2.229e+01  4.903e-02  y = ((-4.3427 - -0.77818) + -2.5552) + ((Re ^ 0.42462) + (...
#                                       Se / 0.078449))
# 16          2.216e+01  5.873e-03  y = (-7.0787 - (SoH * 0.11572)) + ((Re ^ 0.43005) + (Se / ...
#                                       0.073078))
# 18          2.200e+01  3.643e-03  y = ((-4.3427 - (SoH * -0.91594)) + -2.5552) + ((Re ^ 0.42...
#                                       462) + (Se / 0.078449))
# 20          2.199e+01  3.544e-04  y = ((-4.3427 - (SoH * (0.74635 / -0.77818))) + -2.5552) +...
#                                        ((Re ^ 0.42462) + (Se / 0.078449))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.920e+04
# Progress: 224 / 800 total iterations (28.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.812e+01  6.854e-02  y = (1.6375 + Se) / 0.12307
# 8           3.745e+01  8.927e-03  y = ((Se + 2.0431) - -1.6388) ^ 1.9649
# 9           2.462e+01  4.192e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.460e+01  5.135e-04  y = ((Re + -1.7816) ^ 0.38693) + (Se / 0.10227)
# 13          2.201e+01  5.567e-02  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.186e+01  2.295e-03  y = (-4.3427 - (1.0911 / SoH)) + ((Se / 0.078449) + (Re ^ ...
#                                       0.42462))
# 18          2.180e+01  1.224e-03  y = (((-4.3427 - (1.0911 / SoH)) - 0.087103) + (Se / 0.078...
#                                       449)) + (Re ^ 0.42462)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.230e+04
# Progress: 238 / 800 total iterations (29.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.812e+01  6.854e-02  y = (1.6375 + Se) / 0.12307
# 8           3.745e+01  8.927e-03  y = ((Se + 2.0431) - -1.6388) ^ 1.9649
# 9           2.462e+01  4.192e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.460e+01  5.135e-04  y = ((Re + -1.7816) ^ 0.38693) + (Se / 0.10227)
# 13          2.201e+01  5.567e-02  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.186e+01  2.295e-03  y = (-4.3427 - (1.0911 / SoH)) + ((Se / 0.078449) + (Re ^ ...
#                                       0.42462))
# 18          2.180e+01  1.224e-03  y = (((-4.3427 - (1.0911 / SoH)) - 0.087103) + (Se / 0.078...
#                                       449)) + (Re ^ 0.42462)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.780e+04
# Progress: 260 / 800 total iterations (32.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.745e+01  7.747e-02  y = (Se + 3.682) ^ 1.9651
# 9           2.462e+01  1.397e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.460e+01  5.135e-04  y = ((Re + -1.7816) ^ 0.38693) + (Se / 0.10227)
# 13          2.201e+01  5.567e-02  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.186e+01  2.295e-03  y = ((-4.3427 - (1.0911 / SoH)) + (Se / 0.078449)) + (Re ^...
#                                        0.42462)
# 18          2.175e+01  2.514e-03  y = (-4.3427 - ((1.0911 / SoH) - -0.23542)) + ((Se / 0.078...
#                                       449) + (Re ^ 0.42462))
# 20          2.161e+01  3.198e-03  y = ((-4.3427 - ((1.0911 / (SoH - 0.14075)) - 0.087103)) +...
#                                        (Se / 0.078449)) + (Re ^ 0.42462)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.240e+04
# Progress: 298 / 800 total iterations (37.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.745e+01  7.747e-02  y = (Se + 3.682) ^ 1.9651
# 9           2.462e+01  1.397e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.457e+01  1.048e-03  y = ((Re ^ 0.38693) + (Se / 0.10227)) + -0.29288
# 13          2.201e+01  5.513e-02  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.130e+01  1.083e-02  y = (Re ^ 0.43428) + ((Se / 0.07116) + ((-2.1828 / SoH) - ...
#                                       5.3934))
# 20          2.037e+01  1.122e-02  y = ((0.078449 + Re) ^ 0.42462) + ((0.59168 * ((Se * Se) /...
#                                        0.078449)) + (-0.23158 - 1.2534))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+04
# Progress: 306 / 800 total iterations (38.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.745e+01  7.747e-02  y = (Se + 3.682) ^ 1.9651
# 9           2.462e+01  1.397e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.457e+01  1.048e-03  y = ((Re ^ 0.38693) + (Se / 0.10227)) + -0.29288
# 13          2.201e+01  5.513e-02  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.130e+01  1.083e-02  y = (Re ^ 0.43428) + ((Se / 0.07116) + ((-2.1828 / SoH) - ...
#                                       5.3934))
# 20          2.037e+01  1.122e-02  y = ((0.078449 + Re) ^ 0.42462) + (((0.59168 * (Se * Se)) ...
#                                       / 0.078449) + (-0.23158 - 1.2534))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.590e+04
# Progress: 354 / 800 total iterations (44.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4771) + 17.788
# 9           2.462e+01  1.106e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.457e+01  1.072e-03  y = -0.18754 + ((Re ^ 0.38693) + (Se / 0.10227))
# 13          2.201e+01  5.511e-02  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.130e+01  1.083e-02  y = (Re ^ 0.43428) + ((Se / 0.07116) + ((-2.1828 / SoH) - ...
#                                       5.3934))
# 20          2.037e+01  1.126e-02  y = ((-0.045006 + (Re ^ 0.42462)) + (((0.59168 * Se) * Se)...
#                                        / 0.078449)) + (-0.23158 - 1.2534)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.870e+04
# Progress: 381 / 800 total iterations (47.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4771) + 17.788
# 9           2.462e+01  1.106e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.205e+01  5.515e-02  y = ((Re ^ 0.43437) + (Se / 0.071357)) + -7.9984
# 13          2.201e+01  1.028e-03  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.130e+01  1.083e-02  y = (Re ^ 0.43428) + ((Se / 0.07116) + ((-2.1828 / SoH) - ...
#                                       5.3934))
# 18          2.037e+01  2.246e-02  y = ((Re ^ 0.42462) + ((0.59168 * (Se * Se)) / 0.078449)) ...
#                                       + (-0.23158 - 1.2534)
# 20          2.037e+01  6.202e-05  y = ((-0.045006 + (Re ^ 0.42462)) + (((0.59168 * Se) * Se)...
#                                        / 0.078449)) + (-0.23158 - 1.2534)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.280e+04
# Progress: 427 / 800 total iterations (53.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4771) + 17.788
# 9           2.462e+01  1.106e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.205e+01  5.515e-02  y = ((Re ^ 0.43437) + (Se / 0.071357)) + -7.9984
# 13          2.201e+01  1.028e-03  y = (((Re - 8.9648) ^ 0.43437) + (Se / 0.071357)) + -7.998...
#                                       4
# 16          2.130e+01  1.083e-02  y = (Re ^ 0.43428) + ((Se / 0.07116) + ((-2.1828 / SoH) - ...
#                                       5.3934))
# 18          2.037e+01  2.246e-02  y = ((Re ^ 0.42462) + ((0.59168 * (Se * Se)) / 0.078449)) ...
#                                       + (-0.23158 - 1.2534)
# 20          2.037e+01  6.202e-05  y = ((-0.045006 + (Re ^ 0.42462)) + (((0.59168 * Se) * Se)...
#                                        / 0.078449)) + (-0.23158 - 1.2534)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.870e+04
# Progress: 456 / 800 total iterations (57.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4771) + 17.788
# 9           2.462e+01  1.106e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.205e+01  5.515e-02  y = ((Re ^ 0.43437) + (Se / 0.071357)) + -7.9984
# 12          2.163e+01  1.928e-02  y = (Re ^ 0.42561) + ((Se / 0.16337) * Se)
# 16          2.130e+01  3.813e-03  y = (Re ^ 0.43428) + ((Se / 0.07116) + ((-2.1828 / SoH) - ...
#                                       5.3934))
# 18          2.037e+01  2.246e-02  y = ((Re ^ 0.42462) + ((0.59168 * (Se * Se)) / 0.078449)) ...
#                                       + (-0.23158 - 1.2534)
# 20          2.037e+01  6.202e-05  y = ((-0.045006 + (Re ^ 0.42462)) + (((0.59168 * Se) * Se)...
#                                        / 0.078449)) + (-0.23158 - 1.2534)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.950e+04
# Progress: 474 / 800 total iterations (59.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4771) + 17.788
# 9           2.462e+01  1.106e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.205e+01  5.515e-02  y = ((Re ^ 0.43437) + (Se / 0.071357)) + -7.9984
# 12          2.157e+01  2.230e-02  y = (Re ^ 0.42462) + ((Se / 0.16337) * Se)
# 14          2.152e+01  1.059e-03  y = ((Re ^ 0.42462) - 0.16359) + ((Se / 0.16337) * Se)
# 16          1.981e+01  4.147e-02  y = (Re ^ 0.42462) + ((Se ^ 1.7775) * (-0.40525 + (Se / 0....
#                                       16337)))
# 20          1.949e+01  4.053e-03  y = (Re ^ 0.42846) + (Se * ((((Se + 4.3572) * Se) + -0.727...
#                                       9) * Se))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.700e+04
# Progress: 527 / 800 total iterations (65.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 9           2.462e+01  1.106e-01  y = (Re ^ 0.38693) + (Se / 0.10227)
# 11          2.205e+01  5.515e-02  y = ((Re ^ 0.43437) + (Se / 0.071357)) + -7.9984
# 12          2.157e+01  2.230e-02  y = (Re ^ 0.42462) + ((Se / 0.16337) * Se)
# 14          2.152e+01  1.059e-03  y = ((Re ^ 0.42462) - 0.16359) + ((Se / 0.16337) * Se)
# 16          1.981e+01  4.147e-02  y = (Re ^ 0.42462) + ((Se ^ 1.7775) * (-0.40525 + (Se / 0....
#                                       16337)))
# 19          1.919e+01  1.048e-02  y = ((((Se / 0.48707) ^ 2.5901) + (Re ^ 0.43015)) + (SoH +...
#                                        -3.0816)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.550e+04
# Progress: 565 / 800 total iterations (70.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 9           2.462e+01  1.107e-01  y = (Re ^ 0.38629) - (Se * -9.897)
# 11          1.997e+01  1.047e-01  y = (Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)
# 16          1.981e+01  1.592e-03  y = (Re ^ 0.42462) + ((Se ^ 1.7775) * (-0.40525 + (Se / 0....
#                                       16337)))
# 18          1.976e+01  1.173e-03  y = (((Se / 0.48707) ^ 2.5901) + (((Re ^ 0.43015) + -0.227...
#                                       04) - 0.64344)) - Pr
# 19          1.919e+01  2.911e-02  y = ((((Se / 0.48707) ^ 2.5901) + (Re ^ 0.43015)) + (SoH +...
#                                        -3.0816)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.520e+04
# Progress: 596 / 800 total iterations (74.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.462e+01  3.317e-01  y = (Re ^ 0.38629) - (Se * -9.897)
# 11          1.997e+01  1.047e-01  y = (Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)
# 13          1.996e+01  1.915e-04  y = ((Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)) - -0.12092
# 16          1.974e+01  3.658e-03  y = (((Se / 0.48707) ^ 2.5901) + ((Re ^ 0.43015) - 0.64344...
#                                       )) - Pr
# 19          1.919e+01  9.352e-03  y = ((((Se / 0.48707) ^ 2.5901) + (Re ^ 0.43015)) + (SoH +...
#                                        -3.0816)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.340e+04
# Progress: 601 / 800 total iterations (75.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.462e+01  3.317e-01  y = (Re ^ 0.38629) - (Se * -9.897)
# 11          1.997e+01  1.047e-01  y = (Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)
# 13          1.996e+01  1.915e-04  y = ((Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)) - -0.12092
# 16          1.974e+01  3.658e-03  y = (((Se / 0.48707) ^ 2.5901) + ((Re ^ 0.43015) - 0.64344...
#                                       )) - Pr
# 18          1.951e+01  5.850e-03  y = (Re ^ 0.43015) + ((((Se / 0.48707) ^ 2.5901) + 0.48707...
#                                       ) + (SoH + -3.0816))
# 19          1.919e+01  1.636e-02  y = ((((Se / 0.48707) ^ 2.5901) + (Re ^ 0.43015)) + (SoH +...
#                                        -3.0816)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.820e+04
# Progress: 606 / 800 total iterations (75.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.462e+01  3.317e-01  y = (Re ^ 0.38629) - (Se * -9.897)
# 11          1.997e+01  1.047e-01  y = (Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)
# 13          1.996e+01  1.915e-04  y = ((Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)) - -0.12092
# 16          1.974e+01  3.658e-03  y = (((Se / 0.48707) ^ 2.5901) + ((Re ^ 0.43015) - 0.64344...
#                                       )) - Pr
# 18          1.951e+01  5.850e-03  y = (Re ^ 0.43015) + ((((Se / 0.48707) ^ 2.5901) + 0.48707...
#                                       ) + (SoH + -3.0816))
# 19          1.919e+01  1.636e-02  y = ((((Se / 0.48707) ^ 2.5901) + (Re ^ 0.43015)) + (SoH +...
#                                        -3.0816)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+04
# Progress: 623 / 800 total iterations (77.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.462e+01  3.317e-01  y = (Re ^ 0.38629) - (Se * -9.897)
# 11          1.997e+01  1.047e-01  y = (Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)
# 13          1.996e+01  1.915e-04  y = ((Re ^ 0.42272) + ((Se / 0.5183) ^ 2.6209)) - -0.12092
# 16          1.970e+01  4.308e-03  y = ((Re ^ 0.42272) + (((Se / 0.5183) ^ 2.6209) + SoH)) - ...
#                                       0.55159
# 17          1.966e+01  2.357e-03  y = (Re ^ 0.42272) + ((((Se / 0.5183) ^ 2.6209) + SoH) - P...
#                                       r)
# 18          1.951e+01  7.391e-03  y = (Re ^ 0.43015) + ((((Se / 0.48707) ^ 2.5901) + 0.48707...
#                                       ) + (SoH + -3.0816))
# 19          1.919e+01  1.636e-02  y = ((((Se / 0.48707) ^ 2.5901) + (Re ^ 0.43015)) + (SoH +...
#                                        -3.0816)) + SoH
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 1.560e+04
# Progress: 648 / 800 total iterations (81.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.462e+01  3.317e-01  y = (Re ^ 0.38629) - (Se * -9.897)
# 11          1.954e+01  1.155e-01  y = ((Se / 0.64579) ^ 3.4606) + (Re ^ 0.43081)
# 13          1.952e+01  5.043e-04  y = (((Se / 0.64579) ^ 3.4606) + (Re ^ 0.43081)) + -0.4404...
#                                       7
# 16          1.917e+01  5.972e-03  y = (((Se / 0.64468) ^ 3.4382) + ((Re ^ 0.42946) + SoH)) -...
#                                        0.98302
# 18          1.917e+01  7.758e-05  y = (((Se / 0.64356) ^ 3.4541) + ((-1.2024 + Re) ^ 0.43227...
#                                       )) + (SoH - 1.3412)
# 19          1.893e+01  1.246e-02  y = (((((Se / 0.65152) ^ 3.4939) + SoH) + (Re ^ 0.43017)) ...
#                                       + SoH) - 1.8864
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.190e+04
# Progress: 703 / 800 total iterations (87.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.457e+01  3.335e-01  y = (Se + 0.43081) * (Re ^ 0.43081)
# 11          1.954e+01  1.146e-01  y = ((Se / 0.64579) ^ 3.4606) + (Re ^ 0.43081)
# 13          1.952e+01  5.043e-04  y = (((Se / 0.64579) ^ 3.4606) + (Re ^ 0.43081)) + -0.4404...
#                                       7
# 16          1.917e+01  6.002e-03  y = ((Re ^ 0.4294) + ((Se / 0.65776) ^ 3.5319)) + (SoH - 0...
#                                       .87756)
# 18          1.914e+01  9.478e-04  y = (Re ^ 0.4294) + ((((Se / 0.65776) ^ 3.5319) + (SoH / 0...
#                                       .87756)) + -0.9665)
# 19          1.893e+01  1.063e-02  y = (((((Se / 0.65152) ^ 3.4939) + SoH) + (Re ^ 0.43017)) ...
#                                       + SoH) - 1.8864
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.610e+04
# Progress: 751 / 800 total iterations (93.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.457e+01  3.335e-01  y = (Se + 0.43081) * (Re ^ 0.43081)
# 11          1.948e+01  1.161e-01  y = ((Se / 0.65776) ^ 3.5319) + (Re ^ 0.4294)
# 14          1.934e+01  2.442e-03  y = (Re ^ 0.43081) + (((Se / 0.64579) ^ 3.4606) * SoH)
# 16          1.917e+01  4.373e-03  y = ((Re ^ 0.4294) + ((Se / 0.65776) ^ 3.5319)) + (SoH - 0...
#                                       .87756)
# 18          1.914e+01  9.478e-04  y = (Re ^ 0.4294) + ((((Se / 0.65776) ^ 3.5319) + (SoH / 0...
#                                       .87756)) + -0.9665)
# 19          1.893e+01  1.063e-02  y = (((((Se / 0.65152) ^ 3.4939) + SoH) + (Re ^ 0.43017)) ...
#                                       + SoH) - 1.8864
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.650e+04
# Progress: 798 / 800 total iterations (99.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.457e+01  3.335e-01  y = (Se + 0.43081) * (Re ^ 0.43081)
# 11          1.948e+01  1.161e-01  y = ((Se / 0.65776) ^ 3.5319) + (Re ^ 0.4294)
# 14          1.934e+01  2.442e-03  y = (Re ^ 0.43081) + (((Se / 0.64579) ^ 3.4606) * SoH)
# 16          1.917e+01  4.373e-03  y = ((Re ^ 0.4294) + ((Se / 0.65776) ^ 3.5319)) + (SoH - 0...
#                                       .87756)
# 18          1.914e+01  9.478e-04  y = (Re ^ 0.4294) + ((((Se / 0.65776) ^ 3.5319) + (SoH / 0...
#                                       .87756)) + -0.9665)
# 19          1.893e+01  1.063e-02  y = (((((Se / 0.65152) ^ 3.4939) + SoH) + (Re ^ 0.43017)) ...
#                                       + SoH) - 1.8864
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.550e+01  0.000e+00  y = 20.014
# 4           4.372e+01  1.328e-02  y = Se + 19.115
# 6           3.431e+01  1.212e-01  y = (Se ^ 6.4745) - -17.79
# 8           3.430e+01  1.976e-04  y = ((Se ^ 5.8008) - -14.67) ^ 1.0677
# 9           2.457e+01  3.335e-01  y = (Se + 0.43081) * (Re ^ 0.43081)
# 11          1.948e+01  1.161e-01  y = ((Se / 0.65776) ^ 3.5319) + (Re ^ 0.4294)
# 14          1.934e+01  2.442e-03  y = (Re ^ 0.43081) + (((Se / 0.64579) ^ 3.4606) * SoH)
# 16          1.917e+01  4.373e-03  y = ((Re ^ 0.4294) + ((Se / 0.65776) ^ 3.5319)) + (SoH - 0...
#                                       .87756)
# 18          1.914e+01  9.478e-04  y = (Re ^ 0.4294) + ((((Se / 0.65776) ^ 3.5319) + (SoH / 0...
#                                       .87756)) + -0.9665)
# 19          1.893e+01  1.063e-02  y = (((((Se / 0.65152) ^ 3.4939) + SoH) + (Re ^ 0.43017)) ...
#                                       + SoH) - 1.8864
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250921_011316_b2m6HF\hall_of_fame.csv
# Tiempo de ejecución: 125.99751663208008 [s]

# %%
equations = model.equations_['equation']
equations = equations.apply(lambda x: x.replace('^', '**'))
print('=== TRAIN ===')
df_train = eval_equations(x_train, y_train, equations).sort_values(by='mse')
display(df_train)

print('\n=== VALIDATION ===')
x_val.rename(columns={'S': 'Se'}, inplace=True)
df_val = eval_equations(x_val, y_val, equations).sort_values(by='mse')
display(df_val)
# Out:
# === TRAIN ===
#                                          expresiones        mse
# 9  (((((Se / 0.65151566) ** 3.4939196) + SoH) + (...  18.933336
# 8  (Re ** 0.4293992) + ((((Se / 0.65776443) ** 3....  19.135727
# 7  ((Re ** 0.4293992) + ((Se / 0.65776443) ** 3.5...  19.172071
# 6  (Re ** 0.4308128) + (((Se / 0.6457888) ** 3.46...  19.340530
# 5  ((Se / 0.65776443) ** 3.5318732) + (Re ** 0.42...  19.482801
# 4               (Se + 0.4308128) * (Re ** 0.4308128)  24.574717
# 3       ((Se ** 5.8007617) - -14.66982) ** 1.0676985  34.300932
# 2                      (Se ** 6.474474) - -17.790165  34.314619
# 1                                     Se + 19.114872  43.724883
# 0                                          20.014498        inf
# === VALIDATION ===
#                                          expresiones        mse
# 9  (((((Se / 0.65151566) ** 3.4939196) + SoH) + (...  14.451003
# 7  ((Re ** 0.4293992) + ((Se / 0.65776443) ** 3.5...  14.617449
# 8  (Re ** 0.4293992) + ((((Se / 0.65776443) ** 3....  14.620487
# 6  (Re ** 0.4308128) + (((Se / 0.6457888) ** 3.46...  14.681742
# 5  ((Se / 0.65776443) ** 3.5318732) + (Re ** 0.42...  14.847457
# 4               (Se + 0.4308128) * (Re ** 0.4308128)  18.862718
# 3       ((Se ** 5.8007617) - -14.66982) ** 1.0676985  30.103484
# 2                      (Se ** 6.474474) - -17.790165  30.158986
# 1                                     Se + 19.114872  39.760662
# 0                                          20.014498        inf

# %%
expr = sp.sympify(
    df_val['expresiones'].iloc[0]
).evalf(4)
expr
# Out:
# Re**0.4302 + 4.468*Se**3.494 + 2.0*SoH - 1.886

# %%
x_test = pd.read_csv(r'.\DATA_LIB_Degradation\df_n_test_des.txt')
y_true = x_test['nusselt']
x_test = x_test.drop('nusselt', axis=1)
print('x_test:')
display(x_train.head())
print('y_test:', y_true.to_numpy()[: 5])

f = sp.lambdify(sp.symbols('Re SoH Se Pr'), expr, 'numpy')
y_pred = f(x_test['Re'].to_numpy(),
           x_test['SoH'].to_numpy(),
           x_test['S'].to_numpy(),
           x_test['Pr'].to_numpy())
print('y_pred =', y_pred[: 5])
print('n_pred =', len(y_pred), '/ n_true =', len(y_true))
print()

results = get_general_metrics(y_pred, y_true)
for key, value in results.items():
    print(key, '=', value[0], '+/-', value[1])
# Out:
# x_test:
#          Se          Re        Pr     SoH
# 0  0.280625  212.041256  0.709840  0.6363
# 1  0.280625  212.041256  0.707471  1.0000
# 2  0.280625  197.894331  0.706170  1.0000
# 3  0.344410  188.969448  0.708576  0.6363
# 4  0.344410  188.969448  0.704657  1.0000
# y_test: [12.65606225 13.78598212 14.02560596 13.66040888 13.68752691]
# y_pred = [ 9.4319976  10.1593976   9.84172623  9.63591486  9.54533879]
# n_pred = 15731 / n_true = 15731
#
# RMSE = 3.78 +/- 2.57
# MAE = 2.78 +/- 2.57
# SMAPE = 14.11 +/- 12.93

# %% [markdown]
# ## Coeficiente de Arrastre

# %% [markdown]
# ### Base de datos y exploración

# %%
x_train = pd.read_csv(r'.\DATA_LIB_Degradation\df_cdrag_train_des.txt')
y_train = x_train['cdrag']
x_train = x_train.drop('cdrag', axis=1)
print('x_train:')
display(x_train.head())
print('y_train:', y_train.to_numpy()[: 5])
# Out:
# x_train:
#           S          Re     SoH
# 0  0.280625  212.041256  0.6363
# 1  0.280625  212.041256  1.0000
# 2  0.280625  197.894331  1.0000
# 3  0.344410  188.969448  0.6363
# 4  0.344410  188.969448  1.0000
# y_train: [1.81620614 1.7641475  1.90709754 1.94818158 1.79092469]

# %%
x_min, x_max = x_train.min(), x_train.max()
xn_train = (x_train - x_min) / (x_max - x_min)
xn_train.head()
x_val = pd.read_csv(r'.\DATA_LIB_Degradation\df_cdrag_val_des.txt')
y_val = x_val['cdrag']
x_val = x_val.drop('cdrag', axis=1)
xn_val = (x_val - x_min) / (x_max - x_min)
xn_val.head()
# Out:
#           S        Re       SoH
# 0  0.753974  0.223500  1.000000
# 1  0.753974  0.214392  1.000000
# 2  0.753974  0.209950  1.000000
# 3  0.621218  0.287809  0.666544
# 4  0.621218  0.287809  0.666544

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

ax[0].scatter(x_train['Re'], y_train, marker='.', c=x_train['S'])
ax[0].set_xlabel('Re')
ax[0].set_ylabel(r'$c_d$')

ax[1].scatter(x_train['S'], y_train, marker='.', c=x_train['Re'], cmap='magma')
ax[1].set_xlabel('S')
ax[1].set_ylabel(r'$c_d$')

fig.suptitle('Coeficiente de Arrastre (Train)')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

ax[0].scatter(x_val['Re'], y_val, marker='.', c=x_val['S'])
ax[0].set_xlabel('Re')
ax[0].set_ylabel(r'$c_d$')

ax[1].scatter(x_val['S'], y_val, marker='.', c=x_val['Re'], cmap='magma')
ax[1].set_xlabel('S')
ax[1].set_ylabel(r'$c_d$')

fig.suptitle('Coeficiente de Arrastre (Val)')
plt.show()

# %%
print(len(np.unique(x_train['S'])))
# Out:
# 50

# %% [markdown]
# ### Evolución Grámatica (sin segmentación)

# %%
from time import time
from tqdm import tqdm
from pysr import PySRRegressor

x_train.rename(columns={'S': 'Se'}, inplace=True)

# %%
model = PySRRegressor(
    niterations=200,
    binary_operators=["+","-","*" ,"/", "^"],
    unary_operators=[],
    population_size=50,
    populations=4,
    tournament_selection_n=3,
    verbosity=1,
    maxsize=20,
    parsimony=1e-2,
    constraints={'^':(-1,1)},
    complexity_of_variables=2,
    random_state=0,
    progress=True
)

t0 = time()
model.fit(x_train, y_train)
tf = time()
print(f"Tiempo de ejecución: {tf - t0} [s]")
# Out:
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 2.970e+04
# Progress: 26 / 800 total iterations (3.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.769e-01  3.518e-03  y = 0.79482 + (Se ^ 1.1938)
# 9           4.692e-01  5.388e-03  y = ((Re ^ -0.34366) - -0.69533) + Se
# 11          4.691e-01  7.356e-05  y = (((Re - 1.6945) ^ -0.34366) - -0.69533) + Se
# 14          4.418e-01  2.002e-02  y = ((((Se ^ 0.85886) - -1.1326) + Re) * 0.99946) - Re
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.860e+04
# Progress: 63 / 800 total iterations (7.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.769e-01  3.518e-03  y = 0.79482 + (Se ^ 1.1938)
# 9           4.692e-01  5.388e-03  y = ((Re ^ -0.34366) - -0.69533) + Se
# 11          4.649e-01  4.610e-03  y = ((Re + -1.8395) ^ -0.16717) - (-0.44671 - Se)
# 13          4.605e-01  4.720e-03  y = ((((Re * 0.087924) + -0.69533) ^ -0.54181) + 0.67094) ...
#                                       + Se
# 14          4.418e-01  4.156e-02  y = ((((Se ^ 0.85886) - -1.1326) + Re) * 0.99946) - Re
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.240e+04
# Progress: 100 / 800 total iterations (12.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.769e-01  3.518e-03  y = 0.79482 + (Se ^ 1.1938)
# 9           4.692e-01  5.388e-03  y = ((Re ^ -0.34366) - -0.69533) + Se
# 11          4.621e-01  7.667e-03  y = ((0.11488 * Re) ^ -0.47048) + (0.67094 + Se)
# 12          4.434e-01  4.122e-02  y = (((Se - -1.1326) + Re) * 0.99946) - Re
# 14          4.418e-01  1.835e-03  y = ((((Se ^ 0.85886) - -1.1326) + Re) * 0.99946) - Re
# 16          4.339e-01  9.054e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.620e+04
# Progress: 138 / 800 total iterations (17.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.769e-01  3.518e-03  y = 0.79482 + (Se ^ 1.1938)
# 9           4.692e-01  5.388e-03  y = ((Re ^ -0.34366) - -0.69533) + Se
# 11          4.621e-01  7.667e-03  y = ((0.11488 * Re) ^ -0.47048) + (0.67094 + Se)
# 12          4.434e-01  4.122e-02  y = (((Se - -1.1326) + Re) * 0.99946) - Re
# 14          4.418e-01  1.835e-03  y = ((((Se ^ 0.85886) - -1.1326) + Re) * 0.99946) - Re
# 16          4.339e-01  9.054e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.550e+04
# Progress: 168 / 800 total iterations (21.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.769e-01  3.518e-03  y = 0.79482 + (Se ^ 1.1938)
# 9           4.692e-01  5.388e-03  y = ((Re ^ -0.34366) - -0.69533) + Se
# 11          4.621e-01  7.667e-03  y = ((0.11488 * Re) ^ -0.47048) + (0.67094 + Se)
# 12          4.434e-01  4.122e-02  y = (((Se - -1.1326) + Re) * 0.99946) - Re
# 14          4.418e-01  1.835e-03  y = ((((Se ^ 0.85886) - -1.1326) + Re) * 0.99946) - Re
# 16          4.339e-01  9.054e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.200e+04
# Progress: 221 / 800 total iterations (27.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 9           4.692e-01  5.294e-03  y = ((Re ^ -0.34366) - -0.69533) + Se
# 11          4.621e-01  7.667e-03  y = ((0.11488 * Re) ^ -0.47048) + (0.67094 + Se)
# 12          4.434e-01  4.122e-02  y = (((Se - -1.1326) + Re) * 0.99946) - Re
# 14          4.418e-01  1.835e-03  y = ((((Se ^ 0.85886) - -1.1326) + Re) * 0.99946) - Re
# 16          4.339e-01  9.054e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.350e+04
# Progress: 260 / 800 total iterations (32.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 9           4.686e-01  5.702e-03  y = ((0.11488 * Re) ^ -0.055969) + Se
# 11          4.621e-01  7.054e-03  y = ((0.11488 * Re) ^ -0.47048) + (0.67094 + Se)
# 12          4.434e-01  4.122e-02  y = (((Re + Se) - -1.1326) * 0.99946) - Re
# 13          4.419e-01  3.431e-03  y = (Se + 0.37816) + (((Re + -0.16251) * 0.012951) ^ -0.48...
#                                       45)
# 14          4.405e-01  3.066e-03  y = ((Se - -1.5252) + (Re - (Re * 1.0007))) * 0.84215
# 16          4.339e-01  7.640e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.350e+04
# Progress: 309 / 800 total iterations (38.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.650e-01  8.396e-03  y = ((Re ^ -0.16662) + Se) + 0.44562
# 11          4.508e-01  1.551e-02  y = (((0.05453 + Re) ^ -0.16662) / 0.44562) + Se
# 12          4.434e-01  1.649e-02  y = (((Re + Se) - -1.1326) * 0.99946) - Re
# 13          4.419e-01  3.431e-03  y = (Se + 0.37816) + (((Re + -0.16251) * 0.012951) ^ -0.48...
#                                       45)
# 14          4.405e-01  3.066e-03  y = ((Se - -1.5252) + (Re - (Re * 1.0007))) * 0.84215
# 16          4.339e-01  7.640e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.320e+04
# Progress: 358 / 800 total iterations (44.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 13          4.419e-01  6.310e-04  y = (Se + 0.37816) + (((Re + -0.16251) * 0.012951) ^ -0.48...
#                                       45)
# 14          4.405e-01  3.066e-03  y = ((Se - -1.5252) + (Re - (Re * 1.0007))) * 0.84215
# 16          4.339e-01  7.640e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.730e+04
# Progress: 393 / 800 total iterations (49.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.429e-01  1.283e-04  y = (Se + 0.55811) + (96.426 / (Re + 1.8422))
# 13          4.418e-01  1.212e-03  y = (Se + 0.37816) + (((Re + -1.2385) * 0.012951) ^ -0.484...
#                                       5)
# 14          4.405e-01  2.910e-03  y = ((Se - -1.5252) + (Re - (Re * 1.0007))) * 0.84215
# 16          4.339e-01  7.640e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.780e+04
# Progress: 441 / 800 total iterations (55.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.429e-01  1.283e-04  y = (Se + 0.55811) + (96.426 / (Re + 1.8422))
# 13          4.418e-01  1.217e-03  y = (Se + (((Re + -1.3071) * 0.012951) ^ -0.4845)) + 0.378...
#                                       16
# 14          4.405e-01  2.900e-03  y = ((Se - -1.5252) + (Re - (Re * 1.0007))) * 0.84215
# 16          4.339e-01  7.640e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.140e+04
# Progress: 493 / 800 total iterations (61.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.419e-01  1.250e-03  y = (Se + ((Re * 0.012951) ^ -0.4845)) + 0.37816
# 13          4.418e-01  9.490e-05  y = (Se + (((Re + -1.3071) * 0.012951) ^ -0.4845)) + 0.378...
#                                       16
# 14          4.405e-01  2.900e-03  y = ((Se - -1.5252) + (Re - (Re * 1.0007))) * 0.84215
# 16          4.339e-01  7.640e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.890e+04
# Progress: 538 / 800 total iterations (67.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.419e-01  1.250e-03  y = (Se + ((Re * 0.012951) ^ -0.4845)) + 0.37816
# 13          4.418e-01  9.490e-05  y = (Se + (((Re + -1.3071) * 0.012951) ^ -0.4845)) + 0.378...
#                                       16
# 14          4.405e-01  2.914e-03  y = (Se - (((-1.5252 + Re) * 1.0007) - Re)) * 0.84215
# 16          4.339e-01  7.633e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.130e+04
# Progress: 582 / 800 total iterations (72.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.411e-01  2.133e-03  y = ((129.49 / (Re + 38.101)) + Se) + 0.51692
# 14          4.405e-01  4.459e-04  y = (Se - (((-1.5252 + Re) * 1.0007) - Re)) * 0.84215
# 16          4.339e-01  7.633e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.310e+04
# Progress: 630 / 800 total iterations (78.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.411e-01  2.133e-03  y = ((129.49 / (Re + 38.101)) + Se) + 0.51692
# 14          4.405e-01  4.459e-04  y = (Se - (((-1.5252 + Re) * 1.0007) - Re)) * 0.84215
# 16          4.339e-01  7.633e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.440e+04
# Progress: 688 / 800 total iterations (86.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.411e-01  2.133e-03  y = ((129.49 / (Re + 38.101)) + Se) + 0.51692
# 13          4.411e-01  2.515e-05  y = ((129.49 / ((Re - -1.2561) + 38.101)) + Se) + 0.51692
# 14          4.405e-01  1.287e-03  y = (Se - (((-1.5252 + Re) * 1.0007) - Re)) * 0.84215
# 16          4.339e-01  7.633e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.690e+04
# Progress: 738 / 800 total iterations (92.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.411e-01  2.133e-03  y = ((129.49 / (Re + 38.101)) + Se) + 0.51692
# 13          4.411e-01  2.515e-05  y = ((129.49 / ((Re - -1.2561) + 38.101)) + Se) + 0.51692
# 14          4.405e-01  1.287e-03  y = (Se - (((-1.5252 + Re) * 1.0007) - Re)) * 0.84215
# 16          4.339e-01  7.633e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 6.520e+04
# Progress: 779 / 800 total iterations (97.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.411e-01  2.133e-03  y = ((129.49 / (Re + 38.101)) + Se) + 0.51692
# 13          4.411e-01  2.515e-05  y = ((129.49 / ((Re - -1.2561) + 38.101)) + Se) + 0.51692
# 14          4.405e-01  1.287e-03  y = (Se - (((-1.5252 + Re) * 1.0007) - Re)) * 0.84215
# 16          4.339e-01  7.633e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.308e-01  0.000e+00  y = 1.7009
# 4           4.802e-01  9.089e-02  y = Se - -0.8024
# 6           4.767e-01  3.660e-03  y = (Se ^ 1.2079) + 0.8058
# 7           4.729e-01  8.125e-03  y = (Re ^ -0.034208) + Se
# 9           4.430e-01  3.261e-02  y = ((96.426 / Re) + 0.55811) + Se
# 11          4.411e-01  2.133e-03  y = ((129.49 / (Re + 38.101)) + Se) + 0.51692
# 13          4.411e-01  2.515e-05  y = ((129.49 / ((Re - -1.2561) + 38.101)) + Se) + 0.51692
# 14          4.405e-01  1.287e-03  y = (Se - (((-1.5252 + Re) * 1.0007) - Re)) * 0.84215
# 16          4.339e-01  7.633e-03  y = ((Se + 0.91418) + ((Se / (Re ^ -0.50084)) * -0.019886)...
#                                       ) ^ 1.4502
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Tiempo de ejecución: 94.42937731742859 [s]
#   - outputs\20250921_010737_AR8BTH\hall_of_fame.csv

# %%
equations = model.equations_['equation']
equations = equations.apply(lambda x: x.replace('^', '**'))
print('=== TRAIN ===')
df_train = eval_equations(x_train, y_train, equations).sort_values(by='mse')
display(df_train)

print('\n=== VALIDATION ===')
x_val.rename(columns={'S': 'Se'}, inplace=True)
df_val = eval_equations(x_val, y_val, equations).sort_values(by='mse')
display(df_val)
# Out:
# === TRAIN ===
#                                          expresiones       mse
# 8  ((Se + 0.9141782) + ((Se / (Re ** -0.50083816)...  0.433862
# 7  (Se - (((-1.5251601 + Re) * 1.0006578) - Re)) ...  0.440536
# 6  ((129.48993 / ((Re - -1.2561272) + 38.10133)) ...  0.441103
# 5   ((129.48993 / (Re + 38.10133)) + Se) + 0.5169155  0.441125
# 4                 ((96.42577 / Re) + 0.5581075) + Se  0.443011
# 3                          (Re ** -0.034208477) + Se  0.472866
# 2                     (Se ** 1.2078688) + 0.80580163  0.476724
# 1                                       Se - -0.8024  0.480226
# 0                                          1.7009448       inf
# === VALIDATION ===
#                                          expresiones       mse
# 6  ((129.48993 / ((Re - -1.2561272) + 38.10133)) ...  0.270471
# 5   ((129.48993 / (Re + 38.10133)) + Se) + 0.5169155  0.270602
# 4                 ((96.42577 / Re) + 0.5581075) + Se  0.271917
# 8  ((Se + 0.9141782) + ((Se / (Re ** -0.50083816)...  0.273838
# 7  (Se - (((-1.5251601 + Re) * 1.0006578) - Re)) ...  0.275805
# 3                          (Re ** -0.034208477) + Se  0.305390
# 1                                       Se - -0.8024  0.312428
# 2                     (Se ** 1.2078688) + 0.80580163  0.315795
# 0                                          1.7009448       inf

# %%
expr = sp.sympify(
    df_val['expresiones'].iloc[0]
).evalf(4)
expr
# Out:
# Se + 0.5169 + 129.5/(Re + 39.36)

# %%
x_test = pd.read_csv(r'.\DATA_LIB_Degradation\df_cdrag_test_des.txt')
y_true = x_test['cdrag']
x_test = x_test.drop('cdrag', axis=1)
print('x_test:')
display(x_train.head())
print('y_test:', y_true.to_numpy()[: 5])

f = sp.lambdify(sp.symbols('Re SoH Se'), expr, 'numpy')
y_pred = f(x_test['Re'].to_numpy(),
           x_test['SoH'].to_numpy(),
           x_test['S'].to_numpy())
print('y_pred =', y_pred[: 5])
print('n_pred =', len(y_pred), '/ n_true =', len(y_true))
print()

results = get_general_metrics(y_pred, y_true)
for key, value in results.items():
    print(key, '=', value[0], '+/-', value[1])
# Out:
# x_test:
#          Se          Re     SoH
# 0  0.280625  212.041256  0.6363
# 1  0.280625  212.041256  1.0000
# 2  0.280625  197.894331  1.0000
# 3  0.344410  188.969448  0.6363
# 4  0.344410  188.969448  1.0000
# y_test: [1.84063062 1.80419647 1.83289982 1.84955957 1.93785371]
# y_pred = [1.31530254 1.31530254 1.34891591 1.37223919 1.38291351]
# n_pred = 15639 / n_true = 15639
#
# RMSE = 0.53 +/- 0.34
# MAE = 0.4 +/- 0.34
# SMAPE = 24.05 +/- 17.52

# %% [markdown]
# ## Factor de Fricción

# %% [markdown]
# ### Base de datos y exploración

# %%
x_train = pd.read_csv(r'.\DATA_LIB_Degradation\df_ff_train_des.txt')
y_train = x_train['frictionFactor']
x_train = x_train.drop('frictionFactor', axis=1)
print('x_train:')
display(x_train.head())
print('y_train:', y_train.to_numpy()[: 5])
# Out:
# x_train:
#           S          Re     SoH
# 0  0.280625  212.041256  0.6363
# 1  0.280625  212.041256  1.0000
# 2  0.280625  197.894331  1.0000
# 3  0.344410  188.969448  0.6363
# 4  0.344410  188.969448  1.0000
# y_train: [3.01555351 2.9419802  3.26051676 2.69129088 2.40581715]

# %%
x_min, x_max = x_train.min(), x_train.max()
xn_train = (x_train - x_min) / (x_max - x_min)
xn_train.head()
x_val = pd.read_csv(r'.\DATA_LIB_Degradation\df_ff_val_des.txt')
y_val = x_val['frictionFactor']
x_val = x_val.drop('frictionFactor', axis=1)
xn_val = (x_val - x_min) / (x_max - x_min)
xn_val.head()
# Out:
#           S        Re       SoH
# 0  0.753974  0.229825  1.000000
# 1  0.753974  0.223500  1.000000
# 2  0.753974  0.214392  1.000000
# 3  0.753974  0.209950  1.000000
# 4  0.621218  0.287809  0.666544

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

ax[0].scatter(x_train['Re'], y_train, marker='.', c=x_train['S'])
ax[0].set_xlabel('Re')
ax[0].set_ylabel(r'$f_D$')

ax[1].scatter(x_train['S'], y_train, marker='.', c=x_train['Re'], cmap='magma')
ax[1].set_xlabel('S')
ax[1].set_ylabel(r'$f_D$')

fig.suptitle('Factor de Fricción (Train)')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

ax[0].scatter(x_val['Re'], y_val, marker='.', c=x_val['S'])
ax[0].set_xlabel('Re')
ax[0].set_ylabel(r'$f_D$')

ax[1].scatter(x_val['S'], y_val, marker='.', c=x_val['Re'], cmap='magma')
ax[1].set_xlabel('S')
ax[1].set_ylabel(r'$f_D$')

fig.suptitle('Factor de Fricción (Val)')
plt.show()

# %%
print(len(np.unique(x_train['S'])))
# Out:
# 50

# %% [markdown]
# ### Evolución Grámatica (sin segmentación)

# %%
from time import time
from tqdm import tqdm
from pysr import PySRRegressor

x_train.rename(columns={'S': 'Se'}, inplace=True)

# %%
model = PySRRegressor(
    niterations=200,
    binary_operators=["+","-","*" ,"/", "^"],
    unary_operators=[],
    population_size=50,
    populations=4,
    tournament_selection_n=3,
    verbosity=1,
    maxsize=20,
    parsimony=1e-2,
    constraints={'^':(-1,1)},
    complexity_of_variables=2,
    random_state=0,
    progress=True
)

t0 = time()
model.fit(x_train, y_train)
tf = time()
print(f"Tiempo de ejecución: {tf - t0} [s]")
# Out:
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# C:\Users\matia\PycharmProjects\GE_Re_EL7037_2025\.venv\Lib\site-packages\pysr\sr.py:1873: UserWarning: Note: Setting `random_state` without also setting `deterministic=True` and `parallelism='serial'` will result in non-deterministic searches.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 1.800e+04
# Progress: 14 / 800 total iterations (1.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.148e-01  2.080e-02  y = 1.4783 - (0.27384 * Se)
# 10          1.131e-01  3.597e-03  y = (0.86212 / ((Se + 0.454) ^ 0.36434)) / 0.64972
# 12          1.131e-01  2.327e-04  y = (((1.0154 / (Se ^ -0.47212)) ^ -0.47212) / 1.0161) * 1...
#                                       .1824
# 15          1.121e-01  2.855e-03  y = (Re ^ -0.066444) - ((-0.066444 / 0.27384) / (0.44516 *...
#                                        (Se ^ 0.23761)))
# 20          1.095e-01  4.779e-03  y = (Re ^ -0.066444) + ((0.066285 - (-0.066444 - ((Re ^ -0...
#                                       .18451) * (0.95892 * 0.76967)))) / Se)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.900e+04
# Progress: 35 / 800 total iterations (4.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.148e-01  2.080e-02  y = 1.4783 - (0.27384 * Se)
# 8           1.132e-01  7.052e-03  y = (2.2063 / (Se * 1.0946)) ^ 0.21821
# 10          1.131e-01  1.428e-04  y = (0.86212 / ((Se + 0.454) ^ 0.36434)) / 0.64972
# 12          1.131e-01  2.327e-04  y = (((1.0154 / (Se ^ -0.47212)) ^ -0.47212) / 1.0161) * 1...
#                                       .1824
# 15          9.184e-02  6.935e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.660e+04
# Progress: 66 / 800 total iterations (8.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.132e-01  2.359e-02  y = 2.1632 - (Se ^ 0.30036)
# 8           1.132e-01  7.713e-05  y = (2.2063 / (Se * 1.0946)) ^ 0.21821
# 10          1.131e-01  1.428e-04  y = (0.86212 / ((Se + 0.454) ^ 0.36434)) / 0.64972
# 11          1.131e-01  4.106e-04  y = ((Se ^ -0.086079) / (Se ^ 0.16833)) - -0.15503
# 12          1.131e-01  5.478e-05  y = (((1.0154 / (Se ^ -0.47212)) ^ -0.47212) / 1.0161) * 1...
#                                       .1824
# 13          1.055e-01  6.910e-02  y = (2.2063 / ((Se * (0.61866 * Re)) ^ 0.21821)) - -0.5283...
#                                       7
# 14          9.919e-02  6.197e-02  y = (2.2063 / (((Se * Se) * Re) ^ 0.21821)) - -0.52837
# 15          9.184e-02  7.697e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.220e+04
# Progress: 96 / 800 total iterations (12.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.132e-01  2.359e-02  y = 2.1632 - (Se ^ 0.30036)
# 8           1.131e-01  3.654e-04  y = ((1.273 - -0.65036) / Se) ^ 0.21821
# 11          1.073e-01  1.767e-02  y = (2.2063 / ((Re * Se) ^ 0.22644)) - -0.61809
# 13          1.055e-01  8.135e-03  y = (2.2063 / ((Se * (0.61866 * Re)) ^ 0.21821)) - -0.5283...
#                                       7
# 14          9.609e-02  9.373e-02  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.820e+04
# Progress: 135 / 800 total iterations (16.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.132e-01  2.359e-02  y = 2.1632 - (Se ^ 0.30036)
# 8           1.131e-01  4.170e-04  y = ((Se ^ -0.29116) + 0.17632) ^ 0.88705
# 10          1.023e-01  4.998e-02  y = (Se + (Re ^ -0.28982)) / Se
# 13          1.004e-01  6.204e-03  y = (((Se * Re) ^ -0.28982) + Se) / Se
# 14          9.609e-02  4.433e-02  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 20          9.175e-02  1.013e-06  y = (((-0.068431 + Re) ^ -0.082495) + 0.28784) - ((0.16528...
#                                        - (Re ^ -0.17263)) * (1.4372 / Se))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.880e+04
# Progress: 151 / 800 total iterations (18.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.132e-01  2.359e-02  y = 2.1632 - (Se ^ 0.30036)
# 8           1.131e-01  4.170e-04  y = ((Se ^ -0.29116) + 0.17632) ^ 0.88705
# 10          1.023e-01  4.998e-02  y = (Se + (Re ^ -0.28982)) / Se
# 12          1.003e-01  1.024e-02  y = (((Re ^ -0.17819) + -0.15409) + Se) / Se
# 14          9.609e-02  2.123e-02  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 20          8.847e-02  1.821e-02  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.140e+04
# Progress: 196 / 800 total iterations (24.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.132e-01  2.359e-02  y = 2.1632 - (Se ^ 0.30036)
# 8           1.131e-01  4.170e-04  y = ((Se ^ -0.29116) + 0.17632) ^ 0.88705
# 9           1.063e-01  6.193e-02  y = (Re ^ -0.28982) + (Se ^ -0.28982)
# 10          1.020e-01  4.129e-02  y = ((Re ^ -0.27814) + Se) / Se
# 12          1.003e-01  8.613e-03  y = (((Re ^ -0.17819) + -0.15409) + Se) / Se
# 14          9.609e-02  2.123e-02  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 20          8.847e-02  1.821e-02  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.650e+04
# Progress: 239 / 800 total iterations (29.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.376e-02  y = (Se ^ -0.25441) + 0.15503
# 9           1.063e-01  2.064e-02  y = (Re ^ -0.28982) + (Se ^ -0.28982)
# 10          1.020e-01  4.129e-02  y = ((Re ^ -0.27814) + Se) / Se
# 12          1.003e-01  8.613e-03  y = (((Re ^ -0.17819) + -0.15409) + Se) / Se
# 14          9.609e-02  2.123e-02  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 20          8.847e-02  1.821e-02  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.880e+04
# Progress: 251 / 800 total iterations (31.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.376e-02  y = (Se ^ -0.25441) + 0.15503
# 9           9.982e-02  4.158e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.896e-02  4.364e-03  y = (((Re ^ -0.16899) + -0.11738) / Se) + 0.9169
# 13          9.718e-02  9.033e-03  y = (((Re ^ -0.19424) + -0.16264) / (Se + -0.16366)) + 0.9...
#                                       3057
# 14          9.609e-02  1.136e-02  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 20          8.847e-02  1.821e-02  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.270e+04
# Progress: 283 / 800 total iterations (35.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 9           9.982e-02  4.156e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.850e-02  6.684e-03  y = (((Re ^ -0.27972) / Se) + 0.72025) * 1.2615
# 13          9.653e-02  1.009e-02  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 20          8.847e-02  1.821e-02  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.730e+04
# Progress: 340 / 800 total iterations (42.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 9           9.982e-02  4.156e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.850e-02  6.684e-03  y = (((Re ^ -0.27972) / Se) + 0.72025) * 1.2615
# 13          9.653e-02  1.009e-02  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 19          8.848e-02  3.639e-02  y = (1.1689 ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)...
#                                       ) * 1.9558) / Se) + 0.11365) * -1.537)
# 20          8.847e-02  2.646e-05  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.870e+04
# Progress: 357 / 800 total iterations (44.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 9           9.982e-02  4.156e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.850e-02  6.684e-03  y = (((Re ^ -0.27972) / Se) + 0.72025) * 1.2615
# 13          9.653e-02  1.009e-02  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 18          9.175e-02  3.081e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 19          8.848e-02  3.639e-02  y = (1.1689 ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)...
#                                       ) * 1.9558) / Se) + 0.11365) * -1.537)
# 20          8.847e-02  2.646e-05  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.780e+04
# Progress: 370 / 800 total iterations (46.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 9           9.982e-02  4.156e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.850e-02  6.684e-03  y = (((Re ^ -0.27972) / Se) + 0.72025) * 1.2615
# 13          9.653e-02  1.009e-02  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.179e-02  2.778e-04  y = 0.66181 - (((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384) + 0.0021368)
# 18          9.175e-02  3.686e-04  y = ((Re ^ -0.082495) + 0.28784) - ((0.16528 - (Re ^ -0.17...
#                                       263)) * (1.4372 / Se))
# 19          8.848e-02  3.639e-02  y = (1.1689 ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)...
#                                       ) * 1.9558) / Se) + 0.11365) * -1.537)
# 20          8.847e-02  2.646e-05  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.980e+04
# Progress: 411 / 800 total iterations (51.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 9           9.982e-02  4.156e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.850e-02  6.684e-03  y = (((Re ^ -0.27972) / Se) + 0.72025) * 1.2615
# 13          9.653e-02  1.009e-02  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 19          8.848e-02  1.774e-02  y = (1.1689 ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)...
#                                       ) * 1.9558) / Se) + 0.11365) * -1.537)
# 20          8.847e-02  2.646e-05  y = (SoH ^ -0.027575) + (((((0.097022 - (Re ^ -0.26094)) *...
#                                        1.9558) / Se) + 0.11365) * -1.537)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.430e+04
# Progress: 441 / 800 total iterations (55.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 9           9.982e-02  4.156e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.940e+04
# Progress: 448 / 800 total iterations (56.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 9           9.982e-02  4.156e-02  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.250e+04
# Progress: 471 / 800 total iterations (58.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.550e+04
# Progress: 481 / 800 total iterations (60.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+04
# Progress: 501 / 800 total iterations (62.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.010e+04
# Progress: 511 / 800 total iterations (63.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.730e+04
# Progress: 521 / 800 total iterations (65.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.440e+04
# Progress: 564 / 800 total iterations (70.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.340e+04
# Progress: 603 / 800 total iterations (75.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.653e-02  3.937e-03  y = ((((Re ^ -0.28439) / Se) + 0.69606) * 1.5256) + -0.181...
#                                       22
# 14          9.609e-02  4.600e-03  y = (2.2063 / ((Se * (Se * Re)) ^ 0.21821)) - -0.58658
# 15          9.184e-02  4.521e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.167e-02  9.114e-04  y = (0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0....
#                                       12035) * 2.2384)) + -0.014353
# 18          8.904e-02  2.918e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.240e+04
# Progress: 615 / 800 total iterations (76.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.541e-02  9.779e-03  y = (Se * -0.51992) + (((Re ^ -0.12031) / 0.78192) * 2.770...
#                                       5)
# 15          9.184e-02  1.906e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.101e-02  4.520e-03  y = 0.62685 - ((-0.12035 + ((0.079556 - (Re ^ -0.27473)) /...
#                                        Se)) * (2.9206 + -0.51671))
# 18          8.904e-02  2.196e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.810e+04
# Progress: 641 / 800 total iterations (80.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.541e-02  9.779e-03  y = (Se * -0.51992) + (((Re ^ -0.12031) / 0.78192) * 2.770...
#                                       5)
# 15          9.184e-02  1.906e-02  y = 0.66181 - ((((0.079556 - (Re ^ -0.27473)) / Se) + -0.1...
#                                       2035) * 2.2384)
# 17          9.101e-02  4.520e-03  y = 0.62685 - ((-0.12035 + ((0.079556 - (Re ^ -0.27473)) /...
#                                        Se)) * (2.9206 + -0.51671))
# 18          8.904e-02  2.196e-02  y = ((-1.537 * (1.9558 / Se)) * (0.097022 - (Re ^ -0.26094...
#                                       ))) + (Re ^ -0.027575)
# 19          8.847e-02  6.349e-03  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.400e+04
# Progress: 660 / 800 total iterations (82.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.052e-02  3.606e-02  y = (((0.22743 - (Re ^ -0.16454)) * -1.9841) / Se) + 0.877...
#                                       47
# 17          8.860e-02  5.370e-03  y = ((((0.15288 - (Re ^ -0.23362)) * 1.2852) / (Se + -0.13...
#                                       635)) * -1.5785) + 0.9455
# 19          8.847e-02  7.157e-04  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.390e+04
# Progress: 678 / 800 total iterations (84.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.052e-02  3.606e-02  y = (((0.22743 - (Re ^ -0.16454)) * -1.9841) / Se) + 0.877...
#                                       47
# 17          8.860e-02  5.370e-03  y = ((((0.15288 - (Re ^ -0.23362)) * 1.2852) / (Se + -0.13...
#                                       635)) * -1.5785) + 0.9455
# 19          8.847e-02  7.157e-04  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.650e+04
# Progress: 692 / 800 total iterations (86.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.052e-02  3.606e-02  y = (((0.22743 - (Re ^ -0.16454)) * -1.9841) / Se) + 0.877...
#                                       47
# 17          8.860e-02  5.370e-03  y = ((((0.15288 - (Re ^ -0.23362)) * 1.2852) / (Se + -0.13...
#                                       635)) * -1.5785) + 0.9455
# 19          8.847e-02  7.157e-04  y = (((((0.097022 - (Re ^ -0.26094)) * 1.9558) / Se) + 0.1...
#                                       1365) * -1.537) + (1.1408 ^ -0.027575)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 2.180e+04
# Progress: 711 / 800 total iterations (88.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  1.550e-06  y = ((Se + 0.28394) ^ -0.3961) + 0.25147
# 9           9.982e-02  1.247e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.052e-02  3.606e-02  y = (((0.22743 - (Re ^ -0.16454)) * -1.9841) / Se) + 0.877...
#                                       47
# 17          8.831e-02  6.194e-03  y = (((((0.25606 - (Re ^ -0.1598)) * 1.499) / Se) * -1.859...
#                                       9) + 0.82416) - 0.025705
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.360e+04
# Progress: 735 / 800 total iterations (91.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  2.193e-05  y = ((Se ^ -0.18913) * 1.3795) + -0.22376
# 9           9.982e-02  1.246e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.052e-02  3.606e-02  y = (((0.22743 - (Re ^ -0.16454)) * -1.9841) / Se) + 0.877...
#                                       47
# 15          9.049e-02  1.570e-04  y = (((0.22743 - ((Re + -0.94934) ^ -0.16454)) * -1.9841) ...
#                                       / Se) + 0.87747
# 17          8.831e-02  1.223e-02  y = (((((0.25606 - (Re ^ -0.1598)) * 1.499) / Se) * -1.859...
#                                       9) + 0.82416) - 0.025705
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.080e+04
# Progress: 775 / 800 total iterations (96.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  2.193e-05  y = ((Se ^ -0.18913) * 1.3795) + -0.22376
# 9           9.982e-02  1.246e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.052e-02  3.606e-02  y = (((0.22743 - (Re ^ -0.16454)) * -1.9841) / Se) + 0.877...
#                                       47
# 15          9.049e-02  1.570e-04  y = (((0.22743 - ((Re + -0.94934) ^ -0.16454)) * -1.9841) ...
#                                       / Se) + 0.87747
# 17          8.831e-02  1.223e-02  y = (((((0.25606 - (Re ^ -0.1598)) * 1.499) / Se) * -1.859...
#                                       9) + 0.82416) - 0.025705
# 20          8.829e-02  6.307e-05  y = (((((0.25606 - (Re ^ -0.1598)) * 1.499) / Se) * -1.859...
#                                       9) + 0.82416) - (0.025705 * Se)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.273e-01  0.000e+00  y = 1.2114
# 6           1.131e-01  2.377e-02  y = (Se ^ -0.22292) * 1.1554
# 8           1.131e-01  2.193e-05  y = ((Se ^ -0.18913) * 1.3795) + -0.22376
# 9           9.982e-02  1.246e-01  y = ((Re ^ -0.22945) / Se) + 0.89669
# 11          9.729e-02  1.284e-02  y = ((Re ^ -0.27972) / (0.4882 * Se)) + 0.72025
# 13          9.052e-02  3.606e-02  y = (((0.22743 - (Re ^ -0.16454)) * -1.9841) / Se) + 0.877...
#                                       47
# 15          9.049e-02  1.570e-04  y = (((0.22743 - ((Re + -0.94934) ^ -0.16454)) * -1.9841) ...
#                                       / Se) + 0.87747
# 17          8.831e-02  1.223e-02  y = (((((0.25606 - (Re ^ -0.1598)) * 1.499) / Se) * -1.859...
#                                       9) + 0.82416) - 0.025705
# 19          8.822e-02  5.129e-04  y = ((0.25606 - (Re ^ -0.1598)) * ((1.499 / Se) * -1.8599)...
#                                       ) + (0.82416 + (0.025705 * -0.7277))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Tiempo de ejecución: 161.2229425907135 [s]
#   - outputs\20250921_010914_AR8BTH\hall_of_fame.csv

# %%
equations = model.equations_['equation']
equations = equations.apply(lambda x: x.replace('^', '**'))
print('=== TRAIN ===')
df_train = eval_equations(x_train, y_train, equations).sort_values(by='mse')
display(df_train)

print('\n=== VALIDATION ===')
x_val.rename(columns={'S': 'Se'}, inplace=True)
df_val = eval_equations(x_val, y_val, equations).sort_values(by='mse')
display(df_val)
# Out:
# === TRAIN ===
#                                          expresiones       mse
# 8  ((0.25606337 - (Re ** -0.15980455)) * ((1.4989...  0.088217
# 7  (((((0.25606337 - (Re ** -0.15980455)) * 1.498...  0.088307
# 6  (((0.22743377 - ((Re + -0.94934) ** -0.1645441...  0.090494
# 5  (((0.22743377 - (Re ** -0.16454414)) * -1.9841...  0.090523
# 4  ((Re ** -0.2797188) / (0.488201 * Se)) + 0.720...  0.097292
# 3             ((Re ** -0.22945052) / Se) + 0.8966898  0.099823
# 2    ((Se ** -0.18913063) * 1.3794578) + -0.22375883  0.113073
# 1                    (Se ** -0.22292398) * 1.1553878  0.113078
# 0                                           1.211369       inf
# === VALIDATION ===
#                                          expresiones       mse
# 7  (((((0.25606337 - (Re ** -0.15980455)) * 1.498...  0.064775
# 8  ((0.25606337 - (Re ** -0.15980455)) * ((1.4989...  0.065148
# 6  (((0.22743377 - ((Re + -0.94934) ** -0.1645441...  0.066693
# 5  (((0.22743377 - (Re ** -0.16454414)) * -1.9841...  0.066697
# 4  ((Re ** -0.2797188) / (0.488201 * Se)) + 0.720...  0.071370
# 3             ((Re ** -0.22945052) / Se) + 0.8966898  0.074511
# 2    ((Se ** -0.18913063) * 1.3794578) + -0.22375883  0.085465
# 1                    (Se ** -0.22292398) * 1.1553878  0.085530
# 0                                           1.211369       inf

# %%
expr = sp.sympify(
    df_val['expresiones'].iloc[0]
).evalf(4)
expr
# Out:
# 0.7985 - 1.86*(0.3838 - 1.499/Re**0.1598)/Se

# %%
x_test = pd.read_csv(r'.\DATA_LIB_Degradation\df_ff_test_des.txt')
y_true = x_test['frictionFactor']
x_test = x_test.drop('frictionFactor', axis=1)
print('x_test:')
display(x_train.head())
print('y_test:', y_true.to_numpy()[: 5])

f = sp.lambdify(sp.symbols('Re SoH Se'), expr, 'numpy')
y_pred = f(x_test['Re'].to_numpy(),
           x_test['SoH'].to_numpy(),
           x_test['S'].to_numpy())
print('y_pred =', y_pred[: 5])
print('n_pred =', len(y_pred), '/ n_true =', len(y_true))
print()

results = get_general_metrics(y_pred, y_true)
for key, value in results.items():
    print(key, '=', value[0], '+/-', value[1])
# Out:
# x_test:
#          Se          Re     SoH
# 0  0.280625  212.041256  0.6363
# 1  0.280625  212.041256  1.0000
# 2  0.280625  197.894331  1.0000
# 3  0.344410  188.969448  0.6363
# 4  0.344410  188.969448  1.0000
# y_test: [3.0442087  2.99253505 3.09981516 3.05552637 3.26630343]
# y_pred = [2.47988721 2.47988721 2.53089754 2.56518877 2.58060574]
# n_pred = 15626 / n_true = 15626
#
# RMSE = 0.25 +/- 0.17
# MAE = 0.18 +/- 0.17
# SMAPE = 15.52 +/- 14.06
